# %% [markdown]
# <a href="https://colab.research.google.com/github/lochana-vishwajith/ML_Assignment2_IT19140230_IT19111520_IT18014396_IT19152806/blob/Testing/Testings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
carset_final = pd.read_csv('vehicle_details_finals.csv')

# %%
carset = pd.read_csv('vehicle_data.csv',low_memory=False)

# %%
carset_final.head()
# Out:
#    Unnamed: 0     Price   Brand               Model  Year Condition  \
# 0           0  12900000   Honda               Vezel  2017      Used
# 1           1  16250000  Jaguar                  XF  2013      Used
# 2           2  17000000  Toyota                 CHR  2020      Used
# 3           3  13000000  Toyota                 CHR  2017      Used
# 4           4  33500000  Toyota  Land Cruiser Prado  2015      Used
#
#   Transmission       Body    Fuel  Capacity  Mileage
# 0    Automatic  SUV / 4x4  Hybrid      1500    37000
# 1    Automatic     Saloon  Diesel      2200    42000
# 2    Automatic  SUV / 4x4  Petrol      1200    15000
# 3    Automatic  SUV / 4x4  Petrol      1200    21000
# 4    Automatic  SUV / 4x4  Petrol      2700    57000

# %%
carset_final.isna()
# Out:
#        Unnamed: 0  Price  Brand  Model   Year  Condition  Transmission   Body  \
# 0           False  False  False  False  False      False         False  False
# 1           False  False  False  False  False      False         False  False
# 2           False  False  False  False  False      False         False  False
# 3           False  False  False  False  False      False         False  False
# 4           False  False  False  False  False      False         False  False
# ...           ...    ...    ...    ...    ...        ...           ...    ...
# 40378       False  False  False  False  False      False         False  False
# 40379       False  False  False  False  False      False         False  False
# 40380       False  False  False  False  False      False         False  False
# 40381       False  False  False  False  False      False         False  False
# 40382       False  False  False  False  False      False         False  False
#
#         Fuel  Capacity  Mileage
# ...

# %%
carset_final.isna().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Brand           0
# Model           0
# Year            0
# Condition       0
# Transmission    0
# Body            0
# Fuel            0
# Capacity        0
# Mileage         0
# dtype: int64

# %%
carset.head()
# Out:
#                                       Title  \
# 0         Honda Vezel Limited 2017 for sale
# 1      Jaguar XF Fully Loaded 2013 for sale
# 2  Toyota CHR GT New Face 2wd 2020 for sale
# 3           Toyota CHR Toyato 2017 for sale
# 4   Toyota Land Cruiser Prado 2015 for sale
#
#                                            Sub_title          Price   Brand  \
# 0  Posted on 01 Sep 2:45 pm, Kurunegala City, Kur...  Rs 12,900,000   Honda
# 1  Posted on 28 Sep 10:23 am, Kurunegala City, Ku...  Rs 16,250,000  Jaguar
# 2       Posted on 16 Sep 1:16 pm, Colombo 7, Colombo  Rs 17,000,000  Toyota
# 3      Posted on 30 Sep 10:12 am, Colombo 7, Colombo  Rs 13,000,000  Toyota
# 4        Posted on 30 Sep 9:50 pm, Kelaniya, Gampaha  Rs 33,500,000  Toyota
#
#                 Model          Edition  Year Condition Transmission  \
# 0               Vezel          Limited  2017      Used    Automatic
# 1                  XF     Fully Loaded  2013      Used    Automatic
# ...

# %%
carset.isna()
# Out:
#         Title  Sub_title  Price  Brand  Model  Edition   Year  Condition  \
# 0       False      False  False  False  False    False  False      False
# 1       False      False  False  False  False    False  False      False
# 2       False      False  False  False  False    False  False      False
# 3       False      False  False  False  False    False  False      False
# 4       False      False  False  False  False    False  False      False
# ...       ...        ...    ...    ...    ...      ...    ...        ...
# 123966  False      False  False  False  False     True  False      False
# 123967  False      False  False  False  False     True  False      False
# 123968  False      False  False  False  False     True  False      False
# 123969  False      False  False  False  False     True  False      False
# 123970  False      False  False  False  False     True  False      False
#
#         Transmission   Body   Fuel  Capacity  Mileage  Location  Description  \
# ...

# %%
carset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123971 entries, 0 to 123970
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Title           123971 non-null  object
#  1   Sub_title       123971 non-null  object
#  2   Price           123971 non-null  object
#  3   Brand           123971 non-null  object
#  4   Model           123970 non-null  object
#  5   Edition         47538 non-null   object
#  6   Year            123971 non-null  int64
#  7   Condition       123971 non-null  object
#  8   Transmission    123970 non-null  object
#  9   Body            118876 non-null  object
#  10  Fuel            123971 non-null  object
#  11  Capacity        123766 non-null  object
#  12  Mileage         123971 non-null  object
#  13  Location        123971 non-null  object
#  14  Description     107797 non-null  object
#  15  Post_URL        123971 non-null  object
# ...

# %%
carset['Edition'].unique()
# Out:
# array(['Limited', 'Fully Loaded', 'GT New Face 2wd', ..., 'Scp10',
#        'Grade 2016', 'G -TURBO'], dtype=object)

# %%
carset.isna().sum()
# Out:
# Title                 0
# Sub_title             0
# Price                 0
# Brand                 0
# Model                 1
# Edition           76433
# Year                  0
# Condition             0
# Transmission          1
# Body               5095
# Fuel                  0
# Capacity            205
# Mileage               0
# Location              0
# Description       16174
# Post_URL              0
# Seller_name          98
# Seller_type           0
# published_date        0
# dtype: int64

# %%
carset.isna().sum().reset_index(name="n").plot.bar(x='index', y='n', rot=45)

# %%
df = pd.DataFrame({'Price' : carset_final['Price']})
ax = df.plot.hist(by=["Price"], figsize=(10, 8),bins=20, alpha=0.5)

# %%
df.value_counts().plot.bar(figsize=(20, 8),x='index', y='n', rot=90)

# %%
carset_final['Price'].plot.bar()

# %%
carset_final.hist(column='Price')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7f9d2f0950>]],
#       dtype=object)
