# %% [markdown]
# <a href="https://colab.research.google.com/github/lochana-vishwajith/ML_Assignment2_IT19140230_IT19111520_IT18014396_IT19152806/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# description about the libraries
#
#
# **NumPy**
#
# NumPy, which stands for Numerical Python, is a python library that consists of multidimensional array objects and a collection of routines for processing those arrays. Using NumPy, logical and mathematical operations can be performed.
#
# **sklearn**
#
# Sklearn, which stands for scikit-learn is a python library for machine learning. Sklearn is focuses on machine learning techniques, such as mathematical, statistical, and general-purpose algorithms, which serve as the foundation for many machine learning technologies. The sklearn library includes a number of useful machine learning and statistical modeling methods, such as classification, regression, clustering, and dimensionality reduction.

# %%
#Importing libraries 
import pandas as pd
import numpy  as np
from sklearn import linear_model
import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# importing the code

# %%
url = 'https://raw.githubusercontent.com/lochana-vishwajith/ML_Assignment2_IT19140230_IT19111520_IT18014396_IT19152806/main/Vehicle%20details.csv'
carset = pd.read_csv(url)

# %%
carset = pd.read_csv('Vehicle_details.csv')

# %% [markdown]
# checking the dataset

# %%
carset.head()
# Out:
#         Price   Brand               Model          Edition  Year Condition  \
# 0  12,900,000   Honda               Vezel          Limited  2017      Used
# 1  16,250,000  Jaguar                  XF     Fully Loaded  2013      Used
# 2  17,000,000  Toyota                 CHR  GT New Face 2wd  2020      Used
# 3  13,000,000  Toyota                 CHR           Toyato  2017      Used
# 4  33,500,000  Toyota  Land Cruiser Prado            prado  2015      Used
#
#   Transmission       Body    Fuel  Capacity    Mileage
# 0    Automatic  SUV / 4x4  Hybrid  1,500 cc  37,000 km
# 1    Automatic     Saloon  Diesel  2,200 cc  42,000 km
# 2    Automatic  SUV / 4x4  Petrol  1,200 cc  15,000 km
# 3    Automatic  SUV / 4x4  Petrol  1,200 cc  21,000 km
# 4    Automatic  SUV / 4x4  Petrol  2,700 cc  57,000 km

# %%
carset.shape
# Out:
# (40531, 11)

# %%
carset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40531 entries, 0 to 40530
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Price         40531 non-null  object
#  1   Brand         40531 non-null  object
#  2   Model         40531 non-null  object
#  3   Edition       40531 non-null  object
#  4   Year          40531 non-null  int64
#  5   Condition     40531 non-null  object
#  6   Transmission  40531 non-null  object
#  7   Body          40531 non-null  object
#  8   Fuel          40531 non-null  object
#  9   Capacity      40531 non-null  object
#  10  Mileage       40531 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 3.4+ MB

# %% [markdown]
# Featuring the dataset

# %%
#finding the unique values available in the year
carset['Year'].unique()
#year column is ok
# Out:
# array([2017, 2013, 2020, 2015, 2018, 2016, 1995, 2007, 2012, 2010, 1985,
#        2008, 2019, 2003, 2014, 1999, 2011, 1982, 1989, 2006, 2009, 2005,
#        1993, 1990, 1988, 2004, 1981, 1983, 1979, 2002, 1991, 2000, 1996,
#        2001, 1997, 1984, 2021, 1998, 1978, 1987, 1986, 1992, 1994, 1960,
#        1975, 1958, 1980, 1976, 1956, 1959, 1953, 1967, 1973, 1972, 1955,
#        1946, 1968, 1961, 1969, 1970, 1974, 1966, 1977, 1971, 1947, 1963,
#        1964, 1945, 1952, 1965, 1957, 1935, 1938, 1950, 1962, 1922, 2022,
#        1951])

# %%
# finding the unique values in price
len(carset['Price'].unique())
# Out:
# 2516

# %%
len(carset['Edition'].unique())
# Out:
# 14106

# %% [markdown]
# some of the data has been supressed we cannot have a look on them so need to enable options to see them as well.

# %%
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# compute.use_numba : bool
#     Use the numba engine option for select operations if it is installed,
#     the default is False
#     Valid values: False,True
#     [default: False] [currently: False]
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# display.column_space No description available.
#     [default: 12] [currently: 12]
# display.date_dayfirst : boolean
#     When True, prints and parses dates with the day first, eg 20/01/2005
#     [default: False] [currently: False]
# display.date_yearfirst : boolean
#     When True, prints and parses dates with the year first, eg 2005/01/20
#     [default: False] [currently: False]
# display.encoding : str/unicode
#     Defaults to the detected encoding of the console.
#     Specifies the encoding to be used for strings returned by to_string,
#     these are generally strings meant to be displayed on the console.
#     [default: UTF-8] [currently: UTF-8]
# display.expand_frame_repr : boolean
#     Whether to print out the full DataFrame repr for wide DataFrames across
#     multiple lines, `max_columns` is still respected, but the output will
#     wrap-around across multiple "pages" if its width exceeds `display.width`.
#     [default: True] [currently: True]
# display.float_format : callable
#     The callable should accept a floating point number and return
#     a string with the desired format of the number. This is used
#     in some places like SeriesFormatter.
#     See formats.format.EngFormatter for an example.
#     [default: None] [currently: None]
# display.html.border : int
#     A ``border=value`` attribute is inserted in the ``<table>`` tag
#     for the DataFrame HTML repr.
#     [default: 1] [currently: 1]
# display.html.table_schema : boolean
#     Whether to publish a Table Schema representation for frontends
#     that support it.
#     (default: False)
#     [default: False] [currently: False]
# display.html.use_mathjax : boolean
#     When True, Jupyter notebook will process table contents using MathJax,
#     rendering mathematical expressions enclosed by the dollar symbol.
#     (default: True)
#     [default: True] [currently: True]
# display.large_repr : 'truncate'/'info'
#     For DataFrames exceeding max_rows/max_cols, the repr (and HTML repr) can
#     show a truncated table (the default from 0.13), or switch to the view from
#     df.info() (the behaviour in earlier versions of pandas).
#     [default: truncate] [currently: truncate]
# display.latex.escape : bool
#     This specifies if the to_latex method of a Dataframe uses escapes special
#     characters.
#     Valid values: False,True
#     [default: True] [currently: True]
# display.latex.longtable :bool
#     This specifies if the to_latex method of a Dataframe uses the longtable
#     format.
#     Valid values: False,True
#     [default: False] [currently: False]
# display.latex.multicolumn : bool
#     This specifies if the to_latex method of a Dataframe uses multicolumns
#     to pretty-print MultiIndex columns.
#     Valid values: False,True
#     [default: True] [currently: True]
# display.latex.multicolumn_format : bool
#     This specifies if the to_latex method of a Dataframe uses multicolumns
#     to pretty-print MultiIndex columns.
#     Valid values: False,True
#     [default: l] [currently: l]
# display.latex.multirow : bool
#     This specifies if the to_latex method of a Dataframe uses multirows
#     to pretty-print MultiIndex rows.
#     Valid values: False,True
#     [default: False] [currently: False]
# display.latex.repr : boolean
#     Whether to produce a latex DataFrame representation for jupyter
#     environments that support it.
#     (default: False)
#     [default: False] [currently: False]
# display.max_categories : int
#     This sets the maximum number of categories pandas should output when
#     printing out a `Categorical` or a Series of dtype "category".
#     [default: 8] [currently: 8]
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 20]
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 50]
# display.max_info_columns : int
#     max_info_columns is used in DataFrame.info method to decide if
#     per column information will be printed.
#     [default: 100] [currently: 100]
# display.max_info_rows : int or None
#     df.info() will usually show null-counts for each column.
#     For large frames this can be quite slow. max_info_rows and max_info_cols
#     limit this null check only to frames with smaller dimensions than
#     specified.
#     [default: 1690785] [currently: 1690785]
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]
# display.max_seq_items : int or None
#     When pretty-printing a long sequence, no more then `max_seq_items`
#     will be printed. If items are omitted, they will be denoted by the
#     addition of "..." to the resulting string.
#
#     If set to None, the number of items to be printed is unlimited.
#     [default: 100] [currently: 100]
# display.memory_usage : bool, string or None
#     This specifies if the memory usage of a DataFrame should be displayed when
#     df.info() is called. Valid values True,False,'deep'
#     [default: True] [currently: True]
# display.min_rows : int
#     The numbers of rows to show in a truncated view (when `max_rows` is
#     exceeded). Ignored when `max_rows` is set to None or 0. When set to
#     None, follows the value of `max_rows`.
#     [default: 10] [currently: 10]
# display.multi_sparse : boolean
#     "sparsify" MultiIndex display (don't display repeated
#     elements in outer levels within groups)
#     [default: True] [currently: True]
# display.notebook_repr_html : boolean
#     When True, IPython notebook will use html representation for
#     pandas objects (if it is available).
#     [default: True] [currently: True]
# display.pprint_nest_depth : int
#     Controls the number of nested levels to process when pretty-printing
#     [default: 3] [currently: 3]
# display.precision : int
#     Floating point output precision in terms of number of places after the
#     decimal, for regular formatting as well as scientific notation. Similar
#     to ``precision`` in :meth:`numpy.set_printoptions`.
#     [default: 6] [currently: 6]
# display.show_dimensions : boolean or 'truncate'
#     Whether to print out dimensions at the end of DataFrame repr.
#     If 'truncate' is specified, only print out the dimensions if the
#     frame is truncated (e.g. not display all rows and/or columns)
#     [default: truncate] [currently: truncate]
# display.unicode.ambiguous_as_wide : boolean
#     Whether to use the Unicode East Asian Width to calculate the display text
#     width.
#     Enabling this may affect to the performance (default: False)
#     [default: False] [currently: False]
# display.unicode.east_asian_width : boolean
#     Whether to use the Unicode East Asian Width to calculate the display text
#     width.
#     Enabling this may affect to the performance (default: False)
#     [default: False] [currently: False]
# display.width : int
#     Width of the display in characters. In case python/IPython is running in
#     a terminal this can be set to None and pandas will correctly auto-detect
#     the width.
#     Note that the IPython notebook, IPython qtconsole, or IDLE do not run in a
#     terminal and hence it is not possible to correctly detect the width.
#     [default: 80] [currently: 80]
# io.excel.ods.reader : string
#     The default Excel reader engine for 'ods' files. Available options:
#     auto, odf.
#     [default: auto] [currently: auto]
# io.excel.ods.writer : string
#     The default Excel writer engine for 'ods' files. Available options:
#     auto, odf.
#     [default: auto] [currently: auto]
# io.excel.xls.reader : string
#     The default Excel reader engine for 'xls' files. Available options:
#     auto, xlrd.
#     [default: auto] [currently: auto]
# io.excel.xls.writer : string
#     The default Excel writer engine for 'xls' files. Available options:
#     auto, xlwt.
#     [default: auto] [currently: auto]
#     (Deprecated, use `` instead.)
# io.excel.xlsb.reader : string
#     The default Excel reader engine for 'xlsb' files. Available options:
#     auto, pyxlsb.
#     [default: auto] [currently: auto]
# io.excel.xlsm.reader : string
#     The default Excel reader engine for 'xlsm' files. Available options:
#     auto, xlrd, openpyxl.
#     [default: auto] [currently: auto]
# io.excel.xlsm.writer : string
#     The default Excel writer engine for 'xlsm' files. Available options:
#     auto, openpyxl.
#     [default: auto] [currently: auto]
# io.excel.xlsx.reader : string
#     The default Excel reader engine for 'xlsx' files. Available options:
#     auto, xlrd, openpyxl.
#     [default: auto] [currently: auto]
# io.excel.xlsx.writer : string
#     The default Excel writer engine for 'xlsx' files. Available options:
#     auto, openpyxl, xlsxwriter.
#     [default: auto] [currently: auto]
# io.hdf.default_format : format
#     default format writing format, if None, then
#     put will default to 'fixed' and append will default to 'table'
#     [default: None] [currently: None]
# io.hdf.dropna_table : boolean
#     drop ALL nan rows when appending to a table
#     [default: False] [currently: False]
# io.parquet.engine : string
#     The default parquet reader/writer engine. Available options:
#     'auto', 'pyarrow', 'fastparquet', the default is 'auto'
#     [default: auto] [currently: auto]
# io.sql.engine : string
#     The default sql reader/writer engine. Available options:
#     'auto', 'sqlalchemy', the default is 'auto'
#     [default: auto] [currently: auto]
# mode.chained_assignment : string
#     Raise an exception, warn, or no action if trying to use chained assignment,
#     The default is warn
#     [default: warn] [currently: warn]
# mode.data_manager : string
#     Internal data manager type; can be "block" or "array". Defaults to "block",
#     unless overridden by the 'PANDAS_DATA_MANAGER' environment variable (needs
#     to be set before pandas is imported).
#     [default: block] [currently: block]
# mode.sim_interactive : boolean
#     Whether to simulate interactive mode for purposes of testing
#     [default: False] [currently: False]
# mode.string_storage : string
#     The default storage for StringDtype.
#     [default: python] [currently: python]
# mode.use_inf_as_na : boolean
#     True means treat None, NaN, INF, -INF as NA (old way),
#     False means None and NaN are null, but INF, -INF are not NA
#     (new way).
#     [default: False] [currently: False]
# mode.use_inf_as_null : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#     [default: False] [currently: False]
#     (Deprecated, use `mode.use_inf_as_na` instead.)
# plotting.backend : str
#     The plotting backend to use. The default value is "matplotlib", the
#     backend provided with pandas. Other backends can be specified by
#     providing the name of the module that implements the backend.
#     [default: matplotlib] [currently: matplotlib]
# plotting.matplotlib.register_converters : bool or 'auto'.
#     Whether to register converters with matplotlib's units registry for
#     dates, times, datetimes, and Periods. Toggling to False will remove
#     the converters, restoring any converters that pandas overwrote.
#     [default: auto] [currently: auto]
# styler.render.max_elements : int
#     The maximum number of data-cell (<td>) elements that will be rendered before
#     trimming will occur over columns, rows or both if needed.
#     [default: 262144] [currently: 262144]
# styler.sparse.columns : bool
#     Whether to sparsify the display of hierarchical columns. Setting to False will
#     display each explicit level element in a hierarchical key for each column.
#     [default: True] [currently: True]
# styler.sparse.index : bool
#     Whether to sparsify the display of a hierarchical index. Setting to False will
#     display each explicit level element in a hierarchical key for each row.
#     [default: True] [currently: True]

# %% [markdown]
# changing the options of the pandas to see all the rows

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %% [markdown]
# changing the properties

# %%
pd.set_option('display.max_rows',None)

# %%
pd.set_option('display.max_columns',None)

# %%
#display.max_seq_items

pd.set_option('display.max_colwidth',None)

# %%
#display.show_dimensions
pd.get_option('display.show_dimensions')
# Out:
# 'truncate'

# %%
from os import truncate
#display.show_dimensions set
pd.set_option('display.show_dimensions',True)

# %%
#display.show_dimensions
pd.get_option('display.show_dimensions')
# Out:
# True

# %% [markdown]
# checking out the options selected correctly or not

# %%
carset['Edition'].unique()
# Out:
# array(['Limited', 'Fully Loaded', 'GT New Face 2wd', 'Toyato', 'prado',
#        'Suzuki Alto Japan', 'SUV', 'FM Safety Edition 2', '2014',
#        'Safety', 'NGX 50 GT Turbo', 'GLD', '260', 'Premium', 'G Grade',
#        'GP1', 'BLUETEC HYBRID', '2010', '5 Hse', 'Box', '110 Puma 2.4',
#        'WXB 2019', 'E60 M SPORT', 'Stingray', 'Alto 2015', 'STINGRAY',
#        'TURBO', 'S Grade', 'TX L', 'LXI INDIAN', 'Ivory Package Z 2016',
#        'AUTO KOREA', 'G Grade 7 Seater', '(used)', 'G Grade 2014',
#        '2010 1st owner', 'safety', 'Audi', 'Sensing', 'Raize Z Grade',
#        'DIMO', 'Auto 2003 japan', 'N 17 1600cc manual', 'TX Limited',
#        '2017', 'M-Sport', 'Lexus Nx300h', 'Diesel LWB', 'LongWheel',
#        'M-Sport Plus', 'Cabriolet', 'SVO P400e', 'Sorento 2014',
#        'High Spec', 'F10', 'Si4 Non-hybrid', '2020 New Face lift',
#        'P400e', '5000cc Supercharged', 'TURBO CUSTOM 2018',
#        'Z Orange Gold', 'EX', 'Active-line', 'Audi A3 TFSI Sedan',
#        'Micro Geely Panda', 'EX PACK', 'GLX', 'Rocco B5', '6 SPEED',
#        'Japan', 'GXR', 'GT line', 'LXI', 'CRV Masterpiece 2020',
#        'Mitsubishi', 'Brand New', '1989', 'SR Turbo', 'Turbo Safety',
#        'ASX', 'Diesel', 'Mercedes Benz', '2013 3 option',
#        'Original M Sport', 'Full option', '2015', 'F Grade', 'Kompesaro',
#        '120 Diesel', 'G SUPERIOR', '3rd generation', 'Civic FD3', '-',
#        'Lancer cb2A', 'DGA/HA368 Alto', '240', 'Avantgarde', '270 XDI',
#        'KSP130', 'S-BMD21', 'G sport gs', '1st Owner', '800',
#        'Fully loaded', 'Japan (Auto)', 'Helly Hansen 4WD',
#        'Higest Grade cab', 'sport 2013', 'original Push Start',
#        'Automatic', 'WXB DAA-NKE165', '5th Generation', '2012', 'V2',
#        'Premium Sport', 'Champ 2015', 'Toyota Hilux Surf', 'Micro',
#        'Vogue P400e', 'Ex Turbo 1.0', 'GP5 L', 'Ex 2014',
#        '2nd Generation', 'C-Hr Gt Gx50', 'Toyota', 'Dual Purpose Cab',
#        'Center', 'W30', 'Majesta Luxury', '12000KMs', 'Premium Plus',
#        'Blue', 'T30 2004', 'X G Grade', 'wagon GL', 'Honda', 'GS Custom',
#        'Trim', 'Toyota 141( 1.6Auto)', 'G Superior - 2011',
#        'Honda Fit Gp1', 'V98', 'b210', 'WXB Anniveary', 'japan',
#        '2018 AMG Primum plus', 'S Touring', 'B11', 'SPORTS RXT Exchange',
#        'No edition', 'EK Wagon 2017', 'J Style', 'Cruze',
#        'Fb15 Auto Exchange', 'Vezel', 'FB14 (Doctor Sunny)',
#        'COMPANY BRAND NEW', 'G Superior', 'Gt', 'Bajaj Qute', 'M SPORT',
#        'TX', 'G', '2018', 'SUNROOF', '4', 'FB 13', 'FB 15 Super Saloon',
#        'Mirage GP5', 'Highest spec', 'TXL', 'HEAD UP DISPLAY', '518i',
#        'Ex Sedan Tech 2018', '5R Vtech', 'Safety Edition 2',
#        'Phev Rockford', 'Montero sport', 'E Four', 'G-Limited',
#        'FX Hybrid', 'AZEO', 'Land Cruiser Prado', 'PETROL 2011 REG',
#        '1.3 AUTO FULL OPT', 'Motor car', 'Sensing LED', 'Masterpiece',
#        'Alto Car', 'WXB Safety', '29K MILES 1ST OWNER', 'ESCUDO',
#        'eprise', 'Indica', 'GT Turbo NGX10', 'Sport', 'tata', 'GT Turbo',
#        'jeep 4Ã\x974', 'Noah', 'GP 5 S', 'Impreza', 'SLINE VOPRUNG',
#        'ZX V8 Bruno Cross', 'SEDAN EX TECH PACK', 'White CLA 200', '2004',
#        'GP 1', 'Suzuki', 'Limited Edition', 'S Led', 'Z Grade',
#        'Roomy Safety 2020', '2019', 'FX', 'Metallic Copper',
#        'S Line 4 Kitted', 'Bluetech Diesel', 'G / Chrome Grill',
#        'Diesel 1-20 CRDI', 'altoK11 Auto', 'B-15', 'Prado 150',
#        'Orange Package', 'TX 150 Diesel', 'Sportback', 'Hybrid', 'AWD',
#        'R Stingray 2018', 'Luxury Line', 'Long Wheel', 'V8 ZX 202',
#        'T156', 'G Revo', 'GP5', '1.5', 'Full Spec', 'S Line Anni Edition',
#        'KSP 130', 'Unregisterd', 'AE110 L GRADE AUTO', 'Dx Wagon',
#        'i Auto', 'SYLPHY FG10 AUTO', 'Diesel 3.2 V78W', 'S Line', 'Turbo',
#        'V8', 'Unregistered', 'Car', 'Montero 2007', 'Discovery 4',
#        'G superior', 'Xdrive', 'NGX10', 'WXB', 'Autobiography',
#        'LWB Autobiography', 'no', 'SX Turbo', 'SLINE FULL SPEC', 'K 10',
#        '260 G Grade', 'Single CAB', 'AZEO Model', 'GLS', 'Safety edition',
#        'Manual', 'Cygnus V8 LX470', 'GX', 'ZE 2 Auto Hybrid', '141',
#        'K11', '2005', 'X1', '2018 NEW FACE AXIO', '110', 'BJ5P',
#        'Frontier', 'custom', 'Auto Japan', 'AUTO', 'B14, EX Saloon',
#        '1981', 'Xurban', 'car', 'PHV Premium Plus', 'Box LC76',
#        'GT NGX50 Two Tone', 's-grade', 'Highest Spec G Plus', 'GP1 2014',
#        'Honda fit GP1 2013', 'Toyota Axio Hybrid', 'HSE Urban Diesel',
#        'V-TIL', 'AMG PREMIUM PLUS', 'Edition 2', 'FACELIFT',
#        'FX Safety Package', '2012 Fully Loaded', 'Xpander Cross',
#        '5 S 3000cc Diesel', 'TFSI S-Line', '2002/1.8T', '8 Airbags',
#        'FZ 2014', 'Axio Hybrid X Grade', 'super saloon N16', 'Montero V6',
#        'Ritz BXI', 'Limited V8', '2016', 'V46', 'Kia',
#        'Prado 95 Diesel 2002', 'Axio X Limited 2015', 'ZVW30', 'Vogue SE',
#        'Auto', 'SsanYong', 'Edition 3', 'GLS V6', '111',
#        'CE110, XE Saloon', 'Sedan TECH 1500cc', 'Stingray ..', 'Rocco',
#        'Max Full Option', 'GP 4  Hybrid', 'AMG Premium Plus', 'LC105',
#        'DOUBLE CAB 4WHEEL', 'GP5 S', 'V6 Elegance W211',
#        'Dolphin Grand cabin', 'Megane', 'e AMG Premium +',
#        'S Drive Diesel', 'Sr5', 'Push Start', 'N17  EX Saloon',
#        'WXB Package', 'B310', 'HSE Limited Edition', 'G sport',
#        '4 Diesel', '2006 New Body', '2000', 'EX Package',
#        '2013 Beige Interior', 'G-Superior', 'Full Option japan', 'B 11',
#        'Nissan Trad Sunny', 'WXB-Facelift', 'Non Hybrid', 'Panda',
#        'Black', '5008 GT', 'G Premium F/ Loaded', 'GT NGX50',
#        'Edition III', 'GT TURBO', 'Allure 2019', 'Custom Z Turbo',
#        'S Limited', 'Custom XS', 'Sports Japan', 'Safety Package', 'PHEV',
#        '2013', 'Custom Turbo', 'Ex Tech Sedan', 'MANUAL',
#        'Invincible Auto', 'Elegance', 'Toyota Vitz 2018',
#        'Long wheelbase', '3.0 D4D V Grade', 'Ex Saloon', 'Voxy',
#        'X Grade', 'Stonic Highest Grade', 'BLACK TOP', 'TRJ 150',
#        '318i Luxury Line', 'M Sport Sunroof', 'Discovery',
#        'S Line Fully Loaded', 'CROSA', 'Prius 30 G', 'GT Line', 'Zs',
#        '1.3CC', 'Wagon Car', 'Custom X', 'Highway Star Premium',
#        'Beetle AK 12', 'NZT 260', 'Prado 120', 'J STYLE',
#        'EX Stylish edition', 'Ex', 'AZE0', '120', 'Land Rover',
#        'Brilliant Style', 'SPORT HSE DIESEL', 'EX Grade', '121',
#        'X5 M Sport Full Spec', 'Custom Z', 'E300 Amg line', 'Exceed',
#        'GT  NGX10', 'V6 Jeep', 'MiCRO GEELY Mark ii', 'VX 101', 'SPORT',
#        'N17', 'B5 Rocco', 'B12 1986', 'EX Turbo', 'Mg', 'Turbo 4 Way Cam',
#        'Honda Sedan', 'New Face', 'Highest Grade', 'Nissan', '2.0 VVT',
#        'HSE', 'BJ 43', 'COMPANY WARRANTY', '141 Auto', 'Station Wagon',
#        'Latio 2016', 'TX-L', 'Revo Rocco', '2012 Face Lift',
#        'M Sport With SUNROOF', 'X Urban', 'GP 7', 'F Safety Edition II',
#        'FZ Safety (REG-2018)', 'FD 4 - 1.6 I-VTEC', '(Titanium)',
#        'GP5 Cruise Control', 'TWIST', 'diesel 7 seat', 'Single Cab',
#        'Tata Indigo 2006', 'Mazda', 'GT', 'Sunlight Copper', 'C11',
#        'Platinum', 'BLACK', 'White', 'GP5 L 13000km s',
#        '2014 reg non hybrid', 'Premium AMW warranty',
#        'G PREMIUM PLUS PHEV', '5 HSE LuXury Package', 'K10',
#        'Z Gold 2014', 'SWB Vogue', 'LWB Comfort Plus F/L',
#        'P300 R-Dynamic HSE', 'Diesel SV LWB', 'Land Cruiser Double',
#        'HSE 2.0', 'V8 VX Diesel', '7 Seater', 'VTIL Turbo 7 Seat ER',
#        'AMG Premium Package', 'LWB SML FrontierP400', 'Belta Pearl White',
#        'Original M SPORT Plu', 'L Hybrid LWB Highest', 'TRJ150 TX Diesel',
#        'DIESEL 2.0 SML', 'V DIESEL 3.0 7 Seate', 'nissan sunny b310',
#        'M Sport', 'Comfort Plus', 'GT Turbo 2 Tone', 'G Revo Revolution',
#        'AMG Premium LIne', 'AMG Package', 'Y11', 'Quattro 2.0 S Line',
#        'AE80', 'G-Touring', 'P100d', '6 Speaker', 'S limited', 'Gray',
#        'G grade', '2018 Sefty Package', '1.3 EFI AUTO',
#        'G Grade Push Start', 'ILS - AMG', '1.0 Automatic', 'flat light',
#        'G Limited', 'Safety Edition', 'G Custom J Style',
#        'Daihatsu Mira 2018', 'FB15', 'Honda civic ES8', 'Lexus Rx300',
#        'KE 20', 'Push Start 4 Way Cam', 'Intercooler', 'DAA-NHFIO Aqua',
#        'Japan Alto', 'Elite', '54H', 'AE 80', '2011', 'ZS',
#        'Z Orange 2014', 'Vista', 'Full Option', 'fate light',
#        'Toyota Roomy Gs', '128', 'DBA- KSP 130', 'Corolla 141 1 st Onr',
#        'Pajero IO', 'A4', 'FB14', 'X25', 'EP 92', 'COROLLA 110',
#        'Outlander', 'CUSTOM', 'Fully Loaded Sunroof', '110 D240',
#        'Center Spare Wheel', 'AMG', '3 Options Model', 'AMG FULL SPEC',
#        '2000 Cc Quattro', 'PHEV 2014/16', 'LWB AMG', 'TFSi Sport', 'Gp1',
#        'Premium Package', 'DBA-NGX50', 'Corolla', '2009', 'Indica v2',
#        'GP-5 S GRADE', 'S- Grade', 'BMW', '3rd Generation',
#        'M SPORT FULL SPEC', 'Alto Sport 2011', 'Unregistered WXB',
#        '4x4 Diesel', 'Sunroof Fully Loaded', 'HIGH SPEC', 'Smart',
#        'Z Orange package', 'Hyundai Stellar', 'P300', 'FB 14', 'Custom',
#        'SB14 SUPER SALOON', 'S-LINE FULL SPEC', 'VVTI Japan Auto', 'GD 1',
#        'Alpha Sport', 'HSE SPECIAL PAINT', '120 TX', '2002',
#        'xDrive40e Msport', 'Sensing 2019', 'Glory', 'TZ G',
#        'FB15 EX SALOON', 'fz', 'mini cooper', 'S350', 'Hilux',
#        '23,661 Km X Limited', 'AT150', 'Crossroad', 'Lexus', 'Glory TDI',
#        'GT Custom Turbo', 'Toyota premio', 'Wagon R FZ', 'MX 7', '1984',
#        '3rd S Grade', 'Vx Limited', 'Vigo smart cab', 'NGX-50 GT',
#        'Low Mileage', '1000', 'EX Fully Loaded 2016', 'Mode Premier',
#        'Daihatsu Premium', 'Prado TRJ150', 'PHEV G Premium 2015',
#        'MZ Highest', 'GP5 L Grade', 'vigo champ', 'FULL OPTION',
#        'Center Antena', 'S', 'Hatchback', '2016 Facelift Model', 'GM4',
#        'J style', 'LC 1.0', '2007', 'VIGO DOUBLE CAB', 'Hiace LH 30',
#        'Eprise', 'ES 8', 'executive', '323', 'avenchura',
#        'Autobiography SWB', 'Mira', 'PLEO G Grade', 'G Limited 3.0L',
#        'TUCSON 4 WHEEL', 'Face Lift S', 'LWB Highest Spec', 'NGX 10',
#        'Premium+/Amg Line', 'SDrive18i', 'unlimited edition',
#        'Luxury Car', 'GP5 Hybrid 2015', 'G Superior 260',
#        'Sky Active Luxury', 'URBAN', 'GP5 SAFETY PACKAGE', 'Closed AA435',
#        'Hkk', 'N16 AUTO JAPAN', 'FB15 AUTO', 'AE110 AUTO', 'Y61',
#        'N17 SUPER SALOON', 'Honda fit gp1', 'S Drive 18i',
#        'Land Cruiser Sahara', 'wagon 106', 'EE102 AUTO', 'Auto 2002',
#        'Auto 2011', '2013 S GRADE', '2012 S GRADE', 'Daihatsu',
#        'D21 Turbo Double Cab', 'TFS Double Cab', 'CBAJ200E',
#        'GP5 Hybrid ""S"" Grade', 'G Plus', 'Alto', 'D21 Double Cab',
#        'Suzuki Alto car', 'Japan Masterpiece', 'EX Saloon SB13',
#        'S Full Spec', 'Prefect', 'Cup Holder', 'S AGENT WARRANTY',
#        'Tech Pack Sedan', '3.0 INVINCIBLE LC5', '1-20 Options',
#        '2017 TFSI', 'DISEL AUTO JEEP', 'VX V8 DIESEL', '323 Wagon.',
#        'VX V8 ICE PACK', 'Diesel 4X4', '1.4 TFSI', 'LXI 800',
#        'â\x80\x9cVXâ\x80\x9d Diesel', '240G', 'Electric Mem Sets',
#        'S Limiterd', 'TZ 4.0 V6', '2015 VXI', 'Highway Star', 'M Sports',
#        'N17 Ex Saloon', '5 Forwad', 'Honda Vezel', 'TOYOTA ROCCO 2018',
#        'Face Lift', 'Bluebird EU14', 'VXI', 'L grade', 'CE 106',
#        'Super Exceed', 'XS Custom Turbo', 'AMG Diesel',
#        'Range Rover Rvoque', 'G Garde', 'Passo 2007', 'Ivory Pack 2015',
#        'I Auto', '260  G Grade 2011', 'KE20', 'Vx V8', 'S Grade GP5',
#        'G grade Safety', 'Honda CRV', 'Autobiography PHEV',
#        '2013 G Grade', 'fulloption', 'ZE2 2012', 'GLE 250d AMG Premi +',
#        'KSP90', 'AMW PREMIUM', 'G Grade 2015', 'Alto 800 2016',
#        'GT Turbo NGX-10', 'M Sport Fully Loaded', 'Limited Designo',
#        'Sports', 'Full Petrol', 'S Line Unregistered', 'VIGO SINGLE CAB',
#        'Double cab', 'Aqua 2012', 'ZX 2016 fully loaded',
#        'sunroof 7 seater', 'CLO48', 'NZT260', 'Suzuki Alto Lxi 2015',
#        'FB 15 Ex Saloon', 'JS', '121 G Grade', 'C160', 'GS',
#        'Toyota Prius 2013', 'AK12', 'Rush jeep', '260 G SUPERIOR F-EX',
#        'Hyundai', 'Alto 800', 'Diesel Fully Loaded', 'Roco', 'N16 Nissan',
#        'AE91', 'Reg 2017', 'Wagon R fZ', 'Land cruiser 120', 'XDrive 35i',
#        'K 11', 'Z Grade Gold Orange', 'Turbo VTI-l7', 'G Plus - NZT260',
#        '2.0L Diesel', 'G Style Pack', 'Deisel', '260 NZT', 'Prius s',
#        'GP2', '1978', 'Toyota 121', '4 X 4', 'Suzuki Alto', 'L',
#        'Austin A35', 'ZXI Elegance', 'Luxury Line 2015', 'Prefect 100e',
#        'VTI-L', 'Skyactive', 'sensing', 'saloon', '121 G',
#        'Nissan sunny b310', 'Toyota IST FL 2007', '110 TD5', 'Japanies',
#        'Model Duet', 'RU3 - Orange package', 'X URBAN Reg. 2017', 'N 16',
#        'Autech', 'ZE 2', '3L AUTO', '3L.AUTO', 'KSP-130', 'X URBAN',
#        'outlander', 'pickup', 'Safety Package 2017', 'Z Great',
#        'Safety Edition 3', 'push start', 'Night Edition', 'SKY BLUE',
#        'Toyota Prado', 'MH 55S', 'LN166', 'S Grade 2012',
#        'Glory 580 L GRADE', 'G Grade (WXB)', 'LeGrand', 'Individual',
#        'vezel Z', 'Hilux Cab Sale', 'Premium Ezi', 'TURBO 2019', 'Saftey',
#        'Silver', 'FZ Safety', 'Immaculate', 'Turbo 2018', 'Jeep',
#        '260 model', 'Aventura', '13', 'Toyota vitz safety',
#        'GT - UNREGISTERED', '4th Gen', 'MG ZS 2018', 'stringray',
#        'Swift 1.3 Japan', 'LN 107', 'CS1', 'japan subaru',
#        'Safty edition 01', '(Japan)', 'R FZ 2018', 'Latio',
#        'EX Tech Pack', 'N16 special editione', 'premium', 'SUV 4 x 4',
#        'roccoB5', 'R  2017', 'Grand Cherokee', 'EX Diesel', 'wagon DX',
#        'Nickel Package', 'RE4', 'sports', 'Diesel Turbo', 'ksp90',
#        'Vogue SWB AB 2018', 'G Grade 2016', 'Montero Sport', 'GS SPORTS',
#        'DBA-KSP 130', 'Saloon', 'ROCCO B5 LIMITED', 'DX', '2.5 Lt Turbo',
#        'S class 2015', 'Petrol', 'MSPORT', 'HSE Luxury',
#        'Full Option Auto', 'FD 3', 'Wagon R Fx', 'FB 14 EX SALOON',
#        'G Grade 2013', 'AMG Line', 'k10', 'L300s', 'Highest 2017', 'RU3',
#        'grace', 'Diesel Auto Push', 'NZE 121', 'petrol', 'VTiL', 'BWM',
#        'Toyota Dark Grey', 'MG ZS', 'Minor', 'ZE 3', 'Mirage Vitz Swift',
#        'AE 101 Uk Veion', 'Masterpiece Japan', 'AK 12', '4DR5 4WELL Jeep',
#        'Xtrail 2016 Hybrid', 'GP1 Hybrid FineStyle',
#        'AutobiographyLWB SML', 'Rexton - W', 'S Grade-(DAA-NHP10)',
#        'Eclipse Cross 4WD', 'LXI 2015', 'Z Gold 2014 (2015)', 'dayz',
#        'FZ', 'Alto LXI Model', 'ES 8 (Facelift)', 'DAA GP3',
#        'B5 Rocco 2018', 'VTI- S', 'TFSI', 'Suzuki Swift  2017', 'V Grade',
#        '2001', 'vezel z grade', 'Vxi', 'U Grade', 'G touring', 'AmG line',
#        'S grade', 'Wagon Type', 'C11v', 'PHEV Sunroof',
#        '2.0L TFSI S-TRONIC', 'Swift', 'LKI', 'VITZ GT 1300', 'SUNNY',
#        'PAJERO', 'VTEC', '100', '2016  brand new', 'kE72', 'Celerio',
#        'E FX', 'TX LIMITED', 'S LINE - SALOON', '8 Airbag Push Start',
#        'safty', 'GT Turbo 2019', 'night edition', 'Evoque', 'EX Pack',
#        'V8 DIESEL', 'BRUNO 2WD', 'Full options', '2003', 'MG ZS 7500km',
#        'Baic X25', 'Ti', 'ES8 JAPAN', 'KEY START SAFETY', 'CRV 2018',
#        'Box Prado', 'N16 Auto 1.5 Sylphy', 'ROCCO B5', 'GD1 2007',
#        'Full Option Petrol', 'H-MATIC', 'Z GRADE B/ INTERIOR', '2020',
#        'S MODEL', 'EX PACKAGE', 'S Limited Edition', '141 BRAND NEW',
#        '4Ã\x974 Full Option', 'Raum', 'GLI', 'Z GRADE',
#        'WXB FULLY LOADED', 'Sportero', 'FZ PACKAGE', 'Custom Z Grade Ltd',
#        'WXB G Grade', 'RXT Full Option', 'SENSING', 'VXI New Model',
#        '1 TO 12', 'F Grade Limited', 'Premio', 'Z Grade Orenge Pkg',
#        'Air Bag Model', 'Cygnus', 'TURBO 4WAY', '3rd gen S Grade',
#        'DX wagon', 'Lx', 'Freelander 2 TD4 GS', 'SAFETY EDITON 3',
#        'WXB G GRADE', 'G GRADE', 'ELEGANCE', 'AK12 K12',
#        'GT B/TOP FACE LIFT', 'DIESEL', 'N16', 'S LINE', 'G TURBO 4WD',
#        'EX SENSING FACE LIFT', '4TH GENERATION', 'PREMIUM PACKAGE',
#        'GT BLACK TOP 2WD', 'G TURBO', 'F EX PACKAGE', 'F EX',
#        'EX JAPAN MASTERPIECE', 'VTI-L AUSTRALIAN', 'VTI-LX 4WD',
#        'REVO V GRADE', 'CJ1 Auto', 'CJ1 AUTO', 'Push Dual Multifunct',
#        'CE100', 'HB12 EX Saloon', 'DFSK 580', 'Mint condition',
#        'highway star', 'ZE0', 'TD4', 'Safety Edition II', 'Mini Cooper',
#        'G Great 2016', 'Ke20', 'X Limited', 'kia', 'VXi', 'AK 13',
#        'Wagon R FX', 'Allion 260', 'Np 80', 'Grace Ex Limited',
#        'PHEV G Nevy', '5 Series Petrol', 'March', 'CS 2',
#        'FB15 Ex Saloon', 'TOYOTA', 'M Sport Plus', 'GP5 S Grade',
#        'HRV Japan Auto', '5', 'Axio', 'Highway UNREGISTER', 'NGX50',
#        'Sorento 2015', 'Safety Push Start', 'GLS FULLY LOADED',
#        'SPORT ORIGINAL USA', 'Sports Edition', 'SMART KEY',
#        'GLI Special Edition', 'HB12 trad  Auto', 'Tan Interior',
#        'CLA 180 AMG CLA 45', 'Mercedes Benz C200', 'Prius C',
#        'Mini Car 2 Door', 'Z Full Leatger', 'GLS350d', 'Diesel TX',
#        'V6 3l Supercharger', 'lancer 5 FWD', 'Phev full Option', 'Msport',
#        'S touring', 'Safety unregistered', 'HZJ76', 'Aqua',
#        'Sportero 4D56 2017', 'Hachback', 'Pajero For Sale', 'TX150',
#        'Plug-in-Hybrid PHEV', 'Japan Full Option', 'FL Grade', 'Desal',
#        'Black (LED)', 'GT/ 4 Way Cameras', 'N16 super saloon',
#        '7 seater auto', 'RX8', 'Viva Elite', 'JAPAN ALTO',
#        'G UNREGISTERED', 'VIGO CAB 4 WD', 'Revolution G grade',
#        'M SPORT ( ORIGINAL )', 'Lxi', 'G Super 260', 'Toyota vios',
#        'W212', 'G plus', 'LJ76', 'LJ150', '2008', 'Raptor', 'Tekna',
#        'CBC Safety', 'WXB G', 'Essenes', 'Toyota Corolla',
#        '2005 FULL OPTIONS', 'Laser', 'Hatch Back', 'Orange Edition',
#        'Titanium', 'Aqua Xurban', 'FULL OPTIONS', 'ALTO 2018 SAFETY',
#        'Non Hybrid 2011', 'Japan 2010', 'ZE2 2011', 'Opel Asta',
#        'HYBRID - X LTD / W', 'AK - 12 { AUTO }', 'GP 1 BLACK',
#        'X GRADE PETROL - W', 'SENSING - C/RED', '#NAME?',
#        'NON SAFETY - W', 'PEARL WHITE', 'Roomy', 'Ee 107', 'G High Grade',
#        'Z Grade Orange Pack', 'DBA-NRE 160', 'Panda White 2017', '1979',
#        'L Grade', 'Tank', 'Panda 1300cc', 'SAFETY', 'K11 AUTO CUP HOLDER',
#        'MATIZ', 'BRAND NEW 580', 'U GRADE', 'morris mini cooper',
#        'M Sport Highest Spec', 'EX sensing', 'GT Unregisterd',
#        'Belta Pearl 2011', 'L400  SUV 4x4', 'Suzuki Celerio VXI',
#        'DBA -NZT260', 'HB12 Trad Sunny', 'Zc 71', 'Swist XTA', 'Serena',
#        'GRX', 'Push start', 'Gp5', 'CJ-1', 'Vitz', 'Lancer', 'Power-Up',
#        'Axio G grade', 'BMW 740le', 'SPORT 4WD Auto',
#        'MITSUBISHI ATTRAGE', 'LC5 - DIESEL', 'B 310', 'prado LC5',
#        'Celerio Vxi', 'xtrail 2016', '2018 01st Owner', 'civic',
#        'x3 xdrive 20d', 'PUMA', 'Stigray safety', '03 Options',
#        'INDIVIDUAL M SPORT', 'LXI Indian', '121 Auto 2006 Japan',
#        'MICRO PANDA', 'Outlaw 2007', 'Passo safety 2020',
#        'Sport 2.5 Diesel', '2 GX100', 'Daihatsu Cab', 'Japan Auto 2005',
#        'Honda Grace 2016 EX', 'GT LED', 'Kei', 'Fz', 'Le Grand',
#        'Shadow edition', 'toyota mark 2', 'Allure  GT - Line',
#        'SE Saloon', '4Ã\x974 XLT AUTO', 'SE', 'Sport Diesel',
#        'ZRT260 G SUPERIOR', 'Diesel Com. Reg.2019', 'F Safety Package',
#        '206', 'Harrier (Lexus)', 'aqua', '7 Seats',
#        'G Grade Chrome Shell', 'Wagon GL 1979', 'G Limited 2012',
#        'Panda Air bag', 'Toyota Aqua X Urban', 'Toyota Stalat',
#        'Air-Bag Model', 'EL53 1.5CC AUTO', 'DIESEL 4WD', 'S GRADE',
#        'Original Sports', 'Outlaw', 'KE70', 'PRADO 120',
#        'Suzuki wagon R FX', 'Consul', 'Standard Vanguard', 'Auto 2009',
#        'CHAMP', 'GP.5 L GRADE', 'Premium Edition', 'GP 5', 'G PLUS',
#        'Austin 8', 'good car', 'Montero Sport 2012', 'Gp5 Sport', 'T30',
#        'Vitz PUSH PEARL', 'Renault', 'A5 2018', 'Audi A8 LWB',
#        'GP5 Push Start', 'A60', 'GP5 2014', 'Acenta UK', 'xtrail petrol',
#        'LC5 2013', 'High way star', 'ZE2', '2.0TDi', 'Premium Plus AMG',
#        'TRJ150', 'V78', 'Blue Bird', 'Plugin Hybrid', 'Ac Allow Wheels',
#        'Bandit', 'discovery 4 se', 'Alpha', 'sport pure diesel', 'GP 2',
#        'SDrive20D', 'yellow', 'Safety - White', 'Orange Vitz',
#        'Grey EX Package', 'RED', 'White Primium plus', 'Sky Blue', 'HB12',
#        'GT NGX50 AWD', 'M Sport Full Option', 'CONVERTIBLE',
#        'Mystical Purple', 'BLUE', '4Ã\x974', '1400', '4WD', '3rd Gen',
#        'Red', 'AT170 Auto', 'AMG Premium 2015', 'Chrome Shell G Grade',
#        'L200', 'XLI (Manual gear)', 'Whait', 'Rg2017', 'Suv', 'Black Top',
#        'F/O', 'nissan', 'G Grade 2004', 'GP5 S Grade Highest',
#        'Lancer Box', '4*4 drive', 'N16 Super Saloon', 'Lancer wagon',
#        'Ford Cortina MK4', '1303', 'Flat Light 12', 'Navy Premium',
#        'silver', '260 G Superior', 'Ex Highest grade', '1985',
#        'WXB Limited Edition', 'SKYACTIV', 'RX-8', 'Jeep - military',
#        'N17/ N16 Face lift', 'lancer box', 'TI My road',
#        'Toyota Aqua G Grade', '6 Speake Edition 3', 'auto',
#        'Exclusive Line', 'Corolla AE80', 'X Limited 8 AIRBAGS', 'Grand',
#        'E60', 'black top', 'Elegance / Petrol', 'AT 192',
#        '220d/ Non Hybrid', 'G Supirior', 'platz', 'B Class', 'FB 15',
#        'Mitsubishi Pajero IO', '7 Seater VTI-L', 'Quattro',
#        'Full Option 7 Seater', 'BJ5p', '(1-9)', 'Alto Turbo',
#        '2017 Safety', '260 G', 'full option', 'Edition', 'S gread',
#        'GP 5 Safety Package', 'yaris', 'Hybrid Full Option',
#        'honda civic', '2016 Alto', 'PREMIO G SUPERIOR',
#        'Honda Grace 2015 EX', 'LEXUS', 'Sunroof Leather Seat',
#        'Diesel Brand New', 'AA 60', 'Lancer ex', 'WildTrak 3.2',
#        'Z grade', '4DR', 'Sunny', 'AMG Styling', 'Axia 2016 G Grade',
#        'Custom z Turbo', '330', 'Fully Loaded-Safety', 'Fielder WXB',
#        'Vouge Autobiagraphy', 'GP5 L Plus', 'Gp2', 'HB11', 'Grade  C',
#        'V6', '220d/W212', 'B15', 'BMW i8 Protonic', '2 Grade',
#        'FB 15 EX Salon', 'Land Rover Defender', 'CE 90',
#        'Orange pack Z grade', 'XLT (4Ã\x974)', 'Vios New Face',
#        '2018 Model', 'pajero', 'Premium Plus PHV', 'TX 150 / 6FWD',
#        'CUSTOM UNREGISTER', 'FB15 EX Saloon', 'Vigo',
#        'N17 (n16) Auto Gear', 'YOM-2007 FD3 HYBRID', 'LX 470 V8',
#        'GP1 Hybrid', 'WAGON UNREGISTER', 'PHEV 2014', 'NEW UNREGISTER',
#        'FD1', 'x UNREGISTER', 'GP5 S Mugen Package', 'SPACIA CUSTOM Z',
#        'Moda unregister', 'TURBO NON HYBRID', 'SAFETY PACKAGE',
#        '3.0L TURBO THAILAND', 'Alphard', 'Prado 150 Diesel TX',
#        'G Superior FEX', 'Diesel SunRoof Auto', 'NUBiRA', 'GP 5 F Grade',
#        'Rexton 2007', 'Advance Premium', 'GP 5  L', 'L Type',
#        'Honda fit S Grade', 'GLS Brand New', 'HSE Diesel Sport',
#        'Custem Z', 'Vezel Orange Pack', 'RXT', 'indian', 'Gp 5 2015',
#        'New Face Lift', 'Toyota Yaris', 'DBA.DE3FS', 'Gs Sport',
#        'Honda FIT GP5', 'CUSTOM Z', 'CHR', 'Swift Dzire VXI',
#        'S Line - 3 Kitted', 'Allion G', 'Ex Package', 'Vogue P400E',
#        'P400E', 'Z Highest Orange', 'Ford', 'DAA- GP5',
#        'AMG Line Premium', '350', 'Wagon', 'NZE121 G-grade',
#        'GP 1 Navi Premium', 'Agent Maintained', 'Sorento', '2800',
#        'LC 1.3', 'DFSK', 'G Grade 2012', 'Peugeot', 'Pajero',
#        'lancer tube light', 'Perodua', 'CHR NGX50 AWD',
#        '2019 3rd Edition', 'Trad Sunny', 'Xs Custom', 'Nissan Patrol 160',
#        'Verossa', 'RX-300', 'Ritz VXi 2011', 'Toyota Vitz 2017',
#        'AMG PREMIUM +', 'Kyron 2009', 'Prado-G Frontier', 'Gen-2 2006',
#        'Orange Pack', 'SENSING F/LOADED', '141 corolla',
#        'W212 Avant Grade', '4DR 6', 'KIJANG', 'xeta', 'Hybrid 4WD',
#        'Toyota Prado GX', 'G grade Limited', 'Vigo Smart Cab', 'ZC71S',
#        'Revolution', 'G200S', 'RU4 (4WD)', '141 Lx', 'NISSAN', 'ABS',
#        'EX Tech Sedan', 'S350 AMG', 'Wagon R Stingray',
#        'Auto Full option', 'Smart Key', 'G+ Fully Loaded',
#        'Auto Full Option', 'C230 Sport', '2 Full Option', 'Suzuki alto',
#        'Moda Pack', 'GS CUSTOM', 'Grey C 200 Diesel', 'TFSI Turbo',
#        'Diesel Full Option', 'Package Suv', 'Nissan Patrol Y60',
#        'Z Orange Pack', 'TFSI Turbo (Diesel)', 'VTi Lx', 'ZE1 40KWH',
#        '1300CC Full option', 'Axio Non-Hybrid', '1-10 options',
#        'CRDI 4x4', '2017  Sensing', 'V6 Turbo', 'Toyota corona ct190',
#        'Hybrid Crossover', 'Ex TechPack', 'Lucino', 'ESTIMA G',
#        '2 Diesel', 'Cx', '7 SEATER G GRADE', 'INTELIGENT',
#        'Auto - sunroof', 'auto-Modified', 'CALIFORNIA', 'AUTO 1.5',
#        '2006', 'P.start/M.function', 'Edition 2 Safty Push',
#        'Japanese-Auto', 'F Safty', 'Z Orange', 'TSFI', 'GLA 180',
#        '7 seater(RT-2) 2 Ltr', 'Vezel 2014', 'LongWheelbase Highes',
#        'GP5-S grade/safety', 'DIESEL Autobiography',
#        'GP1-intelligent key', 'Passo-Auto', 'S-Grade', 'EX Masterpiece',
#        'K 12', 'Toyota Vios', 'Intercooler Turbo2.8', '200XDI',
#        'G-plus (NZT-260)', 'V6 Fully Loaded', 'Autech Mode Premier',
#        'Japan Alto 2004', 'sport', 'Isuzu', 'Nissan Sunny 1980',
#        'Toppo BJ', 'Honda insight ZE2', 'F Safety Edition', 'EL 43',
#        '3 rd generation', 'GLS 350d - 4 Matic', 'HL 2 UK', '2018 Safety',
#        'Outlander 2015', 'Safety 2017', 'Rocky', 'SU14', 'G, Limited',
#        '/Turbo', 'Sylphy 1.5L', '2018 Silver', '1300cc Full Option',
#        'Vitz Multy Funtion', '4x4 SUV - Diesel', 'landcruiser prado tx',
#        'P 400e Autobiography', 'k12', 'Edition 2 2018', 'V8 Supercharged',
#        '2011 Option 1-12', 'EE103', 'Z CUSTOM TURBO', 'discovery 4',
#        'WXB CAU', 'V 3.0', 'DAA-NHP10', '(MINI)', 'FX 2017',
#        'Z Orange Package', 'S - Limited', 'GT Turbo NGX10 2WD', 'Fd3',
#        '2002 V6', 'XS', 'PETROL 4800cc', 'montero Sport',
#        'SPORTS Exchange', '45 Blue', 'Doscovery 4S', 'Suzuki Alto 2018',
#        'Y10', 'F Ex 2019', 'W115 220D Classic', 'Trad Sunny B12', 'Gp 2',
#        '725Ld M Sport', '300tdi', '1977', 'CRDI 4X4', 'MG',
#        'M-sport High Spec', 'Three Wheeler Car', 'G Superior (FEX)',
#        '2013 KX', 'AMG  (Barbus)', 'Lexus Harrier', '725d M Sport',
#        'Ex Saloon N16', 'Stingray 2018', 'Bajaj  Qute', '2012 Automatic',
#        'WPCAM', 'With Warranty', 'Wargon R', 'SF5 - STI M2',
#        '260 G-SUPERIOR', 'Axia G', 'Tx150', 'Axio G Grade', 'CX', 'MX7',
#        'Edition 2018', 'WagonR FZ', 'Toyota Vios Japan', '150 TX',
#        'Axela', '2016 Safety Edition', 'wagon r fz safety', 'CE110 1997',
#        'Full safety Japan', 'AMG premium plus', 'Honda veezl',
#        'S Line Petrol', 'Trajet', 'KR - 6210', 'AE - 110', 'NTZ 260',
#        'JAC T6 double cab', 'Wagon 1984', 'X urban', 'LX', 'EG8',
#        'Z Grade Fully loaded', 'Non-Hybrid G grade',
#        'Toyota Axio WXB 2017', 'REVO Double Cab', 'Z Purple', '141 LX',
#        "Tom's G limited", 'Project car', 'Spacia 2018', 'wagon R', '1974',
#        'axio', '18_4029', 'Suzuki Celerio 2015', '.', 'DX Wagon',
#        'Toyota Corolla 141', 'EP 91', 'WFY11 Auto', 'CT190', 'i Light',
#        'Vitz 2018 Safety', 'SkyActiv', 'Cus Turbo UNREGISTER',
#        'SAFETY UNREGISTERED', 'Glx Saloon', 'J  style',
#        'toyota axio 2016', 'Toyota Belta 2010', 'Nissan march K11',
#        '141 Lx 1.6', 'Autobiography P400', 'L Grade - 3rd Gen', 'cab',
#        '141 GLI', 'Sportback 2018', 'E Unregistered', 'Lafesta 2011',
#        'R 2017', 'G - Grade', 'Colt', 'Mira car 2018', 'YOM',
#        'Galant (A52 Model)', 'Suzuki Alto 2015', 'Ex Package 2019',
#        'Xenon Light Truck', 'Ct141', 'Astrella', 'T32 Non-Hybrid', 'Phev',
#        'G super', 'AE 70', 'sunny B12', 'Mode Premier Autech',
#        'Perodua Bezza', 'Suzuki alto K10', 'Suzuki Wagon R 2015',
#        'Australian', 'G-Plus', 'X', 'mini cab', 'Double Cab',
#        'Cayenne S Turbo', '10th Anniveary', 'Autotech ModePremier',
#        'New Shape G Navi', 'toyota passo', 'EX with Sunroof',
#        'HSE Diesel', 'Toyota  vitz', 'G Fontier', '7',
#        'Unregistered (Raize)', 'SD4 Diesel Top-Spec',
#        'Sportback 1.0 TFSI', 'VXI Indian', 'S-Line', 'SR', 'Essence',
#        'Prius', 'R-Design Pro Diesel', 'ksp90 -2011', 'VX Diesel',
#        'Honda Grace EX', 'Japanese', 'E200 Cabriolet AMG',
#        'Suzuki Alto 2017', 'Suzuki Wagon R Fx', 'Suzuki Spacia 2018',
#        '3rd Gen 2011', 'Honda Civic FD1 S', 'Mercedes', 'Premium 2016',
#        'FZ 2016/2017', '200 Premium Tech Pck', 'M5', 'SML Warranty LWB',
#        'Audi A6 S-line 2014', 'Lancer Box 5 FWD', 'Fully automatic',
#        'honda', 'land rover Defender', 'G L model', '1990',
#        'NHW 10 prius', 'Dba - Ksp130Vitz', 'SAFETY EDITION', '1986',
#        'Ex Grade', 'NGX 50', 'Corolla KE30', '3008 GT-Line SUV',
#        'Sorento 2013', 'Wagon R', '4DR6', 'latio', '2 HSE',
#        'Custom 2 Auto Door', '2017 brand new', 'S UNREGISTERED',
#        'Black/Grey', 'Lucino sport', 'Turbo Edition', 'X-Grade',
#        'GS Sport', '3 Ltr Diesel', 'Axio X-Grade', 'GS CUSTOM MODELLIST',
#        'motor car', 'Custom UNREGISTERED', 'UNREGISTERED',
#        'REVO ROCCO B5', 'fb15', 'Aqua 2015', 'Rav4', 'Corolla 121',
#        'GS CUSTOM UNREGISTER', 'HANA PKG UNREGISTER', 'Spike',
#        'XS Custom', 'U-VA', 'AMG premium', 'Nissan HB11', 'G-Grade',
#        'M-Sport Edition', 'R-Dynamic', 'TZ', 'ES Safety', 'Premium Su',
#        'DE3FS', 'KSP 130 Push Start', 'Custom GS', 'Avant-garde 2004',
#        '25T Limited', 'F SPORT', 'Swift  Turbo 4 Way', 'S Drive18i',
#        'Edition 2 Safety', 'G Sports', 'IX', 'LS 2008', 'Honda Grace',
#        'R FZ 2017', 'Moda', '(Used)', 'Safety Edition 1', 'fz safety',
#        'Lapin Unregistered', 'LS grade', 'Premium Plus 2020',
#        'Japan Auto', 'VOPRUNG', 'wagon r fx 2017', 'Cayenne',
#        'Autech Mode Premium', 'Kyron', 'Bluetec Hybrid',
#        'Japan UNREGISTERED', 'NT 260', 'Leather sheets', 'Edition Shadow',
#        'EX Full option', 'M Package', 'Mercedes Benz e250',
#        '4DR Long Wheel', 'Celerio 2020', 'Highway star', 'AZEO G grade',
#        'HSE PURE Diesel 2.0', '2.9 TD', 'Honda GP4',
#        '725D M-SPORT DIESEL', 'Diesel Auto', 'Face Lift TFSI',
#        'Axio Grade', 'Fit GP5', 'Sensing 2017', 'P12', '4th Generation',
#        'GT NGX10', 'VTI L Turbo', 'Alto 800 LXI', 'Push Start Limited',
#        'X5 NIGHT EDITION', 'Flat Light A75', 'E Grade', 'V8 Cygnus',
#        'Galant', 'Rocco 2020', 'Micro Panda 1.0 Auto', 'LIMITED SUV',
#        'mini wagon R type', 'AT212', 'F56 (2-door) 1.5L', 'Toyota GT86',
#        'Land', 'suzuki Hustler', 'Nissan Leaf ZEO', 'Maruti Suzuki',
#        'Crossover', 'Corolla 141 B/N', '2nd gen', '206 2006', 'MARK II',
#        'GP5 L grade', 'Uraban X', 'F75R', 'Toyota Aqua 2014', 'Ke 72',
#        'AMG Premium Pck', 'G Supirio', 'Zxi', 'M-Sport LWB', 'M sport',
#        'Long Wheel Base', 'EE90', 'CE110', 'Bruno NGX 10', 'Allure', 'ex',
#        'R Sport Dynamic', 'Honda N/  Editione', 'Honda Vezel Z Orange',
#        'Ex package', 'Toyota aqua 2015', 'Toyota Prius G', 'Edition 03',
#        'B310 Wagon', 'kE55', 'Lancer l tight', 'no (original)',
#        'Hardtop Convertible', 'Vouge Autobiography', 'DBA-KSP130 Vitz',
#        'Tredia GLX', 'Single Cab 4x4', 'FD3', 'AE 110 Auto',
#        'Wagon R FZ 2015', 'CK2', 'FEX NZT260', 'stingry', 'Luxury 4WD',
#        'N16 EX Saloon', 'EP91', 'Safety Turbo 2017', 'Lancer CS1',
#        'Estima', 'Stream', 'J Style Safety', 'J-STYLE', 'EP 92 Auto',
#        'Hybrid G Grade', 'Modellista', 'Ivory Package', 'GT AUTO',
#        'IO GDI', 'Protonic Red', 'VTI-L SUV 7 SEATS', '11', 'G/S',
#        'DEISEL MANUAL', 'G  Grade', 'R Dynamic', 'Premio 2019', 'Tz',
#        'SYLPHY G11 AUTO', '120 TZ', 'Suzuki Alto Japan S', '1983',
#        'CUSTOM SAFETY PACKAG', 'M Sport Australian',
#        'GP1 Smart Selection', 'Toyota Axio WXB', 'Fielder', '105',
#        'G Navi', 'Oulaw', '1971', '2012 G', 'S R Dynamic',
#        'Sdrive20d 2012', 'Terois', 'S,Grade', 'Sedan', 'Facelift',
#        'Fit 2014', '4 GS', 'March K11', 'Diamond', 'Suzuki  Wagon R',
#        'Power Push', 'Gx', 'Vogue SE SWB P400', 'B211', 'EE102',
#        'Mazda 6', 'GT LED PEARL',
#        'â\x80\x8dâ\x80\x8dâ\x80\x8dâ\x80\x8dZ grade oreng', 'Lancer GL',
#        'Royal Saloon G', 'Prius  G Sports', 'Tredia', 'GT Facelift',
#        'Fx great 2016', 'Pearl white', 'Premio G Superior', '1997',
#        'Toyota vitz 2008', 'FD 4 1.6 I-VTEC', 'Prado', 'Toyota G Touring',
#        'x grade', 'TX150 DIESEL', 'Autobiography LWB', 'K13', 'CRDi',
#        'Smart Cab', 'push Start Limited', 'P300 HSE', 'Ex Tech 2020',
#        'LXI 2006', 'A15', 'XLT', 'toyota  hilux', 'orange pack', 'tx 150',
#        'Toyota Saefty Pakege', 'X-TRAIL HT32', 'GT NGX 50', 'Vti - LX',
#        'ke72', 'Sports Chrono', '2018-REG', 'Longwheel Base',
#        'Pure Petrol', 'S Grade Limited', 'Edition 2019',
#        'Toyota Roomy car', 'Luxury Line Premium', 'PREMIUM', 'Axio WXB',
#        'TOYOTA CHR NGX50', 'Ngx 10', 'G LIMITED', '202 V8 ZX',
#        'R  FZ 2018 Safety', 'Edition 3 Safety', 'Civic Tech Pack',
#        'Grace EX Package', 'scp10', 'Safety Edition3 2019',
#        'Suzuki Turbo', 'S LTD/CRUISE CONTROL', '7 Seater Petrol', 'RS',
#        'hybrid', 'Hilux Rocco', 'BMW X1 SDrive M', 'VXI Limited Edition',
#        '141 LIMITED EDITION', 'D 22', 'Black Colour',
#        'Vogue 3E- Black Pack', 'HSE SD4', 'S55', '2nd Gen',
#        'Z ORANGE GOLD BATCH', '2011 diesel', 'Dayz', '260 G+',
#        'VTI-L Turbo', 'C180', 'Vitz Edition 3', 'mitsubishi',
#        'FZ Premium', '240 Anniversary', '1500cc', 'EX Saloon', 'R172',
#        'Toyota Aqua Reg2017', 'Vezel Sensing', 'Super Saloon Fb 15',
#        'Alto LXI', 'X grade', 'ksp 130', 'ALLION G LIMITED',
#        'FZ Safety 2018', 'G SUPERIOR ST WACTH', 'suv', 'Datsun', 'CBB',
#        '2nd Edition', 'M Sport (Original)', 'Toyota Axio WXB 2020',
#        '3rd Generation 2014', 'Wagon 1980', 'Alto Japan',
#        'MG 2019 ZS Turbo', '120 TZ Fully Loaded', 'Allion', 'GP7',
#        'NGX-50', '580', 'Toyota corolla 121', 'special edition',
#        'Sahara 200', 'Toyota Camry', 'Ek space', 'FB15 New Shell',
#        'FB15 Super Saloon', 'Lancer Wagon', 'Exclusive Package', 'SX4',
#        'Toyota Ep 91', 'KE 72', 'Sky Active', 'Audi A6', 'G grade  WXB',
#        'FB15 SUPER SLOON', 'G -TURBO', 'Tata', 'Y61 Safari',
#        'CRV - VTi-LX AWD', 'Toyota corolla 141', 'CRDi 4WD', 'CRV 7 STR',
#        'Ex Sensing', 'double cab', 'DBA KSP 130', 'Prius 2010',
#        'Vitz 2016', 'Hilux Vigo', 'ZEN VXI', 'Sensing LED safty',
#        '8 Air Bag Push Start', 'Gp5 S Grade', 'Hybrid Night Edition',
#        'IX35', 'Sahara 2017', 'V8 ZX Bruno Cross202', 'Toyota Vitz 2016',
#        'M-SPORT LWB Highest', 'M Sport Night Vision', 'Nke 165 G Grade',
#        'Ke50', 'Cast 1984', 'JT600 1988', 'K10 March', 'TX 150',
#        'Sliding Panroof', 'G Superior FullyLoad', 'X Sensing 2017',
#        'Z Sensing', 'S Line TFSi Sport', 'Model 2012', 'Chogm', '323 Car',
#        'High spec', '2017 model', 'S Grade (Body Kit)', '4DR5 J44',
#        'Santafe 4x4', 'Mini pajero', 'Fb15', 'VX V8 Parliament',
#        'DAA MH55S', 'Z Grade panoramic', '2014 Z Grade', 'ALLURE',
#        'SWB Vouge Black Pck', '320d Face Lift', 'BMW 520D', 'GP5 Hybrid',
#        '110 Kahn', 'Tx 150', '2.5 GT', 'DID Diesel', 'NGX10 GT Turbo',
#        'GP5  - L', 'Avant-Garde', 'Eon', 'TRJ150 6FWD FaceLift',
#        'Suzuki Wagon R', 'Sensing 2018', 'JTE150 Diesel VX',
#        'Black C350e Sport', 'JTE150 Diesel TX', 'nomad',
#        'vezel Z Grade Orange', 'XG Safety', 'Safety Packege',
#        'vezel 2014', 'Orange Packege', 'turbo', 'G grade 2012',
#        'EK Wagon', '4 Way Auto Parking', 'japan Volvo', '20 Anniversary',
#        'Face Lift Model', 'S Full Option', 'Stingray J Style',
#        'Z Style Luxury', 'AMG Premium plus', 'GT NGX10 2WD', 'C12',
#        'toyota Roomy', 'Custom Z 2017', 'GM4 - EX', 'Rs',
#        'Toyota vitz 2019', '30', 'Edition 3 1500cc', 'Custom Safety',
#        'Z Grade Orange pack', '1.8', 'GP 5 L Grade', 'G Touring',
#        '1 - 9 option', 'HSE Pure Diesel', 'HB 11', 'Wagon R FX 2016',
#        'prius 2nd Gen', 'W124', 'brand new', 'CHR 2018',
#        'TRD Limited 6FWD', 'Sahara 81', 'R-Line', 'Technology pack', 'F',
#        'Montero 2002', 'Mira E:S', 'Honda Civic Sedan Uk',
#        'GT Line Fully Loaded', 'Boxy', 'io', 'CelerioX Sports',
#        'Tx TRJ150 6FWD', 'Tx TRJ150', '2013 S Limited', 'XBee',
#        'TJR 150W', 'Fortuner', 'TRJ150 Fully Loaded', '2011 1-10', 'ford',
#        '200 V8 Fully Loaded', 'Passo Moda G Grade', 'CE 110',
#        'TFSI Unregister 1.4', 'R FZ 2018 AMW', 'TX TRJ150 Face Lift',
#        '(G) Highest Grade', 'Safety F Grade', 'Honda Civic ES 1',
#        'Zen VXI', '2nd Gen Annivasary', 'Suzuki Swift RS',
#        'G Grade Pearl White', 'SAFETY LOW MILEAGE', 'KSP90 08 AIRBAGS',
#        '/2016', 'Champ', 'Autobiography LW', 'R Dynamic HSE 240D',
#        'G Special', 'Prius 3rd Gen S LED', 'Honda Grace EX pack',
#        '2000cc', 'z grade', 'Ksp 130 Safety', 'Civic', '200DX', 'Urban X',
#        'Masterpiece 2018', 'ROCOO 2020', 'VXI stingray', 'REVO',
#        '1NZ 240 2004', 'vezel', '2016 4th generation',
#        'AMG Sport Premium', 'Sonata EF', 'M235i Convertible', 'Q3 S Line',
#        'Q3 Vorsprung', 'Corolla 141', 'Q7 Fully Loaded', 'GP5  L Grade',
#        'Convertible', 'Spacia Custom G', '2.7V', 'Honda Insight ZE2',
#        'White Titanium', 'WXB 2018', 'Sensing Facelift',
#        'HB 12 Super Salon', 'Prado TZ G', 'Sarwa break/1600 cc',
#        'Sport Line', 'TFSI 35 S Line', '1-12 Options',
#        'KSP 130 Safety Edi', 'TURBO SAFETY PACKAGE', 'Diesel Jeep',
#        'SkyActive', 'M Sport Carbon Core', 'Active Vacation', '4Motion',
#        'Cs1 Evolution ix', 'Hybrid ML', 'NightPack', 'Exclusive line',
#        'Plug-In-Hybrid', 'GP5 - L grade', 'GT Allure Premium',
#        '3rd  Generation', 'ECO Boost  2.3', '7-Jan', 'Honda FD 4', 'Wxb',
#        'NGX 10 2WD GT Turbo', 'Electric', 'K12', 'Toyota Axio WXB 2018',
#        'Model S', 'KIA', 'prius', 'Toyota Axio 2015', 'A/C Power',
#        'Cedric', 'Maserati Levante DV6', 'M Modern Line', 'Bmw',
#        'J31  Luxury', '4DR 5', 'LWB Highest Grade', 'Centre Spare Wheel',
#        'Toyota Vitz 2008', 'At140', 'XG', 'Anniversary Edition',
#        'GP 5 S Grade', 'G Superior 2013', 'Trad HB-12', '1980',
#        '2.0 PETROL', 'GT 2017', 'HSE Only Diesel SML', 'GP5-L',
#        'Facelift Model', 'TFSI PETROL', 'M sport Coupe Diesel',
#        'Kompessor Avangard', 'D22 Cab', 'R FX 2017', 'G- Premium',
#        'TZ 120', 'EIS', 'Toyota Vitz KSP 90', 'Z Grade O Package',
#        'Aqua G Limited 2014', 'A3 sportback UNREG', '2014 G Grade',
#        'Nissan Dayz 2018', 'KSP 90', 'J 44 - Long Wheel', 'Gen 3',
#        '2.0G 4WD', 'Hybrid FD3', 'TX TRJ120', 'Ex Limited', 'Safety Full',
#        'Honda Civic SR UK', 'Navi Premium 2014', 'Sedan full option',
#        '2015 txj 150', 'Sunny 1981', 'Allion 260 G+', 'Ex saloon N16',
#        'Isuzu Single Cab', 'A71', 'B210 SPORT', '2011 1-9 Option',
#        'XV-V6', '150 Prado TX', 'S Touring Limited', 'Prado 150 / 6FWD',
#        'Australian Version', 'AMG Premium PlusDimo', 'super exceed',
#        'vx v8', 'FEX', 'G100 1987', 'NGX - 10', '300TDI', 'Q7 Quattro',
#        'Highest Spec', 'G Superior F EX Pack', 'K10 2015', 'Ravo',
#        'Z Grade (Orange)', 'Warrior Auto', 'Highest Grade Z',
#        '3rd Gen 1st Owner', 'NGX10 GT - TURBO', 'Z Grade Black Pack',
#        '12', 'KDJ150R (Europe)', 'GT NGX10 2wd', 'S Grade 2015',
#        'allion260', 'Toyota Allion 260', 'BMW i8', 'Safety 2019 Reg',
#        'New shape', 'AMG Premium Plus AIR', 'Aze0', '250 XV',
#        'Amg Premium Plus', 'Honda Vezel Z Grade', '| 2020 F grade',
#        'Custom Turbo Z', 'FD1 Type S', 'Amg premium plus',
#        'CE 108 L Model', 'FB1', 'Stingray J-Style', 'Polar White', 'M16',
#        'GT TRO', '7 Seater G Premium', 'S LED', 'G electric seat',
#        'Note Nismo Body kit', '3 option', 'SPORTS EFI', 'Prius 2012',
#        'Wigo G GRADE', 'FD 4', 'Sport GLS Diesel', 'GS (G Sport)',
#        'TOYOTA HILUX Vigo', 'Full Option GLS', 'Alto 800cc', 'CAP',
#        'F Ex G Superior', '323 Inter Play', 'NoX10', 'Honda Civic EX UK',
#        'C180 2014', '2017 G Frontior', '2019 Premium Plus',
#        'GT Turbo Red Top', 'G Sport', 'Gp 5  S grade', 'Laurel', 'K50',
#        'Axio NKE 165', 'GT turbo Blacktop', 'Intercooler Turbo',
#        'Stingray Safety', 'Allion 260 G Grade', 'Navi Premium', 'ML320',
#        'Turbo 2018 2019', 'GP5 Grade S', 'MH55S FZ', 'Triton',
#        '202 Fully Loaded', '8 Air Bag L/Edition', 'Raize 2020', 'Benz',
#        'Discovery 2', 'GSuperior', 'Jeep 4Ã\x974', 'CAE-2492', '6',
#        'Revo', 'SHOGUN', 'SCP90', 'GS Grade', 'K12 Beetle',
#        'NGX 10 GT Turbo', 'Parallel Hybrid', 'Gold badge', '2700XDI',
#        'Prado 150 TX', 'stingray', '4 Way Camera', '725D Exclusive Line',
#        'ZXI', 'TFSI/Turbo', '1.5GL 1981', 'gp2', 'BJ 5',
#        'Z Black Package', 'Full Options', 'Cabriolet AMG', 'IO',
#        'Grade 2013', 'Jelly', 'Alto 800 LXi', 'Vogue Autobiography',
#        'ac power, new paint', 'Allion NZT260', 'ksp130 F Grade',
#        'Every wagon', 'Vigo Double cab', 'Safty Package', '1300 cc',
#        'jewela', 'Swift Rs', 'land rover DEFENDER', 'Edition 3 2019 LED',
#        'F Ex', 'vigo 2007', 'Palathsaba', 'Twist', 'Passo MODA', 'ESTIMA',
#        'Tavera', 'Custom XS 2018', 'W211 avant-garde', 'Orange package',
#        'F Sport', 'Kia Rio 1500 F/O', 'Hilux Surf SSR-X',
#        'Aqua 2013/2015', 'MZ 2018', 'g grade', 'Honda Fit Gp5',
#        'G. Grade', 'C11 1987', 'Hyundai Accent SE', 'Techpack',
#        '2018 NZT 260', 'Non safety', 'B11 Car', '1-12 Option', 'Jstyle',
#        'SV Autobiography', 'Safety edition 2', 'P/ plus   N/ Edition',
#        'FZ 2017', 'G Grade hybrid 2016', 'urban S', 'R -  2017',
#        'axio wxb', 'Vezel RS', 'Sport Premium', 'CLA 200',
#        '2017 automatically', 'Alto Japan L Grade', 'Passo 2008', 'Ct170',
#        'Fully loaded/j style', 'Shadow Edition', 'G Grade Ltd', 'Works',
#        'Marino', 'Honda Vezel 2014', 'DID V6 Coupe', 'Korean',
#        'BlueTEC Hybrid', 'F grade', '1 TO 20 Fully Loaded',
#        'M Sports 2017', 'Z Grad Orange Pack', 'PREMIUM PLUS Fully L',
#        'Brand New  Diesel', 'Sky-Active', '150TX', 'Ksp130 F Grade',
#        'GT Turbo NGX -10', 'Mini Cooper 1969', 'RM 01',
#        '2016 full option', 'WXB grade', 'Prius 2013', 'Tucson',
#        'Hybrid 2014', 'LX 470', 'AE110', 'KSP 130 Full Safety',
#        'pearl White', 't30', 'Montero Jeep', 'G - Superior',
#        'Sedan tech pack', 'Honda Fit Gp5 SGrade', 's grade', '2018 4WD',
#        'Wagon R 2015', 'Sorento 1-12 Option', 'Side Antenna', 'v8',
#        'Edition 1', 'Fully Loaded 2012', '90 Automatic', 'Swift Turbo RS',
#        'premio', 'Spacia Custom z', 'Audi A8-L', 'Boon XL full option',
#        'CBK-0531', 'HSE LUXURY', 'SR  Turbo', '2018 Face Lift',
#        'Sportage AWD', 'KC 7681', 'GT NGX10 Turbo', '1999',
#        'outlander PHEV', 'Jewela Black Edition', 'X1 X line',
#        'Allion 240', 'Ex106A', 'Hilux 2018', 'KiA Fride', 'JEWELA',
#        'Swift Center Antena', 'JT600', '16', 'allion 240', 'Mini cooper',
#        'G Limited Edition', 'YOR 2014', 'Box 1980', 'Honda Fit GP4 RS',
#        'sunny', 'Z Grade Orange', 'Toyota S Touring', '120 GX 2003',
#        'Supercharged', 'Dx 1984', 'Toyota Axio G Grade', 'Toyoto Tank',
#        'Silver Quattro', 'S DRIVE 20d', 'Diesel 2016', 'safety 03', 'G30',
#        'FL', 'GP5 F Grade', 'TX Diesel', 'GP4 Hybrid RS', 'Gold Badge',
#        '2016 /', 'Prius 20', 'String Gray', 'Toyota premio FEX', 'EFI',
#        'V8 Zx Diesel', 'Swift Turbo', 'TOYOTA SAI HYBRID',
#        'Premio F Grade', 'orange package', 'CRV VTI-L Australian',
#        'G Premium', 'Robe', 'F 2017', 'ZX', 'colt', 'Sports EFI',
#        'Japan X grade', 'Prado TX REG 2018', 'C200', 'CAX',
#        'NGX50 GT LED', 'MZ 4X4', 'Black Edition', 'WXB 2018 Limited',
#        'Freelander 2', 'cx', 'B 12', 'Cross', 'Premier Autech 2016',
#        'EX/MASTERPIECE/JAPAN', '1000 Turbo', 'Tech Pack',
#        '4TH GEN / SUNROOF', 'CAC', 'used', 'wagon',
#        'G Superior 8 AirBags', '8 Air Bags', '5 J24', 'Tata Nano',
#        'Grace EX 2015', 'AMG CDI Sports Sedan', '520d',
#        'Royal Extra G180', 'D21 Cab', 'Vagon 1974', 'Push Start 2008',
#        'Land cruiser 2017G', 'X5', 'Premium 2014', 'ZRE141R',
#        'Quattro S Line', 'Vezel Rs', 'GE 06', 'AMG L Premium Plus',
#        'Double Cab Sports', 'TRD', 'Honda Civic', 'Tx Limited',
#        'AMG Version', '14-1161', 'Tx', 'EX Sensing', 'RVSI-2', 'Ae100',
#        'Sports EFI Exchange', 'Manuwal Transmission', '1.8T',
#        'maruti 800', 'Roadster', 'GT LED Turbo', 'Sport 2012', '325',
#        'C12 1985', 'Stingray 2015', 'Ep82', 'DBA-KSP90 Vitz', 'Jaguar',
#        'prime', '4 S', 'Limited Editon', 'Night edition AMG', 'D 21',
#        '2020 REG', 'Black 2015', '2011/2013 ZE2', 'KSP90 2008',
#        'VX limited 101', 'Daihatsu Mira', 'Corona', 'Montero',
#        'A6 2013 Diesel 15Mil', 'mercedes benz', 'Y12w',
#        'Lancer (MIVEC 1.8GT)', 'Royal Saloon', '14 SHI 7694',
#        'Premium Advanced', 'KG', 'Super', 'DX wagen', 'CHR GT TURBO',
#        'Dx wagon', 'Wake 2018 car', 'Aqua S Grade', 'X Sport',
#        'Passo XG Safety', 'VVT 7 Seater', '2018 - G Superior',
#        'GLB 200 AMG Premium', 'Longwaydown', '2WD SUV', 'PASSO 2016',
#        'Ex Master', 'Navi premium', 'Honda fit shutle GP2', 'KE 50',
#        'Kembara (terios)', '2', 'Limited editions',
#        'Front Japan Seat Set', '2006 New body', '1400cc', 'montero',
#        'FEX (G Superior)', 'Sky active', '1988', 'allion 260',
#        'io Anniversary', 'V6 GLS', 'CRV', '70D', 'SPORTS UNREGISTERED',
#        'copen x play', 'Toyota roomy 2018', 'M SPORT AUTO', 'Toyota vitz',
#        'X-Urban', 'Subaru', 'Vigo 2009', '250XV,V6', 'VX Limited',
#        'Progressive Pack', 'NaviPremium Package', '110 riviere',
#        'Z ORANGE PACKAGE', 'NOAH', 'KSP90 08 Airbags', 'KE20 hilux',
#        '30 (3rd Gen) Car', '1987', 'Used', 'X Unregistered', 'Honda Gp 1',
#        'HSE 2.0 Diesel', 'safety Package', 'Hybrid UK Lexus',
#        '2018 Cross', '2L Twin Spark', 'Non Turbo', 'Aqua 2016', 'Fx',
#        '60th Anniversary', 'GT NGX50 4WD', 'Sunny 1987',
#        'Diesel 120 2005', 'Bentley Continental', 'Gx Limited Edition',
#        'Annivesery Ivory', 'A8L 3.0 Quattro', 'W123', 'Edition 03 LED',
#        'Land Cruiser 79 V8', 'Hilux Revo 2018', 'Premio 2017', 'KA67',
#        'Fit Gp5 S Grade', 'Toyota Vitz', 'Pearl White 2017',
#        '2008 Maruti', 'Toyota Premio', 'RX 8 R3', '2.0 C Diesel Turbo',
#        'super Saloon N16', 'Sky-Activ', 'Corolla 1976', 'DS',
#        'mitsublish', 'RX Sensing', 'Grand Tiger D/Cab',
#        'GP5 S grade 2017', 'Lancer 1986', 'Gs Custom', 'X-trail Nt31',
#        '17 2000', 'Luxury Package', 'Porsche', 'X Uaban', 'Diesel CE110',
#        'ZAA AZED', 'ASP', 'DX Wagon KE74', 'Plug-In Hybrid',
#        'Msport Short Wheel', 'Roof Console', 'G101S', 'S GRADE 2013',
#        'GLE 300D', 'EX Sport', 'R FX 2018', 'ZS 2018', 'Gp5 L 2016 Reg.',
#        'Sunny Wagon', 'AMG Night Edition', 'Premium Plus 2017', 'CBF',
#        'Register 2020', 'GL', 'Nissan Laurel HC34', 'R FX 2016',
#        '121 LX Limited', 'Zen', '207 Cab', 'CJ - 2', 'tercel',
#        'KSP90 Leather Seats', 'REVO DOUBLE CAB', 'Glory SUV Jeep',
#        'WagonR FX Safety', 'Panther', '3L AUTO VIGO CHAMP', '3 Option',
#        'DX wagon KE74', 'Revo Revolution', 'SCP90 1300CC', 'B12',
#        'Full Electric', '10_6144', 'VX', 'G Superior 2019', 'a',
#        'Luxury 2021', 'Maruti 800 2012', 'R 2', 'KSP90 Dark Blue',
#        'ksp 130 2016', 'HB 13', 'VTI-L TURBO AUS', 'Vogue 5.0Ltr 503 BHP',
#        'DAA.MK43S.SPACIA', 'x Grade 2008', 'Japanese Model',
#        'Roomy Turbo', 'Exclusive-Line plus', 'FB13', 'GS Sports',
#        'montero 2013 Diesel', '1.5 FEX', 'TX-150', 'twist', 'EG7',
#        'Hilux Double Cab', 'Kluger', 'city', 'X Grade 2007',
#        'FB14 Super Saloon', 'X G PACKAGE', 'manual', 'Anniversary',
#        'F EX G Superior', '1100', '2L Sport', 'VTI-L 7 SEATER', 'KB Cab',
#        'BS5V Wagon', 'GT Face Lift', 'Wagon 1983', 'Sunny B11',
#        'Company brand new', 'Trad', 'JADE BLACK', '1300L', 'BJ40 1983',
#        'EE97', 'Cortina', 'Axio WXB Anniversary', 'Diesel Unregistered',
#        'AT 150', '150 tx', 'roomy', 'fb14 1999', 'WildTrak',
#        'AMG Coupe Facelift', 'BJ5', 'Advance Premium Pack', '1996',
#        'GLS V76', 'A55 Mark 2 Farina', 'Picanto 2016', 'Austin',
#        'Honda Fit gp5', '5 Fwd', 'KE74', 'SPORTS', 'vagon', 'Califonia',
#        '1991', 'GE2', 'G102s', 'MK2.5', '4Th Generation', 'ke20', 'FA4TV',
#        'Suzuki Spacia', 'Toyota Carina', 'Outlowe', 'Ee91', 'KR5411',
# ...
#        'IO GDI 2000', 'Gt Line full options', 'Hybrid 4 Diesel',
#        'F 10/ Diesel', 'C Limited Highest Gr', 'M SPORT INDIVIDUAL',
#        'LX 141', 'Alpha (7 seater)', 'rocco', 'Nissan  FB 14',
#        'GT Turbo 2017', 'RX350', 'Honda Civic SR', 'G Superior 8Air Bags',
#        'Es1', 'Triptonic Auto', 'MK-2 38000KM', 'Vitz Edition 3 LED',
#        'Safety EDITION 02', 'Xeta EV2 GLX', 'Unregistered roomy',
#        '3.3 GL', 'White/ Brown', 'Laurel car', '580L Luxury', 'Facelfit',
#        'XDI270', 'GDI Pajero IO', 'Elephant Back Wagon',
#        'TOPPO AUTOMATIC', 'AMG REG', 'ALTO Sports', 'AMG Triming',
#        'BRANDNEW SEDAN CAR', 'SR/Turbo', 'Nickel Pack', 'Sygnus',
#        '260 (In Weeraketiya)', 'Scp 90', 'Ene Charge', 'NGX 10 GT BRUNO',
#        'Wagon R - Premium', 'White AMG C180', 'EX saloon splend',
#        'Nissan Ex saloon', '230 JM', 'DLA-GG2W', 'Most yellow',
#        'Discovery 5 3Litre', 'BMW 740Le M Sport', 'Y614X4 IRONMAN BUILD',
#        'Vogue Diesel', 'NL 40 Corsa', 'Tank Gs Safety', 'GT NX10',
#        'Gt Turbo 2 Tone', 'Audi A6 Hybrid TFSI', '2 GX 110', 'Sdrive 20D',
#        'Alto VXI', '150 VX Diesel', 'Aqua 2013 G Grade',
#        '2015 Pure Diesel', 'DX k72', 'Perl White', 'DX 72',
#        'Sylphy 1.5 Japan', 'Prius G Touring', 'Luxel alpha',
#        '2015 Fully Loaded', 'CC Fully Loaded', 'PHEV Premium G',
#        'Suzuki A-Star', 'GSuperier', 'TA-VZJ121W', 'TURBO RS',
#        'White V8 202', 'White E200 petrol', 'Active E', 'BMW 520i (E60)',
#        '2L Turbo', 'KGC10', 'HB 310', 'URJ202 ZX', 'JAPAN WAGONR FX',
#        '1500cc Japan', 'TI My Road', 'S High Spec', 'Auto F/O Exchange',
#        'Lecom', 'New Face 2018 Axio', 'Vigo Extra Cab', 'Sportero 2020',
#        '2010 3rd Gen', 'Power shutter', 'Safety 2017 AWD', '2wd/hybrid',
#        'SX 4WD Premium', 'Auto 4 wheels', 'GD8 Japan', 'Tata c lndica',
#        'Premio 240', '110 XE Saloon', 'Langley HN12',
#        '2018 Perl white Ed2', 'car Full options', 'DX wagon 74',
#        'MUGAN INFINITE', 'CHOGM', 'NGX 50,GT TURBO', 'Swift rs  turbo 20',
#        'Wagon R Sting Ray', 'N16 Super saloon', 'W123   200D',
#        'GT LIMITED EDITON', 'Bmw X5 M Sports', 'VXI Auto Sport', 'ZF-1',
#        'Magna  GK-XXXX', 'Singapore Taxi Model', 'Glory Van, Reg 2016',
#        'EX saloon', '95', 'VTI-L(Japan)', '1.8 Facelift', 'Fit Gp1',
#        'Urbon', 'XL (Safety Package)', 'Stingray X',
#        'J Style|First Owner', 'DIESEL KDJ150', 'EX PACKAGE SpecialED',
#        'Atos GLS Prime', '650 Japan', 'Hybrid X Grade',
#        'Toyota vitz 2017', 'Matrix 2005', 'PANDA CROSS 2012',
#        'Revo Double Cab', 'Exclusive package', 'sports car',
#        'Japan Auto 2-Door', 'Super Saloon Fb15', 'Fit Gp 5',
#        'Passo Moda Safety', 'Safty Edition 2', 'Red CLA200',
#        'Highway Star Safety', 'Fully Spec', 'C350e', '. B/Top',
#        'Sedan Europe Spec', 'AMG P. Plus Night E', 'Custom Z Turbo 2018',
#        'Custom 2018/', 'N16 GD', 'Swift Kei 2007', 'eagle eye view',
#        'CE106 Automatic ""GL""', 'Essence Uk', 'Tata Indigo cx 2011',
#        'Honda Vezel RS', 'elite', 'Koba', 'Full Loaded Sunroof', 'T5',
#        'G - B/New HV Battery', 'Premium G navi', 'AQUA G GRADE BLACK',
#        'low Mailage', 'Diesel 2012', '200 Tech Plus Pack', 'juke 2012',
#        'M Sport 2016', 'MZ UNREG.', 'Climber Auto Gear', 'FULL LEATHER',
#        'LXI First Owner', 'weel', '2018 Safety Model', '240G Petrol',
#        'japan Auto', 'Black Top/Body Kit', 'Premium Xtrail',
#        'KSP130 2019', '116i', 'Stingray 2014', 'LN 166 DOUBLE  CAB',
#        'Moda Full Option', 'LWB AGENT', '7SEATER', '(used)/',
#        'Sport  Cab', 'AUTO WHITE JAPAN', 'Sunny B 310', '..',
#        '2016 hybrid', 'WXB 2018 LIMITED', 'company maintained',
#        'HB 11 Extra', 'P90D', '4X4 Auto Diesel', 'Dual A/c', 'Sport.',
#        'REVOLUTION 4X4', 'CE108 Wagon Elephant', 'RS 16,000KM',
#        'Y33-Cedric-Brougham', 'TFSi S Line -', 'X2 M sports',
#        '4WD TRITON THAILAND', 'Orange Pack Gold', '1300 Highest Grade',
#        'Telcoline Double Cab', 'D22 Double cab', 'WXB Face Lift',
#        'sportage', 'Sunroof 5 Forward', 'N17, EX Saloon ', 'Suv Package',
#        'Yaris 1300 F/O Auto', '2007  2nd Owner', 'toyota vitz',
#        '1300cc Push Start', 's300 LWB', 'x 25', 'Ex 1St Owner', 'BROWN',
#        '121 - Black', 'Vigo Full option', '2 FULL OPTION',
#        'Box 1984 (13-XXXX)', 'Toyota 141', 'Jcb', 'Cab Lorry',
#        'S Line Sport Package', 'HR52 S-CRUZE-auto',
#        'S grade- 8 AB/Safety', 'GT Turbo NGX10 2wd', 'M Sport Shadow ED',
#        'tekna plus', 'Honda Grace 2016', '7 Seater 4x4',
#        'G GRADE LIMITED', 'VEZEL RS SENSING', 'Wagon Turbo',
#        '5 HSE Luxury Highest', 'DIESEL VX', 'SkyActive Petrol',
#        'Japan 650', 'RE2-4WD-sunroof', 'Urban Body (S)', 'Chevrolet',
#        '67000 KM', 'S Drive 18i X Line', 'LWB Comfort Plus SML',
#        'G Superior White', 'AUTO -1500 cc', 'X SUV', 'SV Diesel LWB 3.0',
#        'GX-L AUTOMATIC', 'Safe', 'TRJ120 TX', 'Super Saloon  N16',
#        'Automatic 2005', 'RXT 2018', 'V45 2003 07 SEATS',
#        '2016 ELECTRIC GATE', 'AMG High Spec', '3000CC Diesel',
#        'Straight-Petrol', '5000cc supercharged', 'M.function/P.start',
#        'S LED Light', 'Auto-Cup Holder', 'Countryman Cooper S',
#        'Auto (Passo)', 'Wagon EE102 Auto', 'Latio Auto', '2020 Rocco',
#        'EU14 Auto', 'Honda Civic ES8', 'Honda Accord 2014', 'Ce110 Auto',
#        '1.3cc', 'AZEO G Grade', 'Glx C11', 'VTIL Turbo 7 Seat', 'Trooper',
#        'Estillo', 'Cab Prado Rocco', 'HSE Diesel Only', 'ae91',
#        '2021.10.29', 'PHEV  ROCKFORD', '29 000 MILES 1 OWNER',
#        'X Hustler', 'Azeo G limited', 'CE Saloon 110', 'PASSO AUTO',
#        'S 580', '120 Limited 8 Airbag', 'Sunroof Limited',
#        'Smart Cab Thailand', 'V44 Turbo', 'TRJ150 TX DIESEL', 'Refina',
#        '4WD Sunroof', 'PICKUP', 'Jewela Edition 2',
#        '2nd Gen 2007 Limited', 'Luxury Limited', 'AK12 AUTO',
#        '8 AIR BAGS', 'S LED 8 Airbag', 'CK1 Efi Limited',
#        'Alto Japn X Grade', '2018 REG', 'Diesel V 3.0 D4D',
#        'TOYOTA PREMIO F EX', 'CJ1', 'Comfort Plus Maximum', 'Auto Diesel',
#        'super saloon auto', 'Face Lift Sunroof', 'E65 Full Option',
#        'CLO48 Turbo  4D56', 'Compressor manual', 'HB12 Auto',
#        'GT Turbo TRD Package', 'AMG Premium PCK', 'AMG line Package',
#        'S Line Quattro 2.0', '1 TO 12 FULLY LOADED', 'FB 15 2000',
#        'FZ COMPANY BRAND NEW', 'A3 S LINE F/LOADED', 'Nissan sunny B211',
#        'Celerio elegence ZXI', 'Rs Sensing F/loaded', 'REVO V',
#        'F EX Highest Package', 'Cab 4WD', 'EX Sensing Face Lift',
#        'RS Fully Loaded', 'Y12  Axis Autech', 'GS450h', '530i M-Sport',
#        'HSE HIGHEST SPEC', 'EX Tech Pack Sedan', 'Sport Brown Leather',
#        'PANDA GEELY 1L AUTO', 'MIRAGE  PUSH START', 'TURBO J Style',
#        'DFSK IAUTO  I-Auto', 'Auto EL40', 'N16 /N17 Body', 'A140 J',
#        '300-', 'R11 Refina', 'RS SAFETY', 'SAFETY P/DOORS',
#        'Lancer Cs 5A', '4 Gear', 'JEWELA SAFETY ED 2', 'Spacia Z Custom',
#        'LED ED3 PUSH', 'LED PUSH S/STOP', 'Z Leather Limited',
#        'REGALIA Gx100', 'lx', '110 puma 2.4', 'Newshell', 'EX 17',
#        'Dual Multifunct', 'Sahara V8 200', 'Honda civic ek3 2000',
#        'Blue Tec pack', 'N16 ex saloon', 'OLM', 'LC105 1 Owner',
#        'Blue tech', 'Toyota Carina 212', 'Sport condition', 'AT170 SE',
#        'GT Turbo NGX 10', '202 V8 Full Spec', '13000km L',
#        'Aqua G LIMITED', 'hybrid body', 'modulo body kit',
#        'G LIMITED PREMIUM', 'Safety Push START', 'EX 39,342 km',
#        '25542 km Mileage', 'x drive 20d', 'Z  IVORY PACKAGE',
#        'PHV G premium Plus', '1.3L', '4WHEEL CAB', 'CHR BLACK TOP 2WD',
#        '2WD G TURBO', 'N17 1600cc Manual', 'TZ Auto', 'AVY',
#        'Es X Limited', 'HSE P300 High Spec', 'Toyota RUSH', 'Terios',
#        'orange Pakege', 'Ze2', 'Chrome Package Auto', 'GLE', 'Z orange',
#        'AMG DIESEL', 'TSFI 2018', 'BOON SAFETY', '2.5 L',
#        'Wagon UNREGISTER', 'anniversary', 'Hybrid (G Grade)',
#        'VTI-LX Five Seater', 'BMW 318i M Sport', 'Center Antana',
#        'Lancer EX', 'Prius 3rd G Touring', 'TXL 7 Diesel',
#        'Renault KWID RXT', 'toyota corolla 1986', 'M Sport 40e -F15',
#        'safety edition 3', 'Mercedes Benz 200D', 'Sportage Diesel',
#        '28436 KM', 'axio X Grade 2014', 'Daihatsu Mira 2017',
#        'GP5 S Grade(2016REG)', 'Mini Cooper 1.3EFI', 'Axio x',
#        'M-Sport LongWheel', '2014 Petrol', 'Stingray 2018 Safety',
#        'emergency breaking p', 'HB12 trad sunny', 'N L 30',
#        'M-Sport Plus-9000km', '2016 4th Gen', 'V6 (Brand New)',
#        'Tube Light', 'Eis', 'Carina GT', 'peugeot 404', 'Vigo...SUV',
#        'ð\x9f\x92¦ à·\x83à·\x94à¶´à·\x92à¶»à·\x92à¶¸ à¶\xadà¶\xadà·\x8aà·\x80à¶ºà·\x9a ð\x9f\x92¦',
#        'AB11', 'Sport GLS', 'gp1', 'N16 FULL OPTION',
#        'MSPORT 725Ld M Sport', 'G Premium Sunroof', 'MODELLISTA',
#        'ZE3 navi premium', 'super saloon N17', 'EX Master Japan',
#        'WHITE - RS', 'M - GRAND', 'Ze3 fully loaded',
#        'X Limited 8 AirBags', 'Basic edition 2016', 'GP 5 Push Start',
#        'METAL BRONZE', 'XG- 30', '1.6L BRANDNEW', 'm sport sky lounge',
#        'Y12  Auto', 'diesel fully loaded', 'AirBag',
#        'GT turbo boostimpuls', 'S Limited 2012', 'GT Turbo F/Loaded',
#        '(AMG LINE)', 'edition 2 2019', '7 seater sunroof', 'Roomy 1300CC',
#        'G grade 7 Seater', 'TSi', 'A6 35TFSI', 'i-AUTO / SUV',
#        'EX Saloon FB15', 'CS2 HH-xxx F/O Auto', 'KG-xxxF/O Auto',
#        'S/Edition', 'MZ Edition', 'Custom Turbo New', '3rd Gen S grade',
#        'Safty 4 Way Cam', '1.8cc', '1.2 4 Door', 'S Unregister',
#        'Hyunda accent R', 'ES1 JAPAN', 'JAPAN TOYOTA',
#        '2018 Z LED Facelift', 'Terios jeep', 'G Turning Solar',
#        'Auto 1000cc', '3 option co.maintaid', 'ssrx', 'Diesel HSC Sport',
#        'G Leather', 'DAA-RUS', 'Black Brand New', 'G Limited Petrol',
#        'SR UK', 'N 17 Ex Saloon', 'eon', 'Navi 5 Turbo', '605 SR',
#        'B13 EX SALOON', 'Overland Trim', 'FD4 1.6l', '4000cc',
#        'Navi primium', 'Smart Cab 3000cc', 'k 11 Auto',
#        '121 DICKY LIGHTS', 'Range Rover EVOQUE', 'Rs sensoning',
#        'Mazda Rx8', 'Prius S', 'sport 2011', 'JEEP', '5 S 3.0L', 'Double',
#        'Lancer Ex', '2.0L FaceLift', 'Silver Brand New',
#        'Toyota Belta 2008', 'Ex Techpack', 'V8 Fully Loaded',
#        'SPORTS RXT EXCHANGE', 'SPORTS Warranty Ex', 'Alion 260',
#        'Alto 2014', 'XDI2700', '800 cc', 'V6 Brand',
#        'Comp .regi.2019.Dies', 'GP5 (L-Grade)', 'Wagon R Fx - 2016',
#        'Zen 1998', '4WD Auto', 'NISSAN N17 2006', 'Honda gp5', 'AMBIENTE',
#        'Petrol Jeep', 'Aqua 2014', 'Vigo Smart', 'V93', 'charade G10',
#        '2013 Limited beige', 'G 2013 sun roof', '2015 Z CAG', 'Auto VXI',
#        'CIVIC EX VTEC CVT', 'SERA SPORT CAR E.F I', 'S Line RS4 Kit',
#        'Black ED', 'SX Turbo Two-Tone', 'Edition ii', 'Vito 116 CDI',
#        'VTIL  7seater', '7 Seater V-TIL', 'CE96  DX Wagon', 'Eg8',
#        'CE 110 Sprinter', 'Range Rover Evoque', 'CRDI 4wd',
#        'AUTO 2003 AIRBAGS', 'Wxb G grade', 'KE20 Classic',
#        'Box 80 Series', 'GLX Xeta', 'Aventura Double Cab',
#        'mazda 323 BJ5P', '500', 'Audi Q3 2.0L Turbo', '2011 AMG SPORT',
#        'AB', 'DBA -ZC713', 'KGC 10', 'Swift saloon', 'YU12', 'Custam',
#        'K-10 Silver', 'Nissan March K11', 'wagon r stingray',
#        'CE 110 / CE 11X', 'premium plus 2019', 'Edrive M Sport', 'TP12',
#        'ZXI MODEL', 'HSE ONLY Diesel', 'RED EP-91', 'A - Star',
#        '121 -Silver-X-GRADE', 'Honda Fit shuttle', 'XLT (4x4)',
#        'X -Grade', 'xDrive 20d', 'TRAED  SUNNY', 'Toyota premio 2012',
#        'WXB Highest grade', 'jeep model', 'Z-ORANGE', 'MAJESTA G grade',
#        'FB15 Anniversary', 'X G grade,', 'Harrier G Limited', 'M200XDi',
#        'ALTO', 'Sportage 4WD', 'Invincible LC5 3.0', 'Boost Impulse',
#        'Ice Pack Diesel VX', 'xurban', 'AWD Automatic',
#        'S LINE TFSI Package', '1.0 LC', 'S Grade PUSH START', 'Hybrid RS',
#        'TMD PUMA2.2', 'Impreza Hybrid', 'l400 space gear 4wd',
#        'Box LC76 CHOGM', 'Austin mini cooper', 'rs sensing', '30 TFSI',
#        'Elantra', 'FZ 1st Owner', 'Ex Vtec Cvt - 2018', 'ES8 AUTO-JAPAN',
#        'J-44', 'TRJ 150 TX L', 'M Performance', 'Auto RXT',
#        'S LINE TFSI Sport', 'TFIS Spec', 'D21 4WD', 'Bluebird B17',
#        'F-EX', 'SS', '800 Company Sports', 'discovery 4 SE',
#        'Primium Plus', 'Aventura Limited', 'EP 71 Corolla', '9 Hawk Eye',
#        'FD 3 UK Edition', 'Mistubishi Colt', 'EP-91',
#        '18-xxF/ O Manual EFi', 'Black Pearl', '320i',
#        'Giulietta 940 Sports', 'DEISEL TURBO', 'Tata Nano Car',
#        'AK12 2002', 'k30 1974', '2 nd Edition', '2004 EFI', 'Ce20',
#        'Land Cruiser Cygnus', 'Auto Hybrid', 'AMG Advance Prmeium',
#        'Station Wagon 1989', 'Pushstart', 'Msport Manual 2006/',
#        'DX WAGON KE 72', 'BAIC X25', '8 Seater Diesel',
#        'PHEV Autobiography', 'Autobigraphy 3Liter', 'TX Limited Petrol',
#        'SD4 HSE Diesel', 'RVSI-2 Brand New', 'Sport DID',
#        'Petrol 7 seats', 'Facelift Model RS', 'CRDi AWD', 'cortina mk4',
#        'PRIUS 30', '5 Speed R.viper', 'SHOGUN V6', 'Audi Q3 1.4L 30 TFSI',
#        'Audi A5 1.4L 30 TFSI', 'Cabriolet/AMG', 'Home used',
#        'Fully loaded Diesel', 'full option aout', 'Exclusive  Line',
#        '141 2007', 'CUSTOM G', 'AVANTGARDE DIESEL', 'S Corss', 'BMW 740e',
#        'V8 ZX Anniversary', 'Edition 110', 'Prado 150 Trj 6FWD',
#        'Dx Wagon KE 74', 'XT set option', 'Europe Turbo',
#        'Palathsabha - 4D56', 'E drive', 'Pleo Japan', 'Audi A5',
#        '3000CC EXECUTIVE', 'CBC', 'GC8', 'maruti 2007',
#        'Top of the Range', '2WD Hybrid', 'S 2010', 'Sky-Actice 2017',
#        'B211 1976', '350 Executive', 'SUZUKI ALTO K10 VXi',
#        'HONDA GRACE EX 2016', 'AE110 SE SALOON G', 'diesel V8 VX',
#        'Ex Tech Pack Sedan', 'X 4 WAY', 'Royal Crown', 'V8 2017',
#        'Toyota 3rd Gen', 'K3', 'KSP 130 Safety', 'W201', 'RS Hsensing',
#        'Sorento 7 Seater', 'Navara Aventura', 'GSS', 'Safety Packages',
#        'Axio 2015', 'S Touring Selection', 'Toyota Voxy 2014',
#        'Aerosport', 'Yellow', '2 Liter Twin Turbo', 'AMG Premier Plus',
#        'KB-', 'Revolution Rocco', 'Vios 2006', 'ex turbo', 'M1',
#        'Tubelight', 'Magna Advance v6', 'Y61 GL', 'AMG Bluetec',
#        'Hyundai Accent 2007', '121 Xli', 'Premio FEX', 'VX Deisel',
#        'AUTO Diesel Turbo', '800EFI', 'AMIEZT', 'S Touring Model',
#        'Stingery', 'LDA-GDJ151W PRADO', 'Z Ivory Pack', '305',
#        'premio G supirior', 'Wagen R Premium 2018', 'Evolution Face GLS',
#        'fb15ex', 'Track Sunny', 'Glory i Auto', 'SG',
#        'RS SENSING Face Lift', 'Japanese edition', 'Electric Unregister',
#        'KE74- Dx wagon', '2007 Toyota Vitz', 'DEISEL WAGON',
#        'Highest G - Turbo', 'EX Saloon 2006', 'Q2 TFSI', 'Maruti 2011',
#        'Freelander 2 SD4 GS', 'Roomy Unregistered', 'Honda Fit GD1',
#        'Vitara SZ-T', 'Suzuki Japan Alto', 'Alto 800 Lxi',
#        'F EX  G Superior CBC', '1-12 Full Options', 'Nissan Sylphy G11',
#        'MINI LORRY', 'Petrol Sunroof', 'New Generation', 'Box Brand New',
#        'White    S-Touring', 'Toyota Vitz F Grade', 'DBA-KSP130 VITZ',
#        'Alto LXI 2015', 'Suzuki estilo zen', '4WD D/CAB',
#        'GP 2 Navi Premium', 'SP/ HZ 6073', 'Premium Avantgarde', 'Scp90',
#        'Audi A3', 'Sports Auto', 'FB13 (Doctor Sunny)', 'GM4 EX Grade',
#        'Toyota Roomy 2019', 'DBA - NGX50', 'Matt Paint', 'Asx',
#        'Diesel auto', 'Passo 2017', 'Vitz Push Start', 'L200 Animal',
#        'Sunroof G Premium', 'GT KPS90', 'AMG PREMIUM  PLUS',
#        '2WD Highest Grade', '2 SD 4 GS', 'Honda MASTERPEICE',
#        'Phev Fully Option', 'NKE165 G', 'Vxi 2014', 'LC',
#        'A5 2018 Highest Spec', 'NGX10 2W Turbo', '2017 RS Sensing',
#        'VXI Face Lift', 'CRV VTI-L Turbo', 'EX Stylish Edition',
#        'Honda Orange Package', 'Face Lift 1.8', 'Virtual Cockpit',
#        'S350 2007', 'Ex full option', 'FX Safty', 'FD1 S',
#        'DE3FS Hatchback', '3rd Gen 2012', 'RS  TURBO', 'Honda GP4 RS',
#        'Civic Sedan', 'AQUA S LIMITED', '(FX) GRADE, 2016',
#        'DAA-RU3, Ivory Ed.', 'Scp10', 'Grade 2016'], dtype=object)

# %%
len(carset['Brand'].unique())
# Out:
# 60

# %%
type(carset['Edition'].unique())
# Out:
# numpy.ndarray

# %%
print(carset['Edition'].unique())
# Out:
# ['Limited' 'Fully Loaded' 'GT New Face 2wd' 'Toyato' 'prado'
#  'Suzuki Alto Japan' 'SUV' 'FM Safety Edition 2' '2014' 'Safety'
#  'NGX 50 GT Turbo' 'GLD' '260' 'Premium' 'G Grade' 'GP1' 'BLUETEC HYBRID'
#  '2010' '5 Hse' 'Box' '110 Puma 2.4' 'WXB 2019' 'E60 M SPORT' 'Stingray'
#  'Alto 2015' 'STINGRAY' 'TURBO' 'S Grade' 'TX L' 'LXI INDIAN'
#  'Ivory Package Z 2016' 'AUTO KOREA' 'G Grade 7 Seater' '(used)'
#  'G Grade 2014' '2010 1st owner' 'safety' 'Audi' 'Sensing' 'Raize Z Grade'
#  'DIMO' 'Auto 2003 japan' 'N 17 1600cc manual' 'TX Limited' '2017'
#  'M-Sport' 'Lexus Nx300h' 'Diesel LWB' 'LongWheel' 'M-Sport Plus'
#  'Cabriolet' 'SVO P400e' 'Sorento 2014' 'High Spec' 'F10' 'Si4 Non-hybrid'
#  '2020 New Face lift' 'P400e' '5000cc Supercharged' 'TURBO CUSTOM 2018'
#  'Z Orange Gold' 'EX' 'Active-line' 'Audi A3 TFSI Sedan'
#  'Micro Geely Panda' 'EX PACK' 'GLX' 'Rocco B5' '6 SPEED' 'Japan' 'GXR'
#  'GT line' 'LXI' 'CRV Masterpiece 2020' 'Mitsubishi' 'Brand New' '1989'
#  'SR Turbo' 'Turbo Safety' 'ASX' 'Diesel' 'Mercedes Benz' '2013 3 option'
#  'Original M Sport' 'Full option' '2015' 'F Grade' 'Kompesaro'
#  '120 Diesel' 'G SUPERIOR' '3rd generation' 'Civic FD3' '-' 'Lancer cb2A'
#  'DGA/HA368 Alto' '240' 'Avantgarde' '270 XDI' 'KSP130' 'S-BMD21'
#  'G sport gs' '1st Owner' '800' 'Fully loaded' 'Japan (Auto)'
#  'Helly Hansen 4WD' 'Higest Grade cab' 'sport 2013' 'original Push Start'
#  'Automatic' 'WXB DAA-NKE165' '5th Generation' '2012' 'V2' 'Premium Sport'
#  'Champ 2015' 'Toyota Hilux Surf' 'Micro' 'Vogue P400e' 'Ex Turbo 1.0'
#  'GP5 L' 'Ex 2014' '2nd Generation' 'C-Hr Gt Gx50' 'Toyota'
#  'Dual Purpose Cab' 'Center' 'W30' 'Majesta Luxury' '12000KMs'
#  'Premium Plus' 'Blue' 'T30 2004' 'X G Grade' 'wagon GL' 'Honda'
#  'GS Custom' 'Trim' 'Toyota 141( 1.6Auto)' 'G Superior - 2011'
#  'Honda Fit Gp1' 'V98' 'b210' 'WXB Anniveary' 'japan'
#  '2018 AMG Primum plus' 'S Touring' 'B11' 'SPORTS RXT Exchange'
#  'No edition' 'EK Wagon 2017' 'J Style' 'Cruze' 'Fb15 Auto Exchange'
#  'Vezel' 'FB14 (Doctor Sunny)' 'COMPANY BRAND NEW' 'G Superior' 'Gt'
#  'Bajaj Qute' 'M SPORT' 'TX' 'G' '2018' 'SUNROOF' '4' 'FB 13'
#  'FB 15 Super Saloon' 'Mirage GP5' 'Highest spec' 'TXL' 'HEAD UP DISPLAY'
#  '518i' 'Ex Sedan Tech 2018' '5R Vtech' 'Safety Edition 2' 'Phev Rockford'
#  'Montero sport' 'E Four' 'G-Limited' 'FX Hybrid' 'AZEO'
#  'Land Cruiser Prado' 'PETROL 2011 REG' '1.3 AUTO FULL OPT' 'Motor car'
#  'Sensing LED' 'Masterpiece' 'Alto Car' 'WXB Safety' '29K MILES 1ST OWNER'
#  'ESCUDO' 'eprise' 'Indica' 'GT Turbo NGX10' 'Sport' 'tata' 'GT Turbo'
#  'jeep 4Ã\x974' 'Noah' 'GP 5 S' 'Impreza' 'SLINE VOPRUNG'
#  'ZX V8 Bruno Cross' 'SEDAN EX TECH PACK' 'White CLA 200' '2004' 'GP 1'
#  'Suzuki' 'Limited Edition' 'S Led' 'Z Grade' 'Roomy Safety 2020' '2019'
#  'FX' 'Metallic Copper' 'S Line 4 Kitted' 'Bluetech Diesel'
#  'G / Chrome Grill' 'Diesel 1-20 CRDI' 'altoK11 Auto' 'B-15' 'Prado 150'
#  'Orange Package' 'TX 150 Diesel' 'Sportback' 'Hybrid' 'AWD'
#  'R Stingray 2018' 'Luxury Line' 'Long Wheel' 'V8 ZX 202' 'T156' 'G Revo'
#  'GP5' '1.5' 'Full Spec' 'S Line Anni Edition' 'KSP 130' 'Unregisterd'
#  'AE110 L GRADE AUTO' 'Dx Wagon' 'i Auto' 'SYLPHY FG10 AUTO'
#  'Diesel 3.2 V78W' 'S Line' 'Turbo' 'V8' 'Unregistered' 'Car'
#  'Montero 2007' 'Discovery 4' 'G superior' 'Xdrive' 'NGX10' 'WXB'
#  'Autobiography' 'LWB Autobiography' 'no' 'SX Turbo' 'SLINE FULL SPEC'
#  'K 10' '260 G Grade' 'Single CAB' 'AZEO Model' 'GLS' 'Safety edition'
#  'Manual' 'Cygnus V8 LX470' 'GX' 'ZE 2 Auto Hybrid' '141' 'K11' '2005'
#  'X1' '2018 NEW FACE AXIO' '110' 'BJ5P' 'Frontier' 'custom' 'Auto Japan'
#  'AUTO' 'B14, EX Saloon' '1981' 'Xurban' 'car' 'PHV Premium Plus'
#  'Box LC76' 'GT NGX50 Two Tone' 's-grade' 'Highest Spec G Plus' 'GP1 2014'
#  'Honda fit GP1 2013' 'Toyota Axio Hybrid' 'HSE Urban Diesel' 'V-TIL'
#  'AMG PREMIUM PLUS' 'Edition 2' 'FACELIFT' 'FX Safety Package'
#  '2012 Fully Loaded' 'Xpander Cross' '5 S 3000cc Diesel' 'TFSI S-Line'
#  '2002/1.8T' '8 Airbags' 'FZ 2014' 'Axio Hybrid X Grade'
#  'super saloon N16' 'Montero V6' 'Ritz BXI' 'Limited V8' '2016' 'V46'
#  'Kia' 'Prado 95 Diesel 2002' 'Axio X Limited 2015' 'ZVW30' 'Vogue SE'
#  'Auto' 'SsanYong' 'Edition 3' 'GLS V6' '111' 'CE110, XE Saloon'
#  'Sedan TECH 1500cc' 'Stingray ..' 'Rocco' 'Max Full Option'
#  'GP 4  Hybrid' 'AMG Premium Plus' 'LC105' 'DOUBLE CAB 4WHEEL' 'GP5 S'
#  'V6 Elegance W211' 'Dolphin Grand cabin' 'Megane' 'e AMG Premium +'
#  'S Drive Diesel' 'Sr5' 'Push Start' 'N17  EX Saloon' 'WXB Package' 'B310'
#  'HSE Limited Edition' 'G sport' '4 Diesel' '2006 New Body' '2000'
#  'EX Package' '2013 Beige Interior' 'G-Superior' 'Full Option japan'
#  'B 11' 'Nissan Trad Sunny' 'WXB-Facelift' 'Non Hybrid' 'Panda' 'Black'
#  '5008 GT' 'G Premium F/ Loaded' 'GT NGX50' 'Edition III' 'GT TURBO'
#  'Allure 2019' 'Custom Z Turbo' 'S Limited' 'Custom XS' 'Sports Japan'
#  'Safety Package' 'PHEV' '2013' 'Custom Turbo' 'Ex Tech Sedan' 'MANUAL'
#  'Invincible Auto' 'Elegance' 'Toyota Vitz 2018' 'Long wheelbase'
#  '3.0 D4D V Grade' 'Ex Saloon' 'Voxy' 'X Grade' 'Stonic Highest Grade'
#  'BLACK TOP' 'TRJ 150' '318i Luxury Line' 'M Sport Sunroof' 'Discovery'
#  'S Line Fully Loaded' 'CROSA' 'Prius 30 G' 'GT Line' 'Zs' '1.3CC'
#  'Wagon Car' 'Custom X' 'Highway Star Premium' 'Beetle AK 12' 'NZT 260'
#  'Prado 120' 'J STYLE' 'EX Stylish edition' 'Ex' 'AZE0' '120' 'Land Rover'
#  'Brilliant Style' 'SPORT HSE DIESEL' 'EX Grade' '121'
#  'X5 M Sport Full Spec' 'Custom Z' 'E300 Amg line' 'Exceed' 'GT  NGX10'
#  'V6 Jeep' 'MiCRO GEELY Mark ii' 'VX 101' 'SPORT' 'N17' 'B5 Rocco'
#  'B12 1986' 'EX Turbo' 'Mg' 'Turbo 4 Way Cam' 'Honda Sedan' 'New Face'
#  'Highest Grade' 'Nissan' '2.0 VVT' 'HSE' 'BJ 43' 'COMPANY WARRANTY'
#  '141 Auto' 'Station Wagon' 'Latio 2016' 'TX-L' 'Revo Rocco'
#  '2012 Face Lift' 'M Sport With SUNROOF' 'X Urban' 'GP 7'
#  'F Safety Edition II' 'FZ Safety (REG-2018)' 'FD 4 - 1.6 I-VTEC'
#  '(Titanium)' 'GP5 Cruise Control' 'TWIST' 'diesel 7 seat' 'Single Cab'
#  'Tata Indigo 2006' 'Mazda' 'GT' 'Sunlight Copper' 'C11' 'Platinum'
#  'BLACK' 'White' 'GP5 L 13000km s' '2014 reg non hybrid'
#  'Premium AMW warranty' 'G PREMIUM PLUS PHEV' '5 HSE LuXury Package' 'K10'
#  'Z Gold 2014' 'SWB Vogue' 'LWB Comfort Plus F/L' 'P300 R-Dynamic HSE'
#  'Diesel SV LWB' 'Land Cruiser Double' 'HSE 2.0' 'V8 VX Diesel' '7 Seater'
#  'VTIL Turbo 7 Seat ER' 'AMG Premium Package' 'LWB SML FrontierP400'
#  'Belta Pearl White' 'Original M SPORT Plu' 'L Hybrid LWB Highest'
#  'TRJ150 TX Diesel' 'DIESEL 2.0 SML' 'V DIESEL 3.0 7 Seate'
#  'nissan sunny b310' 'M Sport' 'Comfort Plus' 'GT Turbo 2 Tone'
#  'G Revo Revolution' 'AMG Premium LIne' 'AMG Package' 'Y11'
#  'Quattro 2.0 S Line' 'AE80' 'G-Touring' 'P100d' '6 Speaker' 'S limited'
#  'Gray' 'G grade' '2018 Sefty Package' '1.3 EFI AUTO' 'G Grade Push Start'
#  'ILS - AMG' '1.0 Automatic' 'flat light' 'G Limited' 'Safety Edition'
#  'G Custom J Style' 'Daihatsu Mira 2018' 'FB15' 'Honda civic ES8'
#  'Lexus Rx300' 'KE 20' 'Push Start 4 Way Cam' 'Intercooler'
#  'DAA-NHFIO Aqua' 'Japan Alto' 'Elite' '54H' 'AE 80' '2011' 'ZS'
#  'Z Orange 2014' 'Vista' 'Full Option' 'fate light' 'Toyota Roomy Gs'
#  '128' 'DBA- KSP 130' 'Corolla 141 1 st Onr' 'Pajero IO' 'A4' 'FB14' 'X25'
#  'EP 92' 'COROLLA 110' 'Outlander' 'CUSTOM' 'Fully Loaded Sunroof'
#  '110 D240' 'Center Spare Wheel' 'AMG' '3 Options Model' 'AMG FULL SPEC'
#  '2000 Cc Quattro' 'PHEV 2014/16' 'LWB AMG' 'TFSi Sport' 'Gp1'
#  'Premium Package' 'DBA-NGX50' 'Corolla' '2009' 'Indica v2' 'GP-5 S GRADE'
#  'S- Grade' 'BMW' '3rd Generation' 'M SPORT FULL SPEC' 'Alto Sport 2011'
#  'Unregistered WXB' '4x4 Diesel' 'Sunroof Fully Loaded' 'HIGH SPEC'
#  'Smart' 'Z Orange package' 'Hyundai Stellar' 'P300' 'FB 14' 'Custom'
#  'SB14 SUPER SALOON' 'S-LINE FULL SPEC' 'VVTI Japan Auto' 'GD 1'
#  'Alpha Sport' 'HSE SPECIAL PAINT' '120 TX' '2002' 'xDrive40e Msport'
#  'Sensing 2019' 'Glory' 'TZ G' 'FB15 EX SALOON' 'fz' 'mini cooper' 'S350'
#  'Hilux' '23,661 Km X Limited' 'AT150' 'Crossroad' 'Lexus' 'Glory TDI'
#  'GT Custom Turbo' 'Toyota premio' 'Wagon R FZ' 'MX 7' '1984'
#  '3rd S Grade' 'Vx Limited' 'Vigo smart cab' 'NGX-50 GT' 'Low Mileage'
#  '1000' 'EX Fully Loaded 2016' 'Mode Premier' 'Daihatsu Premium'
#  'Prado TRJ150' 'PHEV G Premium 2015' 'MZ Highest' 'GP5 L Grade'
#  'vigo champ' 'FULL OPTION' 'Center Antena' 'S' 'Hatchback'
#  '2016 Facelift Model' 'GM4' 'J style' 'LC 1.0' '2007' 'VIGO DOUBLE CAB'
#  'Hiace LH 30' 'Eprise' 'ES 8' 'executive' '323' 'avenchura'
#  'Autobiography SWB' 'Mira' 'PLEO G Grade' 'G Limited 3.0L'
#  'TUCSON 4 WHEEL' 'Face Lift S' 'LWB Highest Spec' 'NGX 10'
#  'Premium+/Amg Line' 'SDrive18i' 'unlimited edition' 'Luxury Car'
#  'GP5 Hybrid 2015' 'G Superior 260' 'Sky Active Luxury' 'URBAN'
#  'GP5 SAFETY PACKAGE' 'Closed AA435' 'Hkk' 'N16 AUTO JAPAN' 'FB15 AUTO'
#  'AE110 AUTO' 'Y61' 'N17 SUPER SALOON' 'Honda fit gp1' 'S Drive 18i'
#  'Land Cruiser Sahara' 'wagon 106' 'EE102 AUTO' 'Auto 2002' 'Auto 2011'
#  '2013 S GRADE' '2012 S GRADE' 'Daihatsu' 'D21 Turbo Double Cab'
#  'TFS Double Cab' 'CBAJ200E' 'GP5 Hybrid ""S"" Grade' 'G Plus' 'Alto'
#  'D21 Double Cab' 'Suzuki Alto car' 'Japan Masterpiece' 'EX Saloon SB13'
#  'S Full Spec' 'Prefect' 'Cup Holder' 'S AGENT WARRANTY' 'Tech Pack Sedan'
#  '3.0 INVINCIBLE LC5' '1-20 Options' '2017 TFSI' 'DISEL AUTO JEEP'
#  'VX V8 DIESEL' '323 Wagon.' 'VX V8 ICE PACK' 'Diesel 4X4' '1.4 TFSI'
#  'LXI 800' 'â\x80\x9cVXâ\x80\x9d Diesel' '240G' 'Electric Mem Sets'
#  'S Limiterd' 'TZ 4.0 V6' '2015 VXI' 'Highway Star' 'M Sports'
#  'N17 Ex Saloon' '5 Forwad' 'Honda Vezel' 'TOYOTA ROCCO 2018' 'Face Lift'
#  'Bluebird EU14' 'VXI' 'L grade' 'CE 106' 'Super Exceed' 'XS Custom Turbo'
#  'AMG Diesel' 'Range Rover Rvoque' 'G Garde' 'Passo 2007'
#  'Ivory Pack 2015' 'I Auto' '260  G Grade 2011' 'KE20' 'Vx V8'
#  'S Grade GP5' 'G grade Safety' 'Honda CRV' 'Autobiography PHEV'
#  '2013 G Grade' 'fulloption' 'ZE2 2012' 'GLE 250d AMG Premi +' 'KSP90'
#  'AMW PREMIUM' 'G Grade 2015' 'Alto 800 2016' 'GT Turbo NGX-10'
#  'M Sport Fully Loaded' 'Limited Designo' 'Sports' 'Full Petrol'
#  'S Line Unregistered' 'VIGO SINGLE CAB' 'Double cab' 'Aqua 2012'
#  'ZX 2016 fully loaded' 'sunroof 7 seater' 'CLO48' 'NZT260'
#  'Suzuki Alto Lxi 2015' 'FB 15 Ex Saloon' 'JS' '121 G Grade' 'C160' 'GS'
#  'Toyota Prius 2013' 'AK12' 'Rush jeep' '260 G SUPERIOR F-EX' 'Hyundai'
#  'Alto 800' 'Diesel Fully Loaded' 'Roco' 'N16 Nissan' 'AE91' 'Reg 2017'
#  'Wagon R fZ' 'Land cruiser 120' 'XDrive 35i' 'K 11' 'Z Grade Gold Orange'
#  'Turbo VTI-l7' 'G Plus - NZT260' '2.0L Diesel' 'G Style Pack' 'Deisel'
#  '260 NZT' 'Prius s' 'GP2' '1978' 'Toyota 121' '4 X 4' 'Suzuki Alto' 'L'
#  'Austin A35' 'ZXI Elegance' 'Luxury Line 2015' 'Prefect 100e' 'VTI-L'
#  'Skyactive' 'sensing' 'saloon' '121 G' 'Nissan sunny b310'
#  'Toyota IST FL 2007' '110 TD5' 'Japanies' 'Model Duet'
#  'RU3 - Orange package' 'X URBAN Reg. 2017' 'N 16' 'Autech' 'ZE 2'
#  '3L AUTO' '3L.AUTO' 'KSP-130' 'X URBAN' 'outlander' 'pickup'
#  'Safety Package 2017' 'Z Great' 'Safety Edition 3' 'push start'
#  'Night Edition' 'SKY BLUE' 'Toyota Prado' 'MH 55S' 'LN166' 'S Grade 2012'
#  'Glory 580 L GRADE' 'G Grade (WXB)' 'LeGrand' 'Individual' 'vezel Z'
#  'Hilux Cab Sale' 'Premium Ezi' 'TURBO 2019' 'Saftey' 'Silver' 'FZ Safety'
#  'Immaculate' 'Turbo 2018' 'Jeep' '260 model' 'Aventura' '13'
#  'Toyota vitz safety' 'GT - UNREGISTERED' '4th Gen' 'MG ZS 2018'
#  'stringray' 'Swift 1.3 Japan' 'LN 107' 'CS1' 'japan subaru'
#  'Safty edition 01' '(Japan)' 'R FZ 2018' 'Latio' 'EX Tech Pack'
#  'N16 special editione' 'premium' 'SUV 4 x 4' 'roccoB5' 'R  2017'
#  'Grand Cherokee' 'EX Diesel' 'wagon DX' 'Nickel Package' 'RE4' 'sports'
#  'Diesel Turbo' 'ksp90' 'Vogue SWB AB 2018' 'G Grade 2016' 'Montero Sport'
#  'GS SPORTS' 'DBA-KSP 130' 'Saloon' 'ROCCO B5 LIMITED' 'DX' '2.5 Lt Turbo'
#  'S class 2015' 'Petrol' 'MSPORT' 'HSE Luxury' 'Full Option Auto' 'FD 3'
#  'Wagon R Fx' 'FB 14 EX SALOON' 'G Grade 2013' 'AMG Line' 'k10' 'L300s'
#  'Highest 2017' 'RU3' 'grace' 'Diesel Auto Push' 'NZE 121' 'petrol' 'VTiL'
#  'BWM' 'Toyota Dark Grey' 'MG ZS' 'Minor' 'ZE 3' 'Mirage Vitz Swift'
#  'AE 101 Uk Veion' 'Masterpiece Japan' 'AK 12' '4DR5 4WELL Jeep'
#  'Xtrail 2016 Hybrid' 'GP1 Hybrid FineStyle' 'AutobiographyLWB SML'
#  'Rexton - W' 'S Grade-(DAA-NHP10)' 'Eclipse Cross 4WD' 'LXI 2015'
#  'Z Gold 2014 (2015)' 'dayz' 'FZ' 'Alto LXI Model' 'ES 8 (Facelift)'
#  'DAA GP3' 'B5 Rocco 2018' 'VTI- S' 'TFSI' 'Suzuki Swift  2017' 'V Grade'
#  '2001' 'vezel z grade' 'Vxi' 'U Grade' 'G touring' 'AmG line' 'S grade'
#  'Wagon Type' 'C11v' 'PHEV Sunroof' '2.0L TFSI S-TRONIC' 'Swift' 'LKI'
#  'VITZ GT 1300' 'SUNNY' 'PAJERO' 'VTEC' '100' '2016  brand new' 'kE72'
#  'Celerio' 'E FX' 'TX LIMITED' 'S LINE - SALOON' '8 Airbag Push Start'
#  'safty' 'GT Turbo 2019' 'night edition' 'Evoque' 'EX Pack' 'V8 DIESEL'
#  'BRUNO 2WD' 'Full options' '2003' 'MG ZS 7500km' 'Baic X25' 'Ti'
#  'ES8 JAPAN' 'KEY START SAFETY' 'CRV 2018' 'Box Prado'
#  'N16 Auto 1.5 Sylphy' 'ROCCO B5' 'GD1 2007' 'Full Option Petrol'
#  'H-MATIC' 'Z GRADE B/ INTERIOR' '2020' 'S MODEL' 'EX PACKAGE'
#  'S Limited Edition' '141 BRAND NEW' '4Ã\x974 Full Option' 'Raum' 'GLI'
#  'Z GRADE' 'WXB FULLY LOADED' 'Sportero' 'FZ PACKAGE' 'Custom Z Grade Ltd'
#  'WXB G Grade' 'RXT Full Option' 'SENSING' 'VXI New Model' '1 TO 12'
#  'F Grade Limited' 'Premio' 'Z Grade Orenge Pkg' 'Air Bag Model' 'Cygnus'
#  'TURBO 4WAY' '3rd gen S Grade' 'DX wagon' 'Lx' 'Freelander 2 TD4 GS'
#  'SAFETY EDITON 3' 'WXB G GRADE' 'G GRADE' 'ELEGANCE' 'AK12 K12'
#  'GT B/TOP FACE LIFT' 'DIESEL' 'N16' 'S LINE' 'G TURBO 4WD'
#  'EX SENSING FACE LIFT' '4TH GENERATION' 'PREMIUM PACKAGE'
#  'GT BLACK TOP 2WD' 'G TURBO' 'F EX PACKAGE' 'F EX' 'EX JAPAN MASTERPIECE'
#  'VTI-L AUSTRALIAN' 'VTI-LX 4WD' 'REVO V GRADE' 'CJ1 Auto' 'CJ1 AUTO'
#  'Push Dual Multifunct' 'CE100' 'HB12 EX Saloon' 'DFSK 580'
#  'Mint condition' 'highway star' 'ZE0' 'TD4' 'Safety Edition II'
#  'Mini Cooper' 'G Great 2016' 'Ke20' 'X Limited' 'kia' 'VXi' 'AK 13'
#  'Wagon R FX' 'Allion 260' 'Np 80' 'Grace Ex Limited' 'PHEV G Nevy'
#  '5 Series Petrol' 'March' 'CS 2' 'FB15 Ex Saloon' 'TOYOTA' 'M Sport Plus'
#  'GP5 S Grade' 'HRV Japan Auto' '5' 'Axio' 'Highway UNREGISTER' 'NGX50'
#  'Sorento 2015' 'Safety Push Start' 'GLS FULLY LOADED'
#  'SPORT ORIGINAL USA' 'Sports Edition' 'SMART KEY' 'GLI Special Edition'
#  'HB12 trad  Auto' 'Tan Interior' 'CLA 180 AMG CLA 45'
#  'Mercedes Benz C200' 'Prius C' 'Mini Car 2 Door' 'Z Full Leatger'
#  'GLS350d' 'Diesel TX' 'V6 3l Supercharger' 'lancer 5 FWD'
#  'Phev full Option' 'Msport' 'S touring' 'Safety unregistered' 'HZJ76'
#  'Aqua' 'Sportero 4D56 2017' 'Hachback' 'Pajero For Sale' 'TX150'
#  'Plug-in-Hybrid PHEV' 'Japan Full Option' 'FL Grade' 'Desal'
#  'Black (LED)' 'GT/ 4 Way Cameras' 'N16 super saloon' '7 seater auto'
#  'RX8' 'Viva Elite' 'JAPAN ALTO' 'G UNREGISTERED' 'VIGO CAB 4 WD'
#  'Revolution G grade' 'M SPORT ( ORIGINAL )' 'Lxi' 'G Super 260'
#  'Toyota vios' 'W212' 'G plus' 'LJ76' 'LJ150' '2008' 'Raptor' 'Tekna'
#  'CBC Safety' 'WXB G' 'Essenes' 'Toyota Corolla' '2005 FULL OPTIONS'
#  'Laser' 'Hatch Back' 'Orange Edition' 'Titanium' 'Aqua Xurban'
#  'FULL OPTIONS' 'ALTO 2018 SAFETY' 'Non Hybrid 2011' 'Japan 2010'
#  'ZE2 2011' 'Opel Asta' 'HYBRID - X LTD / W' 'AK - 12 { AUTO }'
#  'GP 1 BLACK' 'X GRADE PETROL - W' 'SENSING - C/RED' '#NAME?'
#  'NON SAFETY - W' 'PEARL WHITE' 'Roomy' 'Ee 107' 'G High Grade'
#  'Z Grade Orange Pack' 'DBA-NRE 160' 'Panda White 2017' '1979' 'L Grade'
#  'Tank' 'Panda 1300cc' 'SAFETY' 'K11 AUTO CUP HOLDER' 'MATIZ'
#  'BRAND NEW 580' 'U GRADE' 'morris mini cooper' 'M Sport Highest Spec'
#  'EX sensing' 'GT Unregisterd' 'Belta Pearl 2011' 'L400  SUV 4x4'
#  'Suzuki Celerio VXI' 'DBA -NZT260' 'HB12 Trad Sunny' 'Zc 71' 'Swist XTA'
#  'Serena' 'GRX' 'Push start' 'Gp5' 'CJ-1' 'Vitz' 'Lancer' 'Power-Up'
#  'Axio G grade' 'BMW 740le' 'SPORT 4WD Auto' 'MITSUBISHI ATTRAGE'
#  'LC5 - DIESEL' 'B 310' 'prado LC5' 'Celerio Vxi' 'xtrail 2016'
#  '2018 01st Owner' 'civic' 'x3 xdrive 20d' 'PUMA' 'Stigray safety'
#  '03 Options' 'INDIVIDUAL M SPORT' 'LXI Indian' '121 Auto 2006 Japan'
#  'MICRO PANDA' 'Outlaw 2007' 'Passo safety 2020' 'Sport 2.5 Diesel'
#  '2 GX100' 'Daihatsu Cab' 'Japan Auto 2005' 'Honda Grace 2016 EX' 'GT LED'
#  'Kei' 'Fz' 'Le Grand' 'Shadow edition' 'toyota mark 2'
#  'Allure  GT - Line' 'SE Saloon' '4Ã\x974 XLT AUTO' 'SE' 'Sport Diesel'
#  'ZRT260 G SUPERIOR' 'Diesel Com. Reg.2019' 'F Safety Package' '206'
#  'Harrier (Lexus)' 'aqua' '7 Seats' 'G Grade Chrome Shell' 'Wagon GL 1979'
#  'G Limited 2012' 'Panda Air bag' 'Toyota Aqua X Urban' 'Toyota Stalat'
#  'Air-Bag Model' 'EL53 1.5CC AUTO' 'DIESEL 4WD' 'S GRADE'
#  'Original Sports' 'Outlaw' 'KE70' 'PRADO 120' 'Suzuki wagon R FX'
#  'Consul' 'Standard Vanguard' 'Auto 2009' 'CHAMP' 'GP.5 L GRADE'
#  'Premium Edition' 'GP 5' 'G PLUS' 'Austin 8' 'good car'
#  'Montero Sport 2012' 'Gp5 Sport' 'T30' 'Vitz PUSH PEARL' 'Renault'
#  'A5 2018' 'Audi A8 LWB' 'GP5 Push Start' 'A60' 'GP5 2014' 'Acenta UK'
#  'xtrail petrol' 'LC5 2013' 'High way star' 'ZE2' '2.0TDi'
#  'Premium Plus AMG' 'TRJ150' 'V78' 'Blue Bird' 'Plugin Hybrid'
#  'Ac Allow Wheels' 'Bandit' 'discovery 4 se' 'Alpha' 'sport pure diesel'
#  'GP 2' 'SDrive20D' 'yellow' 'Safety - White' 'Orange Vitz'
#  'Grey EX Package' 'RED' 'White Primium plus' 'Sky Blue' 'HB12'
#  'GT NGX50 AWD' 'M Sport Full Option' 'CONVERTIBLE' 'Mystical Purple'
#  'BLUE' '4Ã\x974' '1400' '4WD' '3rd Gen' 'Red' 'AT170 Auto'
#  'AMG Premium 2015' 'Chrome Shell G Grade' 'L200' 'XLI (Manual gear)'
#  'Whait' 'Rg2017' 'Suv' 'Black Top' 'F/O' 'nissan' 'G Grade 2004'
#  'GP5 S Grade Highest' 'Lancer Box' '4*4 drive' 'N16 Super Saloon'
#  'Lancer wagon' 'Ford Cortina MK4' '1303' 'Flat Light 12' 'Navy Premium'
#  'silver' '260 G Superior' 'Ex Highest grade' '1985' 'WXB Limited Edition'
#  'SKYACTIV' 'RX-8' 'Jeep - military' 'N17/ N16 Face lift' 'lancer box'
#  'TI My road' 'Toyota Aqua G Grade' '6 Speake Edition 3' 'auto'
#  'Exclusive Line' 'Corolla AE80' 'X Limited 8 AIRBAGS' 'Grand' 'E60'
#  'black top' 'Elegance / Petrol' 'AT 192' '220d/ Non Hybrid' 'G Supirior'
#  'platz' 'B Class' 'FB 15' 'Mitsubishi Pajero IO' '7 Seater VTI-L'
#  'Quattro' 'Full Option 7 Seater' 'BJ5p' '(1-9)' 'Alto Turbo'
#  '2017 Safety' '260 G' 'full option' 'Edition' 'S gread'
#  'GP 5 Safety Package' 'yaris' 'Hybrid Full Option' 'honda civic'
#  '2016 Alto' 'PREMIO G SUPERIOR' 'Honda Grace 2015 EX' 'LEXUS'
#  'Sunroof Leather Seat' 'Diesel Brand New' 'AA 60' 'Lancer ex'
#  'WildTrak 3.2' 'Z grade' '4DR' 'Sunny' 'AMG Styling' 'Axia 2016 G Grade'
#  'Custom z Turbo' '330' 'Fully Loaded-Safety' 'Fielder WXB'
#  'Vouge Autobiagraphy' 'GP5 L Plus' 'Gp2' 'HB11' 'Grade  C' 'V6'
#  '220d/W212' 'B15' 'BMW i8 Protonic' '2 Grade' 'FB 15 EX Salon'
#  'Land Rover Defender' 'CE 90' 'Orange pack Z grade' 'XLT (4Ã\x974)'
#  'Vios New Face' '2018 Model' 'pajero' 'Premium Plus PHV' 'TX 150 / 6FWD'
#  'CUSTOM UNREGISTER' 'FB15 EX Saloon' 'Vigo' 'N17 (n16) Auto Gear'
#  'YOM-2007 FD3 HYBRID' 'LX 470 V8' 'GP1 Hybrid' 'WAGON UNREGISTER'
#  'PHEV 2014' 'NEW UNREGISTER' 'FD1' 'x UNREGISTER' 'GP5 S Mugen Package'
#  'SPACIA CUSTOM Z' 'Moda unregister' 'TURBO NON HYBRID' 'SAFETY PACKAGE'
#  '3.0L TURBO THAILAND' 'Alphard' 'Prado 150 Diesel TX' 'G Superior FEX'
#  'Diesel SunRoof Auto' 'NUBiRA' 'GP 5 F Grade' 'Rexton 2007'
#  'Advance Premium' 'GP 5  L' 'L Type' 'Honda fit S Grade' 'GLS Brand New'
#  'HSE Diesel Sport' 'Custem Z' 'Vezel Orange Pack' 'RXT' 'indian'
#  'Gp 5 2015' 'New Face Lift' 'Toyota Yaris' 'DBA.DE3FS' 'Gs Sport'
#  'Honda FIT GP5' 'CUSTOM Z' 'CHR' 'Swift Dzire VXI' 'S Line - 3 Kitted'
#  'Allion G' 'Ex Package' 'Vogue P400E' 'P400E' 'Z Highest Orange' 'Ford'
#  'DAA- GP5' 'AMG Line Premium' '350' 'Wagon' 'NZE121 G-grade'
#  'GP 1 Navi Premium' 'Agent Maintained' 'Sorento' '2800' 'LC 1.3' 'DFSK'
#  'G Grade 2012' 'Peugeot' 'Pajero' 'lancer tube light' 'Perodua'
#  'CHR NGX50 AWD' '2019 3rd Edition' 'Trad Sunny' 'Xs Custom'
#  'Nissan Patrol 160' 'Verossa' 'RX-300' 'Ritz VXi 2011' 'Toyota Vitz 2017'
#  'AMG PREMIUM +' 'Kyron 2009' 'Prado-G Frontier' 'Gen-2 2006'
#  'Orange Pack' 'SENSING F/LOADED' '141 corolla' 'W212 Avant Grade' '4DR 6'
#  'KIJANG' 'xeta' 'Hybrid 4WD' 'Toyota Prado GX' 'G grade Limited'
#  'Vigo Smart Cab' 'ZC71S' 'Revolution' 'G200S' 'RU4 (4WD)' '141 Lx'
#  'NISSAN' 'ABS' 'EX Tech Sedan' 'S350 AMG' 'Wagon R Stingray'
#  'Auto Full option' 'Smart Key' 'G+ Fully Loaded' 'Auto Full Option'
#  'C230 Sport' '2 Full Option' 'Suzuki alto' 'Moda Pack' 'GS CUSTOM'
#  'Grey C 200 Diesel' 'TFSI Turbo' 'Diesel Full Option' 'Package Suv'
#  'Nissan Patrol Y60' 'Z Orange Pack' 'TFSI Turbo (Diesel)' 'VTi Lx'
#  'ZE1 40KWH' '1300CC Full option' 'Axio Non-Hybrid' '1-10 options'
#  'CRDI 4x4' '2017  Sensing' 'V6 Turbo' 'Toyota corona ct190'
#  'Hybrid Crossover' 'Ex TechPack' 'Lucino' 'ESTIMA G' '2 Diesel' 'Cx'
#  '7 SEATER G GRADE' 'INTELIGENT' 'Auto - sunroof' 'auto-Modified'
#  'CALIFORNIA' 'AUTO 1.5' '2006' 'P.start/M.function'
#  'Edition 2 Safty Push' 'Japanese-Auto' 'F Safty' 'Z Orange' 'TSFI'
#  'GLA 180' '7 seater(RT-2) 2 Ltr' 'Vezel 2014' 'LongWheelbase Highes'
#  'GP5-S grade/safety' 'DIESEL Autobiography' 'GP1-intelligent key'
#  'Passo-Auto' 'S-Grade' 'EX Masterpiece' 'K 12' 'Toyota Vios'
#  'Intercooler Turbo2.8' '200XDI' 'G-plus (NZT-260)' 'V6 Fully Loaded'
#  'Autech Mode Premier' 'Japan Alto 2004' 'sport' 'Isuzu'
#  'Nissan Sunny 1980' 'Toppo BJ' 'Honda insight ZE2' 'F Safety Edition'
#  'EL 43' '3 rd generation' 'GLS 350d - 4 Matic' 'HL 2 UK' '2018 Safety'
#  'Outlander 2015' 'Safety 2017' 'Rocky' 'SU14' 'G, Limited' '/Turbo'
#  'Sylphy 1.5L' '2018 Silver' '1300cc Full Option' 'Vitz Multy Funtion'
#  '4x4 SUV - Diesel' 'landcruiser prado tx' 'P 400e Autobiography' 'k12'
#  'Edition 2 2018' 'V8 Supercharged' '2011 Option 1-12' 'EE103'
#  'Z CUSTOM TURBO' 'discovery 4' 'WXB CAU' 'V 3.0' 'DAA-NHP10' '(MINI)'
#  'FX 2017' 'Z Orange Package' 'S - Limited' 'GT Turbo NGX10 2WD' 'Fd3'
#  '2002 V6' 'XS' 'PETROL 4800cc' 'montero Sport' 'SPORTS Exchange'
#  '45 Blue' 'Doscovery 4S' 'Suzuki Alto 2018' 'Y10' 'F Ex 2019'
#  'W115 220D Classic' 'Trad Sunny B12' 'Gp 2' '725Ld M Sport' '300tdi'
#  '1977' 'CRDI 4X4' 'MG' 'M-sport High Spec' 'Three Wheeler Car'
#  'G Superior (FEX)' '2013 KX' 'AMG  (Barbus)' 'Lexus Harrier'
#  '725d M Sport' 'Ex Saloon N16' 'Stingray 2018' 'Bajaj  Qute'
#  '2012 Automatic' 'WPCAM' 'With Warranty' 'Wargon R' 'SF5 - STI M2'
#  '260 G-SUPERIOR' 'Axia G' 'Tx150' 'Axio G Grade' 'CX' 'MX7'
#  'Edition 2018' 'WagonR FZ' 'Toyota Vios Japan' '150 TX' 'Axela'
#  '2016 Safety Edition' 'wagon r fz safety' 'CE110 1997'
#  'Full safety Japan' 'AMG premium plus' 'Honda veezl' 'S Line Petrol'
#  'Trajet' 'KR - 6210' 'AE - 110' 'NTZ 260' 'JAC T6 double cab'
#  'Wagon 1984' 'X urban' 'LX' 'EG8' 'Z Grade Fully loaded'
#  'Non-Hybrid G grade' 'Toyota Axio WXB 2017' 'REVO Double Cab' 'Z Purple'
#  '141 LX' "Tom's G limited" 'Project car' 'Spacia 2018' 'wagon R' '1974'
#  'axio' '18_4029' 'Suzuki Celerio 2015' '.' 'DX Wagon'
#  'Toyota Corolla 141' 'EP 91' 'WFY11 Auto' 'CT190' 'i Light'
#  'Vitz 2018 Safety' 'SkyActiv' 'Cus Turbo UNREGISTER'
#  'SAFETY UNREGISTERED' 'Glx Saloon' 'J  style' 'toyota axio 2016'
#  'Toyota Belta 2010' 'Nissan march K11' '141 Lx 1.6' 'Autobiography P400'
#  'L Grade - 3rd Gen' 'cab' '141 GLI' 'Sportback 2018' 'E Unregistered'
#  'Lafesta 2011' 'R 2017' 'G - Grade' 'Colt' 'Mira car 2018' 'YOM'
#  'Galant (A52 Model)' 'Suzuki Alto 2015' 'Ex Package 2019'
#  'Xenon Light Truck' 'Ct141' 'Astrella' 'T32 Non-Hybrid' 'Phev' 'G super'
#  'AE 70' 'sunny B12' 'Mode Premier Autech' 'Perodua Bezza'
#  'Suzuki alto K10' 'Suzuki Wagon R 2015' 'Australian' 'G-Plus' 'X'
#  'mini cab' 'Double Cab' 'Cayenne S Turbo' '10th Anniveary'
#  'Autotech ModePremier' 'New Shape G Navi' 'toyota passo'
#  'EX with Sunroof' 'HSE Diesel' 'Toyota  vitz' 'G Fontier' '7'
#  'Unregistered (Raize)' 'SD4 Diesel Top-Spec' 'Sportback 1.0 TFSI'
#  'VXI Indian' 'S-Line' 'SR' 'Essence' 'Prius' 'R-Design Pro Diesel'
#  'ksp90 -2011' 'VX Diesel' 'Honda Grace EX' 'Japanese'
#  'E200 Cabriolet AMG' 'Suzuki Alto 2017' 'Suzuki Wagon R Fx'
#  'Suzuki Spacia 2018' '3rd Gen 2011' 'Honda Civic FD1 S' 'Mercedes'
#  'Premium 2016' 'FZ 2016/2017' '200 Premium Tech Pck' 'M5'
#  'SML Warranty LWB' 'Audi A6 S-line 2014' 'Lancer Box 5 FWD'
#  'Fully automatic' 'honda' 'land rover Defender' 'G L model' '1990'
#  'NHW 10 prius' 'Dba - Ksp130Vitz' 'SAFETY EDITION' '1986' 'Ex Grade'
#  'NGX 50' 'Corolla KE30' '3008 GT-Line SUV' 'Sorento 2013' 'Wagon R'
#  '4DR6' 'latio' '2 HSE' 'Custom 2 Auto Door' '2017 brand new'
#  'S UNREGISTERED' 'Black/Grey' 'Lucino sport' 'Turbo Edition' 'X-Grade'
#  'GS Sport' '3 Ltr Diesel' 'Axio X-Grade' 'GS CUSTOM MODELLIST'
#  'motor car' 'Custom UNREGISTERED' 'UNREGISTERED' 'REVO ROCCO B5' 'fb15'
#  'Aqua 2015' 'Rav4' 'Corolla 121' 'GS CUSTOM UNREGISTER'
#  'HANA PKG UNREGISTER' 'Spike' 'XS Custom' 'U-VA' 'AMG premium'
#  'Nissan HB11' 'G-Grade' 'M-Sport Edition' 'R-Dynamic' 'TZ' 'ES Safety'
#  'Premium Su' 'DE3FS' 'KSP 130 Push Start' 'Custom GS' 'Avant-garde 2004'
#  '25T Limited' 'F SPORT' 'Swift  Turbo 4 Way' 'S Drive18i'
#  'Edition 2 Safety' 'G Sports' 'IX' 'LS 2008' 'Honda Grace' 'R FZ 2017'
#  'Moda' '(Used)' 'Safety Edition 1' 'fz safety' 'Lapin Unregistered'
#  'LS grade' 'Premium Plus 2020' 'Japan Auto' 'VOPRUNG' 'wagon r fx 2017'
#  'Cayenne' 'Autech Mode Premium' 'Kyron' 'Bluetec Hybrid'
#  'Japan UNREGISTERED' 'NT 260' 'Leather sheets' 'Edition Shadow'
#  'EX Full option' 'M Package' 'Mercedes Benz e250' '4DR Long Wheel'
#  'Celerio 2020' 'Highway star' 'AZEO G grade' 'HSE PURE Diesel 2.0'
#  '2.9 TD' 'Honda GP4' '725D M-SPORT DIESEL' 'Diesel Auto' 'Face Lift TFSI'
#  'Axio Grade' 'Fit GP5' 'Sensing 2017' 'P12' '4th Generation' 'GT NGX10'
#  'VTI L Turbo' 'Alto 800 LXI' 'Push Start Limited' 'X5 NIGHT EDITION'
#  'Flat Light A75' 'E Grade' 'V8 Cygnus' 'Galant' 'Rocco 2020'
#  'Micro Panda 1.0 Auto' 'LIMITED SUV' 'mini wagon R type' 'AT212'
#  'F56 (2-door) 1.5L' 'Toyota GT86' 'Land' 'suzuki Hustler'
#  'Nissan Leaf ZEO' 'Maruti Suzuki' 'Crossover' 'Corolla 141 B/N' '2nd gen'
#  '206 2006' 'MARK II' 'GP5 L grade' 'Uraban X' 'F75R' 'Toyota Aqua 2014'
#  'Ke 72' 'AMG Premium Pck' 'G Supirio' 'Zxi' 'M-Sport LWB' 'M sport'
#  'Long Wheel Base' 'EE90' 'CE110' 'Bruno NGX 10' 'Allure' 'ex'
#  'R Sport Dynamic' 'Honda N/  Editione' 'Honda Vezel Z Orange'
#  'Ex package' 'Toyota aqua 2015' 'Toyota Prius G' 'Edition 03'
#  'B310 Wagon' 'kE55' 'Lancer l tight' 'no (original)'
#  'Hardtop Convertible' 'Vouge Autobiography' 'DBA-KSP130 Vitz'
#  'Tredia GLX' 'Single Cab 4x4' 'FD3' 'AE 110 Auto' 'Wagon R FZ 2015' 'CK2'
#  'FEX NZT260' 'stingry' 'Luxury 4WD' 'N16 EX Saloon' 'EP91'
#  'Safety Turbo 2017' 'Lancer CS1' 'Estima' 'Stream' 'J Style Safety'
#  'J-STYLE' 'EP 92 Auto' 'Hybrid G Grade' 'Modellista' 'Ivory Package'
#  'GT AUTO' 'IO GDI' 'Protonic Red' 'VTI-L SUV 7 SEATS' '11' 'G/S'
#  'DEISEL MANUAL' 'G  Grade' 'R Dynamic' 'Premio 2019' 'Tz'
#  'SYLPHY G11 AUTO' '120 TZ' 'Suzuki Alto Japan S' '1983'
#  'CUSTOM SAFETY PACKAG' 'M Sport Australian' 'GP1 Smart Selection'
#  'Toyota Axio WXB' 'Fielder' '105' 'G Navi' 'Oulaw' '1971' '2012 G'
#  'S R Dynamic' 'Sdrive20d 2012' 'Terois' 'S,Grade' 'Sedan' 'Facelift'
#  'Fit 2014' '4 GS' 'March K11' 'Diamond' 'Suzuki  Wagon R' 'Power Push'
#  'Gx' 'Vogue SE SWB P400' 'B211' 'EE102' 'Mazda 6' 'GT LED PEARL'
#  'â\x80\x8dâ\x80\x8dâ\x80\x8dâ\x80\x8dZ grade oreng' 'Lancer GL'
#  'Royal Saloon G' 'Prius  G Sports' 'Tredia' 'GT Facelift' 'Fx great 2016'
#  'Pearl white' 'Premio G Superior' '1997' 'Toyota vitz 2008'
#  'FD 4 1.6 I-VTEC' 'Prado' 'Toyota G Touring' 'x grade' 'TX150 DIESEL'
#  'Autobiography LWB' 'K13' 'CRDi' 'Smart Cab' 'push Start Limited'
#  'P300 HSE' 'Ex Tech 2020' 'LXI 2006' 'A15' 'XLT' 'toyota  hilux'
#  'orange pack' 'tx 150' 'Toyota Saefty Pakege' 'X-TRAIL HT32' 'GT NGX 50'
#  'Vti - LX' 'ke72' 'Sports Chrono' '2018-REG' 'Longwheel Base'
#  'Pure Petrol' 'S Grade Limited' 'Edition 2019' 'Toyota Roomy car'
#  'Luxury Line Premium' 'PREMIUM' 'Axio WXB' 'TOYOTA CHR NGX50' 'Ngx 10'
#  'G LIMITED' '202 V8 ZX' 'R  FZ 2018 Safety' 'Edition 3 Safety'
#  'Civic Tech Pack' 'Grace EX Package' 'scp10' 'Safety Edition3 2019'
#  'Suzuki Turbo' 'S LTD/CRUISE CONTROL' '7 Seater Petrol' 'RS' 'hybrid'
#  'Hilux Rocco' 'BMW X1 SDrive M' 'VXI Limited Edition'
#  '141 LIMITED EDITION' 'D 22' 'Black Colour' 'Vogue 3E- Black Pack'
#  'HSE SD4' 'S55' '2nd Gen' 'Z ORANGE GOLD BATCH' '2011 diesel' 'Dayz'
#  '260 G+' 'VTI-L Turbo' 'C180' 'Vitz Edition 3' 'mitsubishi' 'FZ Premium'
#  '240 Anniversary' '1500cc' 'EX Saloon' 'R172' 'Toyota Aqua Reg2017'
#  'Vezel Sensing' 'Super Saloon Fb 15' 'Alto LXI' 'X grade' 'ksp 130'
#  'ALLION G LIMITED' 'FZ Safety 2018' 'G SUPERIOR ST WACTH' 'suv' 'Datsun'
#  'CBB' '2nd Edition' 'M Sport (Original)' 'Toyota Axio WXB 2020'
#  '3rd Generation 2014' 'Wagon 1980' 'Alto Japan' 'MG 2019 ZS Turbo'
#  '120 TZ Fully Loaded' 'Allion' 'GP7' 'NGX-50' '580' 'Toyota corolla 121'
#  'special edition' 'Sahara 200' 'Toyota Camry' 'Ek space' 'FB15 New Shell'
#  'FB15 Super Saloon' 'Lancer Wagon' 'Exclusive Package' 'SX4'
#  'Toyota Ep 91' 'KE 72' 'Sky Active' 'Audi A6' 'G grade  WXB'
#  'FB15 SUPER SLOON' 'G -TURBO' 'Tata' 'Y61 Safari' 'CRV - VTi-LX AWD'
#  'Toyota corolla 141' 'CRDi 4WD' 'CRV 7 STR' 'Ex Sensing' 'double cab'
#  'DBA KSP 130' 'Prius 2010' 'Vitz 2016' 'Hilux Vigo' 'ZEN VXI'
#  'Sensing LED safty' '8 Air Bag Push Start' 'Gp5 S Grade'
#  'Hybrid Night Edition' 'IX35' 'Sahara 2017' 'V8 ZX Bruno Cross202'
#  'Toyota Vitz 2016' 'M-SPORT LWB Highest' 'M Sport Night Vision'
#  'Nke 165 G Grade' 'Ke50' 'Cast 1984' 'JT600 1988' 'K10 March' 'TX 150'
#  'Sliding Panroof' 'G Superior FullyLoad' 'X Sensing 2017' 'Z Sensing'
#  'S Line TFSi Sport' 'Model 2012' 'Chogm' '323 Car' 'High spec'
#  '2017 model' 'S Grade (Body Kit)' '4DR5 J44' 'Santafe 4x4' 'Mini pajero'
#  'Fb15' 'VX V8 Parliament' 'DAA MH55S' 'Z Grade panoramic' '2014 Z Grade'
#  'ALLURE' 'SWB Vouge Black Pck' '320d Face Lift' 'BMW 520D' 'GP5 Hybrid'
#  '110 Kahn' 'Tx 150' '2.5 GT' 'DID Diesel' 'NGX10 GT Turbo' 'GP5  - L'
#  'Avant-Garde' 'Eon' 'TRJ150 6FWD FaceLift' 'Suzuki Wagon R'
#  'Sensing 2018' 'JTE150 Diesel VX' 'Black C350e Sport' 'JTE150 Diesel TX'
#  'nomad' 'vezel Z Grade Orange' 'XG Safety' 'Safety Packege' 'vezel 2014'
#  'Orange Packege' 'turbo' 'G grade 2012' 'EK Wagon' '4 Way Auto Parking'
#  'japan Volvo' '20 Anniversary' 'Face Lift Model' 'S Full Option'
#  'Stingray J Style' 'Z Style Luxury' 'AMG Premium plus' 'GT NGX10 2WD'
#  'C12' 'toyota Roomy' 'Custom Z 2017' 'GM4 - EX' 'Rs' 'Toyota vitz 2019'
#  '30' 'Edition 3 1500cc' 'Custom Safety' 'Z Grade Orange pack' '1.8'
#  'GP 5 L Grade' 'G Touring' '1 - 9 option' 'HSE Pure Diesel' 'HB 11'
#  'Wagon R FX 2016' 'prius 2nd Gen' 'W124' 'brand new' 'CHR 2018'
#  'TRD Limited 6FWD' 'Sahara 81' 'R-Line' 'Technology pack' 'F'
#  'Montero 2002' 'Mira E:S' 'Honda Civic Sedan Uk' 'GT Line Fully Loaded'
#  'Boxy' 'io' 'CelerioX Sports' 'Tx TRJ150 6FWD' 'Tx TRJ150'
#  '2013 S Limited' 'XBee' 'TJR 150W' 'Fortuner' 'TRJ150 Fully Loaded'
#  '2011 1-10' 'ford' '200 V8 Fully Loaded' 'Passo Moda G Grade' 'CE 110'
#  'TFSI Unregister 1.4' 'R FZ 2018 AMW' 'TX TRJ150 Face Lift'
#  '(G) Highest Grade' 'Safety F Grade' 'Honda Civic ES 1' 'Zen VXI'
#  '2nd Gen Annivasary' 'Suzuki Swift RS' 'G Grade Pearl White'
#  'SAFETY LOW MILEAGE' 'KSP90 08 AIRBAGS' '/2016' 'Champ'
#  'Autobiography LW' 'R Dynamic HSE 240D' 'G Special' 'Prius 3rd Gen S LED'
#  'Honda Grace EX pack' '2000cc' 'z grade' 'Ksp 130 Safety' 'Civic' '200DX'
#  'Urban X' 'Masterpiece 2018' 'ROCOO 2020' 'VXI stingray' 'REVO'
#  '1NZ 240 2004' 'vezel' '2016 4th generation' 'AMG Sport Premium'
#  'Sonata EF' 'M235i Convertible' 'Q3 S Line' 'Q3 Vorsprung' 'Corolla 141'
#  'Q7 Fully Loaded' 'GP5  L Grade' 'Convertible' 'Spacia Custom G' '2.7V'
#  'Honda Insight ZE2' 'White Titanium' 'WXB 2018' 'Sensing Facelift'
#  'HB 12 Super Salon' 'Prado TZ G' 'Sarwa break/1600 cc' 'Sport Line'
#  'TFSI 35 S Line' '1-12 Options' 'KSP 130 Safety Edi'
#  'TURBO SAFETY PACKAGE' 'Diesel Jeep' 'SkyActive' 'M Sport Carbon Core'
#  'Active Vacation' '4Motion' 'Cs1 Evolution ix' 'Hybrid ML' 'NightPack'
#  'Exclusive line' 'Plug-In-Hybrid' 'GP5 - L grade' 'GT Allure Premium'
#  '3rd  Generation' 'ECO Boost  2.3' '7-Jan' 'Honda FD 4' 'Wxb'
#  'NGX 10 2WD GT Turbo' 'Electric' 'K12' 'Toyota Axio WXB 2018' 'Model S'
#  'KIA' 'prius' 'Toyota Axio 2015' 'A/C Power' 'Cedric'
#  'Maserati Levante DV6' 'M Modern Line' 'Bmw' 'J31  Luxury' '4DR 5'
#  'LWB Highest Grade' 'Centre Spare Wheel' 'Toyota Vitz 2008' 'At140' 'XG'
#  'Anniversary Edition' 'GP 5 S Grade' 'G Superior 2013' 'Trad HB-12'
#  '1980' '2.0 PETROL' 'GT 2017' 'HSE Only Diesel SML' 'GP5-L'
#  'Facelift Model' 'TFSI PETROL' 'M sport Coupe Diesel'
#  'Kompessor Avangard' 'D22 Cab' 'R FX 2017' 'G- Premium' 'TZ 120' 'EIS'
#  'Toyota Vitz KSP 90' 'Z Grade O Package' 'Aqua G Limited 2014'
#  'A3 sportback UNREG' '2014 G Grade' 'Nissan Dayz 2018' 'KSP 90'
#  'J 44 - Long Wheel' 'Gen 3' '2.0G 4WD' 'Hybrid FD3' 'TX TRJ120'
#  'Ex Limited' 'Safety Full' 'Honda Civic SR UK' 'Navi Premium 2014'
#  'Sedan full option' '2015 txj 150' 'Sunny 1981' 'Allion 260 G+'
#  'Ex saloon N16' 'Isuzu Single Cab' 'A71' 'B210 SPORT' '2011 1-9 Option'
#  'XV-V6' '150 Prado TX' 'S Touring Limited' 'Prado 150 / 6FWD'
#  'Australian Version' 'AMG Premium PlusDimo' 'super exceed' 'vx v8' 'FEX'
#  'G100 1987' 'NGX - 10' '300TDI' 'Q7 Quattro' 'Highest Spec'
#  'G Superior F EX Pack' 'K10 2015' 'Ravo' 'Z Grade (Orange)'
#  'Warrior Auto' 'Highest Grade Z' '3rd Gen 1st Owner' 'NGX10 GT - TURBO'
#  'Z Grade Black Pack' '12' 'KDJ150R (Europe)' 'GT NGX10 2wd'
#  'S Grade 2015' 'allion260' 'Toyota Allion 260' 'BMW i8' 'Safety 2019 Reg'
#  'New shape' 'AMG Premium Plus AIR' 'Aze0' '250 XV' 'Amg Premium Plus'
#  'Honda Vezel Z Grade' '| 2020 F grade' 'Custom Turbo Z' 'FD1 Type S'
#  'Amg premium plus' 'CE 108 L Model' 'FB1' 'Stingray J-Style'
#  'Polar White' 'M16' 'GT TRO' '7 Seater G Premium' 'S LED'
#  'G electric seat' 'Note Nismo Body kit' '3 option' 'SPORTS EFI'
#  'Prius 2012' 'Wigo G GRADE' 'FD 4' 'Sport GLS Diesel' 'GS (G Sport)'
#  'TOYOTA HILUX Vigo' 'Full Option GLS' 'Alto 800cc' 'CAP'
#  'F Ex G Superior' '323 Inter Play' 'NoX10' 'Honda Civic EX UK'
#  'C180 2014' '2017 G Frontior' '2019 Premium Plus' 'GT Turbo Red Top'
#  'G Sport' 'Gp 5  S grade' 'Laurel' 'K50' 'Axio NKE 165'
#  'GT turbo Blacktop' 'Intercooler Turbo' 'Stingray Safety'
#  'Allion 260 G Grade' 'Navi Premium' 'ML320' 'Turbo 2018 2019'
#  'GP5 Grade S' 'MH55S FZ' 'Triton' '202 Fully Loaded'
#  '8 Air Bag L/Edition' 'Raize 2020' 'Benz' 'Discovery 2' 'GSuperior'
#  'Jeep 4Ã\x974' 'CAE-2492' '6' 'Revo' 'SHOGUN' 'SCP90' 'GS Grade'
#  'K12 Beetle' 'NGX 10 GT Turbo' 'Parallel Hybrid' 'Gold badge' '2700XDI'
#  'Prado 150 TX' 'stingray' '4 Way Camera' '725D Exclusive Line' 'ZXI'
#  'TFSI/Turbo' '1.5GL 1981' 'gp2' 'BJ 5' 'Z Black Package' 'Full Options'
#  'Cabriolet AMG' 'IO' 'Grade 2013' 'Jelly' 'Alto 800 LXi'
#  'Vogue Autobiography' 'ac power, new paint' 'Allion NZT260'
#  'ksp130 F Grade' 'Every wagon' 'Vigo Double cab' 'Safty Package'
#  '1300 cc' 'jewela' 'Swift Rs' 'land rover DEFENDER' 'Edition 3 2019 LED'
#  'F Ex' 'vigo 2007' 'Palathsaba' 'Twist' 'Passo MODA' 'ESTIMA' 'Tavera'
#  'Custom XS 2018' 'W211 avant-garde' 'Orange package' 'F Sport'
#  'Kia Rio 1500 F/O' 'Hilux Surf SSR-X' 'Aqua 2013/2015' 'MZ 2018'
#  'g grade' 'Honda Fit Gp5' 'G. Grade' 'C11 1987' 'Hyundai Accent SE'
#  'Techpack' '2018 NZT 260' 'Non safety' 'B11 Car' '1-12 Option' 'Jstyle'
#  'SV Autobiography' 'Safety edition 2' 'P/ plus   N/ Edition' 'FZ 2017'
#  'G Grade hybrid 2016' 'urban S' 'R -  2017' 'axio wxb' 'Vezel RS'
#  'Sport Premium' 'CLA 200' '2017 automatically' 'Alto Japan L Grade'
#  'Passo 2008' 'Ct170' 'Fully loaded/j style' 'Shadow Edition'
#  'G Grade Ltd' 'Works' 'Marino' 'Honda Vezel 2014' 'DID V6 Coupe' 'Korean'
#  'BlueTEC Hybrid' 'F grade' '1 TO 20 Fully Loaded' 'M Sports 2017'
#  'Z Grad Orange Pack' 'PREMIUM PLUS Fully L' 'Brand New  Diesel'
#  'Sky-Active' '150TX' 'Ksp130 F Grade' 'GT Turbo NGX -10'
#  'Mini Cooper 1969' 'RM 01' '2016 full option' 'WXB grade' 'Prius 2013'
#  'Tucson' 'Hybrid 2014' 'LX 470' 'AE110' 'KSP 130 Full Safety'
#  'pearl White' 't30' 'Montero Jeep' 'G - Superior' 'Sedan tech pack'
#  'Honda Fit Gp5 SGrade' 's grade' '2018 4WD' 'Wagon R 2015'
#  'Sorento 1-12 Option' 'Side Antenna' 'v8' 'Edition 1' 'Fully Loaded 2012'
#  '90 Automatic' 'Swift Turbo RS' 'premio' 'Spacia Custom z' 'Audi A8-L'
#  'Boon XL full option' 'CBK-0531' 'HSE LUXURY' 'SR  Turbo'
#  '2018 Face Lift' 'Sportage AWD' 'KC 7681' 'GT NGX10 Turbo' '1999'
#  'outlander PHEV' 'Jewela Black Edition' 'X1 X line' 'Allion 240' 'Ex106A'
#  'Hilux 2018' 'KiA Fride' 'JEWELA' 'Swift Center Antena' 'JT600' '16'
#  'allion 240' 'Mini cooper' 'G Limited Edition' 'YOR 2014' 'Box 1980'
#  'Honda Fit GP4 RS' 'sunny' 'Z Grade Orange' 'Toyota S Touring'
#  '120 GX 2003' 'Supercharged' 'Dx 1984' 'Toyota Axio G Grade'
#  'Toyoto Tank' 'Silver Quattro' 'S DRIVE 20d' 'Diesel 2016' 'safety 03'
#  'G30' 'FL' 'GP5 F Grade' 'TX Diesel' 'GP4 Hybrid RS' 'Gold Badge'
#  '2016 /' 'Prius 20' 'String Gray' 'Toyota premio FEX' 'EFI'
#  'V8 Zx Diesel' 'Swift Turbo' 'TOYOTA SAI HYBRID' 'Premio F Grade'
#  'orange package' 'CRV VTI-L Australian' 'G Premium' 'Robe' 'F 2017' 'ZX'
#  'colt' 'Sports EFI' 'Japan X grade' 'Prado TX REG 2018' 'C200' 'CAX'
#  'NGX50 GT LED' 'MZ 4X4' 'Black Edition' 'WXB 2018 Limited' 'Freelander 2'
#  'cx' 'B 12' 'Cross' 'Premier Autech 2016' 'EX/MASTERPIECE/JAPAN'
#  '1000 Turbo' 'Tech Pack' '4TH GEN / SUNROOF' 'CAC' 'used' 'wagon'
#  'G Superior 8 AirBags' '8 Air Bags' '5 J24' 'Tata Nano' 'Grace EX 2015'
#  'AMG CDI Sports Sedan' '520d' 'Royal Extra G180' 'D21 Cab' 'Vagon 1974'
#  'Push Start 2008' 'Land cruiser 2017G' 'X5' 'Premium 2014' 'ZRE141R'
#  'Quattro S Line' 'Vezel Rs' 'GE 06' 'AMG L Premium Plus'
#  'Double Cab Sports' 'TRD' 'Honda Civic' 'Tx Limited' 'AMG Version'
#  '14-1161' 'Tx' 'EX Sensing' 'RVSI-2' 'Ae100' 'Sports EFI Exchange'
#  'Manuwal Transmission' '1.8T' 'maruti 800' 'Roadster' 'GT LED Turbo'
#  'Sport 2012' '325' 'C12 1985' 'Stingray 2015' 'Ep82' 'DBA-KSP90 Vitz'
#  'Jaguar' 'prime' '4 S' 'Limited Editon' 'Night edition AMG' 'D 21'
#  '2020 REG' 'Black 2015' '2011/2013 ZE2' 'KSP90 2008' 'VX limited 101'
#  'Daihatsu Mira' 'Corona' 'Montero' 'A6 2013 Diesel 15Mil' 'mercedes benz'
#  'Y12w' 'Lancer (MIVEC 1.8GT)' 'Royal Saloon' '14 SHI 7694'
#  'Premium Advanced' 'KG' 'Super' 'DX wagen' 'CHR GT TURBO' 'Dx wagon'
#  'Wake 2018 car' 'Aqua S Grade' 'X Sport' 'Passo XG Safety' 'VVT 7 Seater'
#  '2018 - G Superior' 'GLB 200 AMG Premium' 'Longwaydown' '2WD SUV'
#  'PASSO 2016' 'Ex Master' 'Navi premium' 'Honda fit shutle GP2' 'KE 50'
#  'Kembara (terios)' '2' 'Limited editions' 'Front Japan Seat Set'
#  '2006 New body' '1400cc' 'montero' 'FEX (G Superior)' 'Sky active' '1988'
#  'allion 260' 'io Anniversary' 'V6 GLS' 'CRV' '70D' 'SPORTS UNREGISTERED'
#  'copen x play' 'Toyota roomy 2018' 'M SPORT AUTO' 'Toyota vitz' 'X-Urban'
#  'Subaru' 'Vigo 2009' '250XV,V6' 'VX Limited' 'Progressive Pack'
#  'NaviPremium Package' '110 riviere' 'Z ORANGE PACKAGE' 'NOAH'
#  'KSP90 08 Airbags' 'KE20 hilux' '30 (3rd Gen) Car' '1987' 'Used'
#  'X Unregistered' 'Honda Gp 1' 'HSE 2.0 Diesel' 'safety Package'
#  'Hybrid UK Lexus' '2018 Cross' '2L Twin Spark' 'Non Turbo' 'Aqua 2016'
#  'Fx' '60th Anniversary' 'GT NGX50 4WD' 'Sunny 1987' 'Diesel 120 2005'
#  'Bentley Continental' 'Gx Limited Edition' 'Annivesery Ivory'
#  'A8L 3.0 Quattro' 'W123' 'Edition 03 LED' 'Land Cruiser 79 V8'
#  'Hilux Revo 2018' 'Premio 2017' 'KA67' 'Fit Gp5 S Grade' 'Toyota Vitz'
#  'Pearl White 2017' '2008 Maruti' 'Toyota Premio' 'RX 8 R3'
#  '2.0 C Diesel Turbo' 'super Saloon N16' 'Sky-Activ' 'Corolla 1976' 'DS'
#  'mitsublish' 'RX Sensing' 'Grand Tiger D/Cab' 'GP5 S grade 2017'
#  'Lancer 1986' 'Gs Custom' 'X-trail Nt31' '17 2000' 'Luxury Package'
#  'Porsche' 'X Uaban' 'Diesel CE110' 'ZAA AZED' 'ASP' 'DX Wagon KE74'
#  'Plug-In Hybrid' 'Msport Short Wheel' 'Roof Console' 'G101S'
#  'S GRADE 2013' 'GLE 300D' 'EX Sport' 'R FX 2018' 'ZS 2018'
#  'Gp5 L 2016 Reg.' 'Sunny Wagon' 'AMG Night Edition' 'Premium Plus 2017'
#  'CBF' 'Register 2020' 'GL' 'Nissan Laurel HC34' 'R FX 2016'
#  '121 LX Limited' 'Zen' '207 Cab' 'CJ - 2' 'tercel' 'KSP90 Leather Seats'
#  'REVO DOUBLE CAB' 'Glory SUV Jeep' 'WagonR FX Safety' 'Panther'
#  '3L AUTO VIGO CHAMP' '3 Option' 'DX wagon KE74' 'Revo Revolution'
#  'SCP90 1300CC' 'B12' 'Full Electric' '10_6144' 'VX' 'G Superior 2019' 'a'
#  'Luxury 2021' 'Maruti 800 2012' 'R 2' 'KSP90 Dark Blue' 'ksp 130 2016'
#  'HB 13' 'VTI-L TURBO AUS' 'Vogue 5.0Ltr 503 BHP' 'DAA.MK43S.SPACIA'
#  'x Grade 2008' 'Japanese Model' 'Roomy Turbo' 'Exclusive-Line plus'
#  'FB13' 'GS Sports' 'montero 2013 Diesel' '1.5 FEX' 'TX-150' 'twist' 'EG7'
#  'Hilux Double Cab' 'Kluger' 'city' 'X Grade 2007' 'FB14 Super Saloon'
#  'X G PACKAGE' 'manual' 'Anniversary' 'F EX G Superior' '1100' '2L Sport'
#  'VTI-L 7 SEATER' 'KB Cab' 'BS5V Wagon' 'GT Face Lift' 'Wagon 1983'
#  'Sunny B11' 'Company brand new' 'Trad' 'JADE BLACK' '1300L' 'BJ40 1983'
#  'EE97' 'Cortina' 'Axio WXB Anniversary' 'Diesel Unregistered' 'AT 150'
#  '150 tx' 'roomy' 'fb14 1999' 'WildTrak' 'AMG Coupe Facelift' 'BJ5'
#  'Advance Premium Pack' '1996' 'GLS V76' 'A55 Mark 2 Farina'
#  'Picanto 2016' 'Austin' 'Honda Fit gp5' '5 Fwd' 'KE74' 'SPORTS' 'vagon'
#  'Califonia' '1991' 'GE2' 'G102s' 'MK2.5' '4Th Generation' 'ke20' 'FA4TV'
#  'Suzuki Spacia' 'Toyota Carina' 'Outlowe' 'Ee91' 'KR5411' '306' 'NON'
#  'SGS turbo' 'EP82' 'Sport Autobiography' 'Air bag modle' 'CX G11'
#  'N 16 Super saloon' 'KE50' 'CLA' 'Auto Biography' 'Sportero Brand New'
#  'Ghia 1993' '2018 ST 4 WD' 'C12 GLX.Brand New.' 'Prado 6460 SUV' 'AE81'
#  '2018-2019' 'Mitshubishi CS 1' 'Charment' '504' 'G Tourning' 'Alloy'
#  'Elephant Back Car' 'MODE PREMIER' 'Primio' 'Dutsun B310' '1992' '1300'
#  '1975' 'MK1' 'Special Edition' 'G10' 'C11 V' 'trad' 'BJ60' 'KE 74'
#  'Twist XT' 'Mazda m R 90' 'Lancer Galant' 'hilux' 'Company Maintained'
#  'FL , GRADE' 'Sensing LED SUV' 'Z Grade 4Way' 'Cooper S' '1-7 Edition'
#  'Cygnus 2001' 'G Frontier' '1.5L Jeep Auto' 'FNB 14' 'N17 Bluebird'
#  'Hohda' 'Morris minor' '6FWD 2015' 'GDI' '4WD Grand Escudo'
#  "GP-1 She's Edition" 'GS Edition' 'L-BF3V' 'Sport Unregistered'
#  'Power Door' 'GP01' 'Classic 1955' 'RXT800' 'QUATTRO' 'Frontier Cab'
#  'CRDI 7Seater' 'AC/POWER' 'Sr' 'AMG Coupe' 'FZ Suzuki' 'TX.L | 6FWD'
#  'D20' 'ES1 RS' '4x4 Pickup' 'HSC' 'EiS' 'Ssangyong korando' 'Magna'
#  'matiz' '4 HSC Fully Loaded' '4+4' 'Freelander' 'Dusky Brown' 'Ela3'
#  'Lc 1.0' 'Cross over' '121 G grade' 'Full Loaded' 'Limited Auto' 'V8 VX'
#  'JAPAN PASSO 2020' '8' 'GLS (Export)' 'ES Saftey' '1st Owner VXI'
#  'Peugeot 405' '1KD Thailand' 'Z Ivory Sensing' 'Fielder G Limited'
#  'CROSS' '240G Fully Loaded' 'Non Safety (Premium)' 'C'
#  'Toyota Prado 2017' 'Diesel V8' '200 XDI Full Option'
#  'Camry Fully Loaded' 'Full Opt' 'Rush Fully Loaded' 'WXB Facelift'
#  'idrive' 'ECS' 'Face Lift Limited' 'Venue SX (SUNROOF)' '800 LXI'
#  'Fully Loaded SUV' 'LS' 'Toyota S LTD' 'X edition' 'EX Limited F Loaded'
#  'New Model' 'GDB' 'Auto Gear' '5 HSE SD4 Black Trim'
#  'MSport - Individual' 'Moda Push Start 2017' 'BRAND NEW' '3LITRE 4WD'
#  '2002  European' 'GP5  grade' 'NON PRIMIUM' 'NISSAN N17' 'limited'
#  'Alto Automatic' 'GTX Model' '121 Automatic' 'S LED LIMITED' 'G SPORT'
#  'G11' 'CAMPER GOLD CAB' 'S LIMITED' 'DOUBLE CAB 4WD' 'Smart Cab 4 X 4'
#  'CENTER AENTANA AUTO' 'alto auto' 'WAGON EE106' 'G FRONTIER'
#  'DIESEL AUTOMATIC' 'SPECIAL EDITION' 'ASP GLX MODEL' 'VITZ KSP 90'
#  'G HYBRID' 'STYLE AUTO' 'Hillman Minx' 'Desel turbo 4weel' 'premium plus'
#  'Mazda Carol' 'auto 1.8 turbo' 'Custom Limited' 'Kelisa' 'auto 4wd'
#  'SZ TURBO BRAND NEW' 'Desel turbo auto' '800cc' 'Racy Auto sport'
#  'N17 (N16) AUTO GEAR' 'M Sport +' 'GT LINE' 'S Drive20'
#  'Diesel Automatic' 'AVV50' 'V6 GDI' 'QB15(Anniversary)' 'EC7'
#  'C Limited 2nd Gen' 'G-LTD' 'PREMIUM AMG LINE' 'F SAFETY'
#  'M SPORT FULLY LOADED' 'N/FACE ORIGINAL 4WAY' 'GT 2WD FULLY LOADED'
#  '1.3 A 2003' 'GT FACE LIFT 3500KM' 'DIESEL 4WD 7 SEATER'
#  '4WD PLUGGING HYBRID' '2017 Ex Sunroof' 'ORIGINAL 4WAY' 'S PACKAGE'
#  'EX TECHNOLOGY PACK' 'V6 V93' '30th' 'ASP model 1989' 'CR DUPLICATE'
#  'GP4 RS' 'B13' 'Leather' 'Gino Limited Auto' 'Pleo Sport Limited'
#  'Grade G' 'Farina' 'I-Stop' 'D240 110' 'Corolla EE 98' 'AMG Premium'
#  '2017 1st owner' 'X-Drive 20d' 'ES8' 'Fully Loaded SunRoof'
#  'Mitsubishi L200' 'Aventura full option' 'AD wagon' 'C91'
#  'BJ5P Prado light' '1.0 Eco Boost' 'Box. dash board 90 %' 'A45 KITTED'
#  'Vitz 2000' 'VORSPRUNG FULL SPEC' 'Push Start Safety' 'F01'
#  'Edition 3 Hybrid LED' 'GP5 L Limited' '15000KMs' 'Mark 1' 'GP5 S GRADE'
#  'Classic Limited' 'Japan ENE-CHARGE' 'M Sport - F39' 'Mirage'
#  'TFSI Sportsback' 'N17 body' 'G240 G Sunroof  2008' 'S-line' 'STYLE'
#  '202 ZX' '1-12 Diesel CRDI' 'Luxel G grade' 'daihatsu charade g11'
#  'SX automatic AT192' '2015 Highest Grade' 'Smart Vigo Cab' 'RCZ GT Coupe'
#  'Kid - Auto' 'Venue SX Turbo' 'Z Ivory sensing' 'AE100' '7 Seater CRDI'
#  '2.0 DIESEL AUTO' 'REVO ROCCO' 'Vigo Single Ab' 'V6 petrol 2990cc'
#  'G Superior F EX' 'G SUPERIOR F EX' 'TRJ 150 TX Diesel'
#  'X Urban Cross over' 'Pixis JOY' 'CBF XXXX' 'Brown' 'S TOURING'
#  'SPORTS Arbag Exchnge' '7-Seater' 'ROCCO' 'GT Line Pure Tech'
#  '4 HSE Vouge Luxury' 'HSE Only Petrol' 'Box Car' 'ES8 Japan'
#  'Japan Unregistered' '1.3 Push start' 'JAPAN PASSO' 'premium airmatic'
#  'Japan Wagon R 2018' 'Petrol 7 Seater' 'Pearl White'
#  'UNLIMITED FOX SPORT' 'Fully Loaded GLS' 'White Diesel' 'Grey'
#  'G Grade 7seater' 'C11V  - Manual /' 'Sports /' 'Auto - (Diesel)'
#  '/ CS3 -' 'Manual / Full Option' 'FD 3 Hybrid' 'M-Sport 2016'
#  'ac..p/shutters' 'Black..Manual' 'NCP 110' 'Roomy GT Custom' '"G Grade"'
#  'NZT-260 (F)' '2012 Diesel (1-12)' 'Diesel New face' 'AGZ10' '4x4 SUV'
#  'KD-' 'Suzuki jimny' 'Alfa' 'WXB Safety Package' '150' 'Low Milage'
#  'Turbo 4X4' 'DUAL POWER DOORS' '800 Cc Indian' 'G BODY KIT'
#  'S400 Unregistered' 'M sport (Diesel)' 'Nissan X-Trail'
#  'GP5 L Grade 2014' 'Land rover' 'Latio Japan' 'V8 200 ZX'
#  'TRJ 150 TX FullyLoad' 'Y12 Wingroad' 'ASP  1989' 'Series 2' 'LX1'
#  'AK - 12 / AUTO' 'Manual Exchangable' '1.5 GLI Modified' 'G LED LIMITED'
#  'JAPAN - BOX MODEL' 'J STYLE / W' 'First Owner' '7 Seater Full Option'
#  '4D56 Turbo' 'B110' 'MZ  Fully Loaded' 'L light' 'VRG160' 'E46'
#  'Alto LXi' '300Z (Ferrari Kit)' 'Sports SPEC' 'Hibrid' 'Dual air bags'
#  'Flat Light' 'Multifunction' '141...F/O' 'Low millage' 'G grade sunroof'
#  'Safety package' 'Manual..Diesel' 'Japan Alto Auto' 'BF3' 'Morris'
#  'Z Black' 'KE55' 'power shutter' '6 Seater' 'M Sport 2017'
#  'Special Edition  RS' 'Sumo 2005' 'AC' 'GP5- S Grade' 'Safety TV' 'CAO'
#  'GP1 Navi premium' '1-12 OPTION' 'hybrid 4' 'sunroof' 'ORANGE PACKAGE'
#  'F55' 'xvt power up' '2 SD4 HSE' 'CILQ' 'Safety 4 Way Camera'
#  'Nissan Saloon' 'Bi Turbo' 'Honda Fit  GP5' 'fully loded' 'B211 1978'
#  'RD1' 'Yaris Vitz' '1.8T - Turbo' 'Cab' 'Prado 2015' 'VTi-L'
#  'Safety Package-2018' 'LD 1987' 'Turbo 4Way' 'GX - 110' 'Nano' 'BG5P'
#  'Gt Turbo Led' 'Esquire' 'ELECTRIC SUNROOF' 'FZ... Auto stop'
#  'Series III' '1000cc' 'TRJ120 GX' 'e SE' 'Aze0 G Grade'
#  'G Plus Fully Loaded' '3 Auto' 'k 10' 'X 1.5L' '102' 'fully loaded'
#  'Safety Model' 'Manual /Full Option.' 'LEVIN' '260  G-SUPERIOR'
#  'Brand New Imported' 'N17 (N16)' '4x4 jeep' 'LJ79' 'Toyota Vitz 2007'
#  'Familia Automatic' 'Extreme' 'DBA-AACHY 1000CC' '3rd Generation  S'
#  'Alto safety unregist' 'Roomy 2017' 'Vitz Passo 2019' 'TechPack Sunroof'
#  'MX7 Mark11' '121 X Grade' 'March AK12 Bolero' 'K10 1.0L' 'Auto 650'
#  '1.2L' 'B14 - 1.3L' 'Y 11 Silver 1.3L' 'S - 1.8L' 'AMG LINE PREMIUM'
#  'Corolla II' 'Matte Blue' 'Straight Petrol' 'Si4 Straight Petrol'
#  'Vogue Warranty' 'B 15' '140J' '141 Com/ Mtn' 'UK Model 2018' 'F Limited'
#  'Hybrid 2.4Ltr' 'GP 5 S GRADE' 'Sunroof' 'safety push' 'E39' '240 G'
#  'WXB Pearl White' '1st owner' '1 st owner' 'V8 G SELECTION'
#  'B-Class Electric' '120 Petrol' 'FX Safety' '2nd edition'
#  'Smart double cab' 'RS Sensing' 'A33 Excimo' 'MSport Company' 'Bj5'
#  'Sport Diesel  Japan' 'G. Push Start' 'Super Shield' 'Camper Gold'
#  'EP 82 soleil L' '110 Double Cab' 'Manual..AC,' 'Allure Premium' 'D22'
#  'Diesel AMG Premium+' 'KE72 DX' 'RS SENSING' '80' 'Twist XM' 'Auto 1.5'
#  'Extreme ABS' '6 Forward' 'LW Autobiography' 'V8 Sahara' '1.3Ltr'
#  'Range Rover Diesel' 'AE 110' 'GT M Sport Turbo' 'Center Antenna Shift'
#  'MY ROAD' 'Key Start' '1.3 cc' 'B13 BRAND NEW' 'HZ105 UN Model'
#  'SAFETY/PUSH START' 'W202' '3' 'Laguna Mark 2' 'Kyron 200 XDI'
#  'ADVANCE PREMIUM/JBL' '107' 'PUSH START 8 AIR BAG' 'Murano Full Option'
#  'Axio X Grade' 'SV' 'DX KE74' 'RS 4x4 jeep' 'Phev/G Navi Premium'
#  'Audi LWB' 'Safety 2016' 'VB11' '1500CC Auto Japan' '800 Low Milage'
#  'Custom Double' 'Avenir' 'CT 141' '4x4' 'Original Tire/Record'
#  'EX Highest Grade' 'Mercedes benz' 'custom z' 'Manual..AC' '107 SSRX'
# ...
#  'CT II' 'non safety' 'Sport XE' 'Zen 2006' 'CUSTOM Unregister'
#  'VTIL-VTEC' 'Sports Unregistered' 'Hybrid Voxy Noah' 'GSL 1.4'
#  'Spacia custom xs' 'fx-safety' 'XL Safely' 'RT60' 'CHR NGX-10'
#  'EFI AUTO 1300' 'Diesel - 7 Seater' '65-5728' 'editon' 'NTZ260'
#  'Sahara 100 4x4 Jeep' 'W212 /pure Diesel' 'V8 MP Permit' 'GLB200'
#  'G Plus Electric Seat' 'Sunroof LED Lights' 'S Line Sunroof'
#  'PREMIO G SUPERIOR F' 'P90D E Sport' 'Ice Crystal White' 'Vitz 2015'
#  'Custom Z Safety' '2.2Ltr Turbo' '1300cc 4 Cylinder' '4D56 Intercooler'
#  'Nax50 turbo 4WD' 'N 17 Supper Saloon' 'Mahindra Bolero' 'Ee103' 'CSP 90'
#  'A/c,' 'N16 AUTO  JT-2005.' 'T31 Platinum' 'Diesel com.Brand new' 'Ek 11'
#  'Safety (RBS)' 'BMW  MSPORT' 'SI4' '4 XS SDV6 HSE' 'Urban Limited'
#  'HONDA VEZEL RS 2020' '2012 (Registered)' 'GT NGX 10' 'Toyota  DX KE 72'
#  'WXB (Facelift)' 'EFI 800' 'Zotye' 'Manual Face Lifted'
#  'Fb 14 Supper Saloon' 'Ex V-Tech' 'Accent GLS' 'Fully Loaded /Petrol'
#  'Nomad' 'EX-L Masterpiece' 'Safety Key' 'D21 Embosed Body'
#  'Toyota  S Grade' 'CLA 180 AMG' '2008 registered' 'RM1 Fully Loaded'
#  'WDB -211' 'Highest Loaded F10' 'M Sport Plus Limited'
#  'Hse Diesel 3.0 Auto' '3rd GEN' 'CK' 'S Grade Sunroof' 'Ex GLS'
#  'LED/Push/Safety' 'GXL' 'Sunroof Msport' 'Urban 2017' 'Urban G Grade'
#  '161(Non Hybrid)' 'Eclipse cross 2018' 'Toyota CHR 2020'
#  'AMG Premium + Coupe' 'N Wagon Custom' 'Prius S Grade'
#  'Universal Single Cab' 'Universal Double Cab' 'NGX50 2WD 2018'
#  'safety Japan 2018' 'kompressor' '2013 Dec Registered' 'Sports 2018'
#  'Highway Star Un/RE' 'T6' 'TX LIMITED FACE LIFT' 'OZ Rally' '3.0 Diesel'
#  'F LED Safety Model' '6 Options' 'BRUNO' 'Aqua G grede 2013' 'GX 120'
#  'LED Safty Model' 'TRIM' 'Power Steering' 'Sallon' '2019 Registered'
#  'geely' 'Honda  Custom' 'WXB/ Ivory' 'aveo LTD 2008' '2019 AMG Line DIMO'
#  'SLK200 AMG' 'FULLY LOADED 2015 W' 'Premio FEX- G' '3.0D INVINCIBLE'
#  '3.0 DIESEL LWB' '5 3000CC' 'Bajaj Qute RE60' 'Micro Kyron 200 XDI'
#  'DF3V Dx' '4Ã\x974 B5' 'LCI (FACELIFT) -F10' 'warrior'
#  '2.0L Turbocharged' 'double cab puma' 'vigo smart cab' 'LED Safety'
#  'G Superior (F/EX)' 'Tan AMG Premium Plus' 'Triton GLS Top Spec'
#  'car Japan 2017' 'HB 12' 'New Gear Box' 'Fun Cargo' 'Tercel' 'CHR Hybrid'
#  'FB12 Trad Sunny' 'Nissan march' 'Suzuki XBee 2018' 'KQ'
#  'Juke Fully Loaded' 'Silver Colour' 'IO GDI 2000' 'Gt Line full options'
#  'Hybrid 4 Diesel' 'F 10/ Diesel' 'C Limited Highest Gr'
#  'M SPORT INDIVIDUAL' 'LX 141' 'Alpha (7 seater)' 'rocco' 'Nissan  FB 14'
#  'GT Turbo 2017' 'RX350' 'Honda Civic SR' 'G Superior 8Air Bags' 'Es1'
#  'Triptonic Auto' 'MK-2 38000KM' 'Vitz Edition 3 LED' 'Safety EDITION 02'
#  'Xeta EV2 GLX' 'Unregistered roomy' '3.3 GL' 'White/ Brown' 'Laurel car'
#  '580L Luxury' 'Facelfit' 'XDI270' 'GDI Pajero IO' 'Elephant Back Wagon'
#  'TOPPO AUTOMATIC' 'AMG REG' 'ALTO Sports' 'AMG Triming'
#  'BRANDNEW SEDAN CAR' 'SR/Turbo' 'Nickel Pack' 'Sygnus'
#  '260 (In Weeraketiya)' 'Scp 90' 'Ene Charge' 'NGX 10 GT BRUNO'
#  'Wagon R - Premium' 'White AMG C180' 'EX saloon splend'
#  'Nissan Ex saloon' '230 JM' 'DLA-GG2W' 'Most yellow' 'Discovery 5 3Litre'
#  'BMW 740Le M Sport' 'Y614X4 IRONMAN BUILD' 'Vogue Diesel' 'NL 40 Corsa'
#  'Tank Gs Safety' 'GT NX10' 'Gt Turbo 2 Tone' 'Audi A6 Hybrid TFSI'
#  '2 GX 110' 'Sdrive 20D' 'Alto VXI' '150 VX Diesel' 'Aqua 2013 G Grade'
#  '2015 Pure Diesel' 'DX k72' 'Perl White' 'DX 72' 'Sylphy 1.5 Japan'
#  'Prius G Touring' 'Luxel alpha' '2015 Fully Loaded' 'CC Fully Loaded'
#  'PHEV Premium G' 'Suzuki A-Star' 'GSuperier' 'TA-VZJ121W' 'TURBO RS'
#  'White V8 202' 'White E200 petrol' 'Active E' 'BMW 520i (E60)' '2L Turbo'
#  'KGC10' 'HB 310' 'URJ202 ZX' 'JAPAN WAGONR FX' '1500cc Japan'
#  'TI My Road' 'S High Spec' 'Auto F/O Exchange' 'Lecom'
#  'New Face 2018 Axio' 'Vigo Extra Cab' 'Sportero 2020' '2010 3rd Gen'
#  'Power shutter' 'Safety 2017 AWD' '2wd/hybrid' 'SX 4WD Premium'
#  'Auto 4 wheels' 'GD8 Japan' 'Tata c lndica' 'Premio 240' '110 XE Saloon'
#  'Langley HN12' '2018 Perl white Ed2' 'car Full options' 'DX wagon 74'
#  'MUGAN INFINITE' 'CHOGM' 'NGX 50,GT TURBO' 'Swift rs  turbo 20'
#  'Wagon R Sting Ray' 'N16 Super saloon' 'W123   200D' 'GT LIMITED EDITON'
#  'Bmw X5 M Sports' 'VXI Auto Sport' 'ZF-1' 'Magna  GK-XXXX'
#  'Singapore Taxi Model' 'Glory Van, Reg 2016' 'EX saloon' '95'
#  'VTI-L(Japan)' '1.8 Facelift' 'Fit Gp1' 'Urbon' 'XL (Safety Package)'
#  'Stingray X' 'J Style|First Owner' 'DIESEL KDJ150' 'EX PACKAGE SpecialED'
#  'Atos GLS Prime' '650 Japan' 'Hybrid X Grade' 'Toyota vitz 2017'
#  'Matrix 2005' 'PANDA CROSS 2012' 'Revo Double Cab' 'Exclusive package'
#  'sports car' 'Japan Auto 2-Door' 'Super Saloon Fb15' 'Fit Gp 5'
#  'Passo Moda Safety' 'Safty Edition 2' 'Red CLA200' 'Highway Star Safety'
#  'Fully Spec' 'C350e' '. B/Top' 'Sedan Europe Spec' 'AMG P. Plus Night E'
#  'Custom Z Turbo 2018' 'Custom 2018/' 'N16 GD' 'Swift Kei 2007'
#  'eagle eye view' 'CE106 Automatic ""GL""' 'Essence Uk'
#  'Tata Indigo cx 2011' 'Honda Vezel RS' 'elite' 'Koba'
#  'Full Loaded Sunroof' 'T5' 'G - B/New HV Battery' 'Premium G navi'
#  'AQUA G GRADE BLACK' 'low Mailage' 'Diesel 2012' '200 Tech Plus Pack'
#  'juke 2012' 'M Sport 2016' 'MZ UNREG.' 'Climber Auto Gear' 'FULL LEATHER'
#  'LXI First Owner' 'weel' '2018 Safety Model' '240G Petrol' 'japan Auto'
#  'Black Top/Body Kit' 'Premium Xtrail' 'KSP130 2019' '116i'
#  'Stingray 2014' 'LN 166 DOUBLE  CAB' 'Moda Full Option' 'LWB AGENT'
#  '7SEATER' '(used)/' 'Sport  Cab' 'AUTO WHITE JAPAN' 'Sunny B 310' '..'
#  '2016 hybrid' 'WXB 2018 LIMITED' 'company maintained' 'HB 11 Extra'
#  'P90D' '4X4 Auto Diesel' 'Dual A/c' 'Sport.' 'REVOLUTION 4X4'
#  'CE108 Wagon Elephant' 'RS 16,000KM' 'Y33-Cedric-Brougham'
#  'TFSi S Line -' 'X2 M sports' '4WD TRITON THAILAND' 'Orange Pack Gold'
#  '1300 Highest Grade' 'Telcoline Double Cab' 'D22 Double cab'
#  'WXB Face Lift' 'sportage' 'Sunroof 5 Forward' 'N17, EX Saloon '
#  'Suv Package' 'Yaris 1300 F/O Auto' '2007  2nd Owner' 'toyota vitz'
#  '1300cc Push Start' 's300 LWB' 'x 25' 'Ex 1St Owner' 'BROWN'
#  '121 - Black' 'Vigo Full option' '2 FULL OPTION' 'Box 1984 (13-XXXX)'
#  'Toyota 141' 'Jcb' 'Cab Lorry' 'S Line Sport Package' 'HR52 S-CRUZE-auto'
#  'S grade- 8 AB/Safety' 'GT Turbo NGX10 2wd' 'M Sport Shadow ED'
#  'tekna plus' 'Honda Grace 2016' '7 Seater 4x4' 'G GRADE LIMITED'
#  'VEZEL RS SENSING' 'Wagon Turbo' '5 HSE Luxury Highest' 'DIESEL VX'
#  'SkyActive Petrol' 'Japan 650' 'RE2-4WD-sunroof' 'Urban Body (S)'
#  'Chevrolet' '67000 KM' 'S Drive 18i X Line' 'LWB Comfort Plus SML'
#  'G Superior White' 'AUTO -1500 cc' 'X SUV' 'SV Diesel LWB 3.0'
#  'GX-L AUTOMATIC' 'Safe' 'TRJ120 TX' 'Super Saloon  N16' 'Automatic 2005'
#  'RXT 2018' 'V45 2003 07 SEATS' '2016 ELECTRIC GATE' 'AMG High Spec'
#  '3000CC Diesel' 'Straight-Petrol' '5000cc supercharged'
#  'M.function/P.start' 'S LED Light' 'Auto-Cup Holder'
#  'Countryman Cooper S' 'Auto (Passo)' 'Wagon EE102 Auto' 'Latio Auto'
#  '2020 Rocco' 'EU14 Auto' 'Honda Civic ES8' 'Honda Accord 2014'
#  'Ce110 Auto' '1.3cc' 'AZEO G Grade' 'Glx C11' 'VTIL Turbo 7 Seat'
#  'Trooper' 'Estillo' 'Cab Prado Rocco' 'HSE Diesel Only' 'ae91'
#  '2021.10.29' 'PHEV  ROCKFORD' '29 000 MILES 1 OWNER' 'X Hustler'
#  'Azeo G limited' 'CE Saloon 110' 'PASSO AUTO' 'S 580'
#  '120 Limited 8 Airbag' 'Sunroof Limited' 'Smart Cab Thailand' 'V44 Turbo'
#  'TRJ150 TX DIESEL' 'Refina' '4WD Sunroof' 'PICKUP' 'Jewela Edition 2'
#  '2nd Gen 2007 Limited' 'Luxury Limited' 'AK12 AUTO' '8 AIR BAGS'
#  'S LED 8 Airbag' 'CK1 Efi Limited' 'Alto Japn X Grade' '2018 REG'
#  'Diesel V 3.0 D4D' 'TOYOTA PREMIO F EX' 'CJ1' 'Comfort Plus Maximum'
#  'Auto Diesel' 'super saloon auto' 'Face Lift Sunroof' 'E65 Full Option'
#  'CLO48 Turbo  4D56' 'Compressor manual' 'HB12 Auto'
#  'GT Turbo TRD Package' 'AMG Premium PCK' 'AMG line Package'
#  'S Line Quattro 2.0' '1 TO 12 FULLY LOADED' 'FB 15 2000'
#  'FZ COMPANY BRAND NEW' 'A3 S LINE F/LOADED' 'Nissan sunny B211'
#  'Celerio elegence ZXI' 'Rs Sensing F/loaded' 'REVO V'
#  'F EX Highest Package' 'Cab 4WD' 'EX Sensing Face Lift' 'RS Fully Loaded'
#  'Y12  Axis Autech' 'GS450h' '530i M-Sport' 'HSE HIGHEST SPEC'
#  'EX Tech Pack Sedan' 'Sport Brown Leather' 'PANDA GEELY 1L AUTO'
#  'MIRAGE  PUSH START' 'TURBO J Style' 'DFSK IAUTO  I-Auto' 'Auto EL40'
#  'N16 /N17 Body' 'A140 J' '300-' 'R11 Refina' 'RS SAFETY' 'SAFETY P/DOORS'
#  'Lancer Cs 5A' '4 Gear' 'JEWELA SAFETY ED 2' 'Spacia Z Custom'
#  'LED ED3 PUSH' 'LED PUSH S/STOP' 'Z Leather Limited' 'REGALIA Gx100' 'lx'
#  '110 puma 2.4' 'Newshell' 'EX 17' 'Dual Multifunct' 'Sahara V8 200'
#  'Honda civic ek3 2000' 'Blue Tec pack' 'N16 ex saloon' 'OLM'
#  'LC105 1 Owner' 'Blue tech' 'Toyota Carina 212' 'Sport condition'
#  'AT170 SE' 'GT Turbo NGX 10' '202 V8 Full Spec' '13000km L'
#  'Aqua G LIMITED' 'hybrid body' 'modulo body kit' 'G LIMITED PREMIUM'
#  'Safety Push START' 'EX 39,342 km' '25542 km Mileage' 'x drive 20d'
#  'Z  IVORY PACKAGE' 'PHV G premium Plus' '1.3L' '4WHEEL CAB'
#  'CHR BLACK TOP 2WD' '2WD G TURBO' 'N17 1600cc Manual' 'TZ Auto' 'AVY'
#  'Es X Limited' 'HSE P300 High Spec' 'Toyota RUSH' 'Terios'
#  'orange Pakege' 'Ze2' 'Chrome Package Auto' 'GLE' 'Z orange' 'AMG DIESEL'
#  'TSFI 2018' 'BOON SAFETY' '2.5 L' 'Wagon UNREGISTER' 'anniversary'
#  'Hybrid (G Grade)' 'VTI-LX Five Seater' 'BMW 318i M Sport'
#  'Center Antana' 'Lancer EX' 'Prius 3rd G Touring' 'TXL 7 Diesel'
#  'Renault KWID RXT' 'toyota corolla 1986' 'M Sport 40e -F15'
#  'safety edition 3' 'Mercedes Benz 200D' 'Sportage Diesel' '28436 KM'
#  'axio X Grade 2014' 'Daihatsu Mira 2017' 'GP5 S Grade(2016REG)'
#  'Mini Cooper 1.3EFI' 'Axio x' 'M-Sport LongWheel' '2014 Petrol'
#  'Stingray 2018 Safety' 'emergency breaking p' 'HB12 trad sunny' 'N L 30'
#  'M-Sport Plus-9000km' '2016 4th Gen' 'V6 (Brand New)' 'Tube Light' 'Eis'
#  'Carina GT' 'peugeot 404' 'Vigo...SUV'
#  'ð\x9f\x92¦ à·\x83à·\x94à¶´à·\x92à¶»à·\x92à¶¸ à¶\xadà¶\xadà·\x8aà·\x80à¶ºà·\x9a ð\x9f\x92¦'
#  'AB11' 'Sport GLS' 'gp1' 'N16 FULL OPTION' 'MSPORT 725Ld M Sport'
#  'G Premium Sunroof' 'MODELLISTA' 'ZE3 navi premium' 'super saloon N17'
#  'EX Master Japan' 'WHITE - RS' 'M - GRAND' 'Ze3 fully loaded'
#  'X Limited 8 AirBags' 'Basic edition 2016' 'GP 5 Push Start'
#  'METAL BRONZE' 'XG- 30' '1.6L BRANDNEW' 'm sport sky lounge' 'Y12  Auto'
#  'diesel fully loaded' 'AirBag' 'GT turbo boostimpuls' 'S Limited 2012'
#  'GT Turbo F/Loaded' '(AMG LINE)' 'edition 2 2019' '7 seater sunroof'
#  'Roomy 1300CC' 'G grade 7 Seater' 'TSi' 'A6 35TFSI' 'i-AUTO / SUV'
#  'EX Saloon FB15' 'CS2 HH-xxx F/O Auto' 'KG-xxxF/O Auto' 'S/Edition'
#  'MZ Edition' 'Custom Turbo New' '3rd Gen S grade' 'Safty 4 Way Cam'
#  '1.8cc' '1.2 4 Door' 'S Unregister' 'Hyunda accent R' 'ES1 JAPAN'
#  'JAPAN TOYOTA' '2018 Z LED Facelift' 'Terios jeep' 'G Turning Solar'
#  'Auto 1000cc' '3 option co.maintaid' 'ssrx' 'Diesel HSC Sport'
#  'G Leather' 'DAA-RUS' 'Black Brand New' 'G Limited Petrol' 'SR UK'
#  'N 17 Ex Saloon' 'eon' 'Navi 5 Turbo' '605 SR' 'B13 EX SALOON'
#  'Overland Trim' 'FD4 1.6l' '4000cc' 'Navi primium' 'Smart Cab 3000cc'
#  'k 11 Auto' '121 DICKY LIGHTS' 'Range Rover EVOQUE' 'Rs sensoning'
#  'Mazda Rx8' 'Prius S' 'sport 2011' 'JEEP' '5 S 3.0L' 'Double' 'Lancer Ex'
#  '2.0L FaceLift' 'Silver Brand New' 'Toyota Belta 2008' 'Ex Techpack'
#  'V8 Fully Loaded' 'SPORTS RXT EXCHANGE' 'SPORTS Warranty Ex' 'Alion 260'
#  'Alto 2014' 'XDI2700' '800 cc' 'V6 Brand' 'Comp .regi.2019.Dies'
#  'GP5 (L-Grade)' 'Wagon R Fx - 2016' 'Zen 1998' '4WD Auto'
#  'NISSAN N17 2006' 'Honda gp5' 'AMBIENTE' 'Petrol Jeep' 'Aqua 2014'
#  'Vigo Smart' 'V93' 'charade G10' '2013 Limited beige' 'G 2013 sun roof'
#  '2015 Z CAG' 'Auto VXI' 'CIVIC EX VTEC CVT' 'SERA SPORT CAR E.F I'
#  'S Line RS4 Kit' 'Black ED' 'SX Turbo Two-Tone' 'Edition ii'
#  'Vito 116 CDI' 'VTIL  7seater' '7 Seater V-TIL' 'CE96  DX Wagon' 'Eg8'
#  'CE 110 Sprinter' 'Range Rover Evoque' 'CRDI 4wd' 'AUTO 2003 AIRBAGS'
#  'Wxb G grade' 'KE20 Classic' 'Box 80 Series' 'GLX Xeta'
#  'Aventura Double Cab' 'mazda 323 BJ5P' '500' 'Audi Q3 2.0L Turbo'
#  '2011 AMG SPORT' 'AB' 'DBA -ZC713' 'KGC 10' 'Swift saloon' 'YU12'
#  'Custam' 'K-10 Silver' 'Nissan March K11' 'wagon r stingray'
#  'CE 110 / CE 11X' 'premium plus 2019' 'Edrive M Sport' 'TP12' 'ZXI MODEL'
#  'HSE ONLY Diesel' 'RED EP-91' 'A - Star' '121 -Silver-X-GRADE'
#  'Honda Fit shuttle' 'XLT (4x4)' 'X -Grade' 'xDrive 20d' 'TRAED  SUNNY'
#  'Toyota premio 2012' 'WXB Highest grade' 'jeep model' 'Z-ORANGE'
#  'MAJESTA G grade' 'FB15 Anniversary' 'X G grade,' 'Harrier G Limited'
#  'M200XDi' 'ALTO' 'Sportage 4WD' 'Invincible LC5 3.0' 'Boost Impulse'
#  'Ice Pack Diesel VX' 'xurban' 'AWD Automatic' 'S LINE TFSI Package'
#  '1.0 LC' 'S Grade PUSH START' 'Hybrid RS' 'TMD PUMA2.2' 'Impreza Hybrid'
#  'l400 space gear 4wd' 'Box LC76 CHOGM' 'Austin mini cooper' 'rs sensing'
#  '30 TFSI' 'Elantra' 'FZ 1st Owner' 'Ex Vtec Cvt - 2018' 'ES8 AUTO-JAPAN'
#  'J-44' 'TRJ 150 TX L' 'M Performance' 'Auto RXT' 'S LINE TFSI Sport'
#  'TFIS Spec' 'D21 4WD' 'Bluebird B17' 'F-EX' 'SS' '800 Company Sports'
#  'discovery 4 SE' 'Primium Plus' 'Aventura Limited' 'EP 71 Corolla'
#  '9 Hawk Eye' 'FD 3 UK Edition' 'Mistubishi Colt' 'EP-91'
#  '18-xxF/ O Manual EFi' 'Black Pearl' '320i' 'Giulietta 940 Sports'
#  'DEISEL TURBO' 'Tata Nano Car' 'AK12 2002' 'k30 1974' '2 nd Edition'
#  '2004 EFI' 'Ce20' 'Land Cruiser Cygnus' 'Auto Hybrid'
#  'AMG Advance Prmeium' 'Station Wagon 1989' 'Pushstart'
#  'Msport Manual 2006/' 'DX WAGON KE 72' 'BAIC X25' '8 Seater Diesel'
#  'PHEV Autobiography' 'Autobigraphy 3Liter' 'TX Limited Petrol'
#  'SD4 HSE Diesel' 'RVSI-2 Brand New' 'Sport DID' 'Petrol 7 seats'
#  'Facelift Model RS' 'CRDi AWD' 'cortina mk4' 'PRIUS 30' '5 Speed R.viper'
#  'SHOGUN V6' 'Audi Q3 1.4L 30 TFSI' 'Audi A5 1.4L 30 TFSI' 'Cabriolet/AMG'
#  'Home used' 'Fully loaded Diesel' 'full option aout' 'Exclusive  Line'
#  '141 2007' 'CUSTOM G' 'AVANTGARDE DIESEL' 'S Corss' 'BMW 740e'
#  'V8 ZX Anniversary' 'Edition 110' 'Prado 150 Trj 6FWD' 'Dx Wagon KE 74'
#  'XT set option' 'Europe Turbo' 'Palathsabha - 4D56' 'E drive'
#  'Pleo Japan' 'Audi A5' '3000CC EXECUTIVE' 'CBC' 'GC8' 'maruti 2007'
#  'Top of the Range' '2WD Hybrid' 'S 2010' 'Sky-Actice 2017' 'B211 1976'
#  '350 Executive' 'SUZUKI ALTO K10 VXi' 'HONDA GRACE EX 2016'
#  'AE110 SE SALOON G' 'diesel V8 VX' 'Ex Tech Pack Sedan' 'X 4 WAY'
#  'Royal Crown' 'V8 2017' 'Toyota 3rd Gen' 'K3' 'KSP 130 Safety' 'W201'
#  'RS Hsensing' 'Sorento 7 Seater' 'Navara Aventura' 'GSS'
#  'Safety Packages' 'Axio 2015' 'S Touring Selection' 'Toyota Voxy 2014'
#  'Aerosport' 'Yellow' '2 Liter Twin Turbo' 'AMG Premier Plus' 'KB-'
#  'Revolution Rocco' 'Vios 2006' 'ex turbo' 'M1' 'Tubelight'
#  'Magna Advance v6' 'Y61 GL' 'AMG Bluetec' 'Hyundai Accent 2007' '121 Xli'
#  'Premio FEX' 'VX Deisel' 'AUTO Diesel Turbo' '800EFI' 'AMIEZT'
#  'S Touring Model' 'Stingery' 'LDA-GDJ151W PRADO' 'Z Ivory Pack' '305'
#  'premio G supirior' 'Wagen R Premium 2018' 'Evolution Face GLS' 'fb15ex'
#  'Track Sunny' 'Glory i Auto' 'SG' 'RS SENSING Face Lift'
#  'Japanese edition' 'Electric Unregister' 'KE74- Dx wagon'
#  '2007 Toyota Vitz' 'DEISEL WAGON' 'Highest G - Turbo' 'EX Saloon 2006'
#  'Q2 TFSI' 'Maruti 2011' 'Freelander 2 SD4 GS' 'Roomy Unregistered'
#  'Honda Fit GD1' 'Vitara SZ-T' 'Suzuki Japan Alto' 'Alto 800 Lxi'
#  'F EX  G Superior CBC' '1-12 Full Options' 'Nissan Sylphy G11'
#  'MINI LORRY' 'Petrol Sunroof' 'New Generation' 'Box Brand New'
#  'White    S-Touring' 'Toyota Vitz F Grade' 'DBA-KSP130 VITZ'
#  'Alto LXI 2015' 'Suzuki estilo zen' '4WD D/CAB' 'GP 2 Navi Premium'
#  'SP/ HZ 6073' 'Premium Avantgarde' 'Scp90' 'Audi A3' 'Sports Auto'
#  'FB13 (Doctor Sunny)' 'GM4 EX Grade' 'Toyota Roomy 2019' 'DBA - NGX50'
#  'Matt Paint' 'Asx' 'Diesel auto' 'Passo 2017' 'Vitz Push Start'
#  'L200 Animal' 'Sunroof G Premium' 'GT KPS90' 'AMG PREMIUM  PLUS'
#  '2WD Highest Grade' '2 SD 4 GS' 'Honda MASTERPEICE' 'Phev Fully Option'
#  'NKE165 G' 'Vxi 2014' 'LC' 'A5 2018 Highest Spec' 'NGX10 2W Turbo'
#  '2017 RS Sensing' 'VXI Face Lift' 'CRV VTI-L Turbo' 'EX Stylish Edition'
#  'Honda Orange Package' 'Face Lift 1.8' 'Virtual Cockpit' 'S350 2007'
#  'Ex full option' 'FX Safty' 'FD1 S' 'DE3FS Hatchback' '3rd Gen 2012'
#  'RS  TURBO' 'Honda GP4 RS' 'Civic Sedan' 'AQUA S LIMITED'
#  '(FX) GRADE, 2016' 'DAA-RU3, Ivory Ed.' 'Scp10' 'Grade 2016']

# %%
print(len(carset['Edition'].unique()))
# Out:
# 14106

# %% [markdown]
# featuring continues

# %%
carset['Brand'].unique()
# Out:
# array(['Honda', 'Jaguar', 'Toyota', 'Suzuki', 'MG', 'Mitsubishi',
#        'Peugeot', 'Mercedes Benz', 'Land Rover', 'BMW', 'Hyundai', 'Audi',
#        'Daihatsu', 'Nissan', 'Micro', 'Lexus', 'Kia', 'Perodua', 'Ford',
#        'Tata', 'Renault', 'Aston Martin', 'Chevrolet', 'Other brand',
#        'Subaru', 'Alfa Romeo', 'Zotye', 'DFSK', 'Mahindra', 'Mazda',
#        'Volkswagen', 'Maruti Suzuki', 'Jeep', 'Ssang Yong', 'Datsun',
#        'Tesla', 'Mini', 'Isuzu', 'Fiat', 'Poche', 'Morris', 'Austin',
#        'Chery', 'Opel', 'Daewoo', 'Proton', 'Hummer', 'Volvo', 'Skoda',
#        'Porsche', 'Rover', 'Chrysler', 'Geely', 'Citroen', 'Maruti',
#        'Moto Guzzi', 'Vauxhall', 'Pontiac', 'SEAT', 'Buick'], dtype=object)

# %%
carset['Model'].unique()
# Out:
# array(['Vezel', 'XF', 'CHR', 'Land Cruiser Prado', 'Alto', 'ZS', 'Vitz',
#        'Montero', 'Wagon R FX', '405', 'Allion', 'Harrier', 'Wagon R FZ',
#        'Aqua', 'Fit', 'E300', 'Prius', 'Discovery', 'Lancer', 'Defender',
#        'Axio', '520i', 'Wagon R', 'Swift', 'Elantra', 'Avanza', 'Yaris',
#        'Premio', 'Hustler', 'A3', 'Raize', 'GLE 300D', 'Mira', 'Sunny',
#        'Panda', '740Le', 'NX300H', 'X5', 'S300', 'ActiveHybrid 7', 'C180',
#        'Range Rover Sport', 'Sorento', 'i8', '520d', 'Spacia', 'Grace',
#        '3008', 'Leaf', 'Passo', 'Hilux', 'Viva Elite', '5008', 'CRV',
#        'Outlander', 'eK Wagon', 'Civic', 'E220', 'A5', 'Ranger', 'Rexton',
#        'Other Model', 'Maruti', 'Escudo', 'Insight', 'Indica', 'C350',
#        'Trend', 'Range Rover', 'Accord', 'Crown', '508', 'Corolla',
#        'X-Trail', 'Mark', 'Tank', 'Dutsun', 'C200', 'KWID',
#        'Wagon R Stingray', 'Cruze', 'C160', 'Other model', 'X2', 'Mirage',
#        'Eclipse Cross', 'Tucson', 'Vios', '320i', 'A4', 'Vitara',
#        'Bluebird', 'Shogun', 'Cami', 'Impreza', 'Q3', 'Q2',
#        'Land Cruiser Sahara', 'CLA 200', 'X5 M', 'Roomy', 'C300', 'March',
#        'Sportage', '318i', 'Ecosport', '740e', 'AD Wagon', 'Nomad',
#        'Glory', 'Sylphy', 'X3', 'Venue', 'Scorpio', 'Zen', 'X1',
#        'Familia', 'Navara', 'N-Box', 'Boon', 'Starlet', 'Rush', 'Xpander',
#        'Passat', 'Grand Cherokee', 'Hijet', 'Kyron', 'E350', 'E240',
#        'Korando', 'Cefiro', 'Liana', 'Wigo', 'Grand Vitara', 'Santa Fe',
#        'Q7', 'N-WGN', 'Pulsar', 'C220', 'Fortuner', 'Voxy', 'Stonic',
#        '316i', 'S660', '6', 'Move', 'Dayz', 'Range Rover Evoque',
#        'X5 eDrive', 'MX 7', 'Fit Aria', 'Raptor Ranger', 'Tiida',
#        'Fit Shuttle', 'Sprinter', 'Celerio', 'Nano', 'Indigo', 'A-Star',
#        'Redi Go', 'Range Rover Velar', 'Belta', 'A8', '530e', 'GLE 500',
#        'CLA 180', 'Wingroad', 'Model X', 'Cooper', 'IST', 'Picanto',
#        'Baleno', 'Pajero', 'E250', 'Axia', 'Ractis', 'BAIC', 'S400',
#        '406', 'Fielder', '523i', 'Esquire', 'RVR', '528i', '718 Cayman',
#        'Stellar', 'F-Type', 'Ciaz', 'S350', 'Corona', 'Crossroad',
#        'LS400', 'Geely', 'Carina', 'Minor', 'Terios', 'XBee', 'Soluna',
#        '116i', 'Wrangler', 'Camry', 'Cultus', 'Patrol', '735Li', 'Rodeo',
#        'Panamera', 'Cayenne', 'Matrix', "Fit She's", 'GLE 400', 'Q5',
#        'L200', 'Flair', 'Tiguan', '104', 'Axela', 'Jimny', 'ASX', 'RAV4',
#        'A180', 'Panda Cross', 'RX400', 'Primera', 'E200', 'Cherokee',
#        'Range Rover PHEV', 'Skyline', 'RX350', '4DR', 'Freed', 'Presea',
#        'City', 'QQ', 'Polo', 'Accent', 'Uno', 'Sonata', 'Freelander',
#        '800', 'Charade', 'A6', 'HR-V', 'Duet', 'F-Pace', '225XE',
#        'Spectra', 'Carens', 'Qashqai', 'Laser', 'Carol', 'Astra',
#        'Airwave', 'Solio', 'Mini', 'GenX Nano', 'Serena',
#        'Discovery Sport', 'Attrage', '206', 'Coa', 'Oxford', 'Emgrand',
#        'Wira', 'Rio', 'VW1300', 'RX', 'H2', '730Ld', 'Punto', 'Charmant',
#        'Platz', 'B250e', 'EK Custom', 'Alphard', 'Nubira', 'Pixis',
#        'Demio', 'Dzire', 'Mustang', 'CLS', 'Optima', 'Verossa', 'Gen-2',
#        'Extreme', 'Aveo', '320d', 'Tivoli', 'XV', 'GLA 180', 'Gemini',
#        'Rocky', 'Forester', 'Trajet', 'S-Cross', 'Actyon', 'Beetle',
#        'Kelisa', 'BT-50', 'Note', 'Colt', '407', 'Kancil', 'Xenon',
#        'Bezza', 'A1', 'XC90', 'GLB', 'X-Type', '730d', 'Estilo', 'Karoq',
#        'ActiveHybrid 3', 'Musso', 'Everest', 'Galant', 'WagonR', 'GT86',
#        'Focus', 'Cast Activa', 'Cedia', 'S320', 'Mini Cooper', 'SLK 200',
#        'Z100', '505', 'eK Space', 'Korondo', 'SX4', '740Li', 'Legacy',
#        'Eon', 'S60', 'T-Cross', 'Festiva', 'Fiesta', 'M235i', 'Cuore',
#        'Macan', '420d', '3', 'Teana', 'Juke', 'ML320', 'soul', 'Marino',
#        '2008', 'HS250H', 'FTO', 'Tercel', 'SAI', 'Copen', 'S-Type',
#        'Wake', 'Ertiga', 'Dualis', 'Kembara', 'Model S', 'X250d',
#        'Vellfire', 'S500', 'i3', 'e-NV200', 'X25', '305', 'Cambridge',
#        'Golf', 'Altis', 'Thor', 'Tiggo', 'Corsa', '300', 'STI', 'Bolero',
#        'Leganza', 'Terracan', 'R2', 'CX-5', 'Grand i10', 'Sienta', 'NX',
#        'Trooper', 'Esteem', 'Fairlady Z', 'Libero', 'Sumo', 'Santro',
#        'UP', 'Nexon', '530i', 'Excel', 'Etios', 'SLC 180', 'Savvy',
#        'Countryman', 'A200', 'Fulwin', 'ML270', 'Tanto', 'Runx', 'Kuga',
#        'Terrano', '740d', 'Sephia', 'Ceres', 'S80', 'e2o', 'Superb',
#        'Odyssey', 'Strada', '530d', '308', '208', 'J24', 'Saga',
#        '4Runner', 'Jade', '850', '525i', '370Z', '218i', 'S560',
#        'Bighorn', 'Atos', '330e', '100', 'Rhino', 'E-Pace', 'M3',
#        'Atrai Wagon', 'Sedona', 'Zest', '940', 'Quanto', '2', 'Astina',
#        'Micra', 'Spark', 'Safari', 'Carnival', 'i20', 'Vanguard',
#        'Avalon', 'S40', '330i', '190D', 'Ignis', 'Caldina', '404', 'Bora',
#        'Z4', 'FJ Cruiser', '2 Skyactive', 'CT-200H', 'Celica', 'Cynos',
#        'Persona', 'CRZ', 'Fabia', 'Compass', 'BB', 'Delica', 'Cerato',
#        '430i', 'F-150', 'MOCO', 'Mentor', 'Aventura', 'ActiveHybrid 5',
#        'Waja', 'Junior', 'Smart cab', 'Auris', 'XE', '607', '735i',
#        'Linea', 'Viva', 'ML350', 'Kenari', 'MU-X', 'Tribute', 'Lanos',
#        'Gloria', 'MX-5', 'WRX', 'F50', 'Voleex', 'Espero', 'Jetta',
#        'Lifan', 'Integra', 'Telcolin', 'C250', 'M6', 'Splash', 'Renegade',
#        'Getz', 'Sportero', 'i-MiEV', 'E180', '307', '730iL', '328i',
#        'Towny', 'Arona', 'Logo', 'Model', '1100', 'KUV100', 'Exora',
#        'A45', 'XJ', 'Beat', '718 Boxter', 'Mondeo', 'GLA 200', 'TTS',
#        'Jonway', 'Levorg', 'E46', 'XC60', 'Xylo', 'D-Max', 'Ioniq',
#        'ActiveHybrid 740', 'Crosstrek', 'Esse', 'Aristo', 'D20 HACH',
#        '640i', 'V27', 'Octavia', 'e-Golf', 'X6 M', '8', 'CLA 250', 'E60',
#        '535i', 'Twin', 'Land Cruiser', 'Roadster', 'Clubman', '408',
#        'Pathfinder', 'Privilage', 'Step Wagon', '118i'], dtype=object)

# %%
carset['Year'].unique()
# Out:
# array([2017, 2013, 2020, 2015, 2018, 2016, 1995, 2007, 2012, 2010, 1985,
#        2008, 2019, 2003, 2014, 1999, 2011, 1982, 1989, 2006, 2009, 2005,
#        1993, 1990, 1988, 2004, 1981, 1983, 1979, 2002, 1991, 2000, 1996,
#        2001, 1997, 1984, 2021, 1998, 1978, 1987, 1986, 1992, 1994, 1960,
#        1975, 1958, 1980, 1976, 1956, 1959, 1953, 1967, 1973, 1972, 1955,
#        1946, 1968, 1961, 1969, 1970, 1974, 1966, 1977, 1971, 1947, 1963,
#        1964, 1945, 1952, 1965, 1957, 1935, 1938, 1950, 1962, 1922, 2022,
#        1951])

# %%
carset['Year'].unique()
# Out:
# array([2017, 2013, 2020, 2015, 2018, 2016, 1995, 2007, 2012, 2010, 1985,
#        2008, 2019, 2003, 2014, 1999, 2011, 1982, 1989, 2006, 2009, 2005,
#        1993, 1990, 1988, 2004, 1981, 1983, 1979, 2002, 1991, 2000, 1996,
#        2001, 1997, 1984, 2021, 1998, 1978, 1987, 1986, 1992, 1994, 1960,
#        1975, 1958, 1980, 1976, 1956, 1959, 1953, 1967, 1973, 1972, 1955,
#        1946, 1968, 1961, 1969, 1970, 1974, 1966, 1977, 1971, 1947, 1963,
#        1964, 1945, 1952, 1965, 1957, 1935, 1938, 1950, 1962, 1922, 2022,
#        1951])

# %%
carset['Condition'].unique()
# Out:
# array(['Used', 'Reconditioned', 'New'], dtype=object)

# %%
carset['Transmission'].unique()
# Out:
# array(['Automatic', 'Manual', 'Tiptronic', 'Other transmission'],
#       dtype=object)

# %%
carset['Body'].unique()
# Out:
# array(['SUV / 4x4', 'Saloon', 'Hatchback', 'MPV', 'Convertible',
#        'CoupÃ©/Sports', 'Station wagon'], dtype=object)

# %%
carset['Fuel'].unique()
# Out:
# array(['Hybrid', 'Diesel', 'Petrol', 'CNG', 'Electric', 'Other fuel type'],
#       dtype=object)

# %%
carset['Capacity'].unique()
# Out:
# array(['1,500 cc', '2,200 cc', '1,200 cc', '2,700 cc', '650 cc',
#        '1,000 cc', '3,200 cc', '1,905 cc', '1,800 cc', '2,500 cc',
#        '660 cc', '1,300 cc', '2,143 cc', '2,000 cc', '1,400 cc',
#        '2,400 cc', '800 cc', '1,490 cc', '1,580 cc', '1,600 cc',
#        '3,000 cc', '1,190 cc', '5,000 cc', '70 cc', '2,800 cc',
#        '1,790 cc', '1,330 cc', '2,900 cc', '2,660 cc', '3,500 cc',
#        '600 cc', '2,755 cc', '2,982 cc', '2,350 cc', '3,900 cc', '240 cc',
#        '990 cc', '215 cc', '3,300 cc', '2,990 cc', '1,290 cc', '4,200 cc',
#        '1,850 cc', '1,990 cc', '1,995 cc', '4,600 cc', '1,680 cc',
#        '1,280 cc', '4,700 cc', '2,690 cc', '1,590 cc', '4,900 cc',
#        '1,332 cc', '1,350 cc', '2,600 cc', '2,980 cc', '1,998 cc',
#        '1,450 cc', '2,199 cc', '998 cc', '1,980 cc', '3,800 cc',
#        '2,148 cc', '1,798 cc', '658 cc', '1,498 cc', '3,490 cc',
#        '4,160 cc', '3,660 cc', '4,461 cc', '630 cc', '2,494 cc',
#        '1,499 cc', '4,800 cc', '1,100 cc', '1,750 cc', '1,970 cc',
#        '1,997 cc', '1,248 cc', '1,598 cc', '2,180 cc', '2,770 cc',
#        '4,500 cc', '1,339 cc', '3,600 cc', '1,890 cc', '4,000 cc',
#        '2,956 cc', '1,495 cc', '4,242 cc', '1,950 cc', '6,600 cc',
#        '1,595 cc', '1,430 cc', '1,390 cc', '954 cc', '950 cc', '2,390 cc',
#        '1,342 cc', '1,900 cc', '1,496 cc', '4,400 cc', '2,477 cc',
#        '2,442 cc', '1,197 cc', '4,660 cc', '80 cc', '2,179 cc',
#        '3,958 cc', '1,240 cc', '1,984 cc', '1,597 cc', '1,589 cc',
#        '2,447 cc', '1,793 cc', '1,320 cc', '2,950 cc', '2,530 cc',
#        '2,499 cc', '8,000 cc', '110 cc', '996 cc', '2,696 cc', '1,480 cc',
#        '1,991 cc', '1,830 cc', '1,303 cc', '6,162 cc', '796 cc',
#        '2,490 cc', '2,495 cc', '1,780 cc', '4,185 cc', '1,575 cc',
#        '1,395 cc', '664 cc', '1,340 cc', '2,960 cc', '4,951 cc',
#        '2,450 cc', '3,498 cc', '1,599 cc', '2,987 cc', '2,765 cc',
#        '1,323 cc', '1,470 cc', '2,196 cc', '250 cc', '216 cc',
#        '10,000 cc', '1,468 cc', '1,999 cc', '624 cc', '2,440 cc',
#        '999 cc', '217 cc', '850 cc', '2,164 cc', '1,792 cc', '1,700 cc',
#        '1,486 cc', '2,830 cc', '1,349 cc', '205 cc', '1,497 cc',
#        '1,399 cc', '900 cc', '2,351 cc', '668 cc', '1,360 cc', '2,150 cc',
#        '2,820 cc', '3,400 cc', '799 cc', '1,449 cc', '1,899 cc',
#        '1,333 cc', '690 cc', '2,560 cc', '625 cc', '1,796 cc', '880 cc',
#        '2,300 cc', '1,250 cc', '2,694 cc', '2,986 cc', '3,198 cc',
#        '1,951 cc', '4,661 cc', '1,650 cc', '1,975 cc', '1,760 cc', '1 cc',
#        '3,390 cc', '1,555 cc', '4,701 cc', '2,790 cc', '1,005 cc',
#        '700 cc', '1,920 cc', '1,439 cc', '6,450 cc', '1,328 cc',
#        '2,553 cc', '6,000 cc', '2,835 cc', '4,640 cc', '2,951 cc',
#        '100 cc', '1,171 cc', '1,690 cc', '750 cc', '230 cc', '2,771 cc',
#        '1,359 cc', '1,298 cc', '1,160 cc', '980 cc', '2,237 cc',
#        '1,799 cc', '1,971 cc', '1,720 cc', '2,850 cc', '1,275 cc',
#        '2,730 cc', '1,895 cc', '1,193 cc', '2,360 cc', '1,460 cc',
#        '2,776 cc', '2,190 cc', '1,368 cc', '2,349 cc', '659 cc', '220 cc',
#        '1,781 cc', '2,488 cc', '2,250 cc', '2,996 cc', '132 cc', '400 cc',
#        '375 cc', '1,130 cc', '1,199 cc', '1,296 cc', '2,750 cc',
#        '1,489 cc', '2,489 cc', '3,370 cc', '1,270 cc', '2,498 cc',
#        '2,953 cc', '2,659 cc', '500 cc', '1,455 cc', '150 cc', '2,253 cc',
#        '1,587 cc', '2,736 cc', '892 cc', '300 cc', '632 cc', '160 cc',
#        '1,410 cc', '3,250 cc', '2,100 cc', '1,398 cc', '3,895 cc',
#        '1,397 cc', '1,230 cc', '1,688 cc', '1,973 cc', '2,198 cc',
#        '3,150 cc', '145 cc', '2,401 cc', '890 cc', '2,160 cc', '813 cc',
#        '812 cc', '2,188 cc', '620 cc', '1,988 cc', '2,183 cc', '103 cc',
#        '1,932 cc', '2,052 cc', '6,500 cc', '997 cc', '2,523 cc',
#        '1,974 cc', '3,100 cc', '111 cc', '1,295 cc', '1,981 cc',
#        '2,650 cc', '814 cc', '199 cc', '1,405 cc', '1,341 cc', '40 cc',
#        '2,995 cc', '1,299 cc', '2,004 cc', '1,408 cc', '2,230 cc',
#        '2,470 cc', '2,680 cc', '1,476 cc', '1,174 cc', '2 cc', '1,388 cc',
#        '2,460 cc', '970 cc', '1,493 cc', '948 cc', '1,530 cc', '3,497 cc',
#        '2,446 cc', '3,310 cc', '3,950 cc', '1,085 cc', '904 cc', '130 cc',
#        '1,870 cc', '2,972 cc', '2,780 cc', '2,142 cc', '1,166 cc',
#        '2,456 cc', '6,200 cc', '2,362 cc', '4,360 cc', '1,396 cc',
#        '640 cc', '1,324 cc', '2,399 cc', '2,340 cc', '90 cc', '1,075 cc',
#        '2,688 cc', '2,720 cc', '2,880 cc', '1,030 cc', '798 cc',
#        '1,150 cc', '1,061 cc', '125 cc', '2,380 cc', '2,760 cc',
#        '1,277 cc', '2,325 cc', '989 cc', '1,420 cc', '3,700 cc',
#        '4,394 cc', '1,050 cc', '1,797 cc', '3,199 cc', '2,257 cc',
#        '709 cc', '4,999 cc', '3,240 cc', '3,050 cc', '4 cc', '180 cc',
#        '2,345 cc', '2,997 cc', '1,509 cc', '4,250 cc', '1,220 cc',
#        '1,994 cc', '2,970 cc', '2,430 cc', '1,591 cc', '2,459 cc',
#        '993 cc', '3,153 cc', '2,993 cc', '4,528 cc', '1,370 cc',
#        '1,317 cc', '1,986 cc', '2,998 cc', '1,594 cc', '2,779 cc',
#        '4,462 cc', '2,559 cc', '3,456 cc', '1,380 cc', '2,496 cc',
#        '200 cc', '2,422 cc', '4,460 cc', '550 cc', '3,110 cc', '2,005 cc',
#        '2,018 cc', '3,590 cc', '3,780 cc', '1,670 cc', '1,550 cc',
#        '1,605 cc', '1,960 cc', '2,145 cc', '988 cc', '3,956 cc',
#        '1,265 cc', '2,825 cc', '1,968 cc', '1,714 cc', '76 cc',
#        '3,070 cc', '1,640 cc', '1,832 cc', '2,550 cc', '1,820 cc',
#        '1,310 cc', '1,548 cc', '61 cc', '1,471 cc', '2,280 cc',
#        '2,030 cc', '1,170 cc', '2,570 cc', '2,597 cc', '1,234 cc',
#        '2,999 cc', '2,140 cc', '5,146 cc', '1,996 cc', '760 cc',
#        '2,171 cc', '3 cc', '4,199 cc', '1,242 cc', '1,910 cc', '840 cc',
#        '3,999 cc', '2,238 cc', '1,928 cc', '3,431 cc', '2,497 cc',
#        '1,987 cc', '6,100 cc', '1,576 cc', '1,452 cc', '1,198 cc',
#        '1,838 cc', '1,192 cc', '1,825 cc', '2,480 cc', '1,020 cc',
#        '1,622 cc', '270 cc', '2,429 cc', '1,331 cc', '3,450 cc',
#        '1,195 cc', '960 cc', '2,525 cc', '858 cc', '3,960 cc', '225 cc',
#        '649 cc', '3,168 cc', '1,098 cc', '7,000 cc', '451 cc', '155 cc',
#        '3,794 cc', '2,663 cc', '5,461 cc', '2,393 cc', '670 cc', '669 cc',
#        '2,775 cc', '665 cc', '698 cc', '2,799 cc', '2,920 cc', '1,794 cc',
#        '1,620 cc', '2,007 cc', '2,493 cc', '1,897 cc', '2,469 cc',
#        '680 cc', '1,725 cc', '1,244 cc', '1,048 cc', '15 cc', '2,630 cc',
#        '85 cc', '2,194 cc', '2,099 cc', '166 cc', '1,948 cc', '1,462 cc',
#        '185 cc', '2,112 cc', '3,790 cc', '2,979 cc', '346 cc', '2,981 cc',
#        '2,510 cc', '2,123 cc', '1,880 cc', '190 cc', '3,604 cc',
#        '1,992 cc', '129 cc', '245 cc', '1,896 cc', '538 cc', '2,189 cc',
#        '73 cc', '1,294 cc', '1,477 cc', '45 cc'], dtype=object)

# %%
carset['Mileage'].unique()

# %%
carset['Price'].unique()

# %%
carset['Edition'].unique()

# %% [markdown]
# Issues founds
#
#
#
# 1.   *model column looks fine*
#
# 2.  *the brand column ok*
#
# 3. year ok
# 4.condition ok
# 5.transmission ok (remove other type)
# 6.body ok
# 7.fuel other types remove
# 8.capacity need to (convert into int values, remove cc ,change into same fromat)
# 9. price change into int format
# 10. milage change into int format
#
# 11. edition need to change

# %% [markdown]
# **bold text**

# %%
#creating a backup copy of our dataset
backupcarset = carset.copy()

# %% [markdown]
# Cleaning the data of price column

# %%
#to remove a data rows carset[carset['Price'] != 'askfor price'] 
#checking non numeric values from the pricecolumn
print(len(carset['Price'].str.isnumeric()))
# Out:
# 40531

# %%
# removing commas from the price tags and set it into the integer type
carset['Price'] = carset['Price'].str.replace(',','').astype(int);

# %%
#checking the infor object to check weather dataset is changed or not
carset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40531 entries, 0 to 40530
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Price         40531 non-null  int64
#  1   Brand         40531 non-null  object
#  2   Model         40531 non-null  object
#  3   Edition       40531 non-null  object
#  4   Year          40531 non-null  int64
#  5   Condition     40531 non-null  object
#  6   Transmission  40531 non-null  object
#  7   Body          40531 non-null  object
#  8   Fuel          40531 non-null  object
#  9   Capacity      40531 non-null  object
#  10  Mileage       40531 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 3.4+ MB

# %% [markdown]
# featuring the milage to integer type

# %%
carset['Mileage'].unique()
# Out:
# array(['37,000 km', '42,000 km', '15,000 km', '21,000 km', '57,000 km',
#        '46,521 km', '60,000 km', '29,000 km', '110,000 km', '68,000 km',
#        '150,000 km', '115,000 km', '92,000 km', '20,300 km', '49,750 km',
#        '108,000 km', '53,000 km', '79,000 km', '17,000 km', '100,000 km',
#        '117,000 km', '160,000 km', '95,000 km', '84,000 km', '109,000 km',
#        '190,000 km', '61,235 km', '80,500 km', '125,485 km', '145,000 km',
#        '120,000 km', '72,000 km', '66,000 km', '50,500 km', '22,000 km',
#        '9,400 km', '11,500 km', '156,000 km', '5,000 km', '130,452 km',
#        '158,000 km', '118,000 km', '49,300 km', '12,000 km', '101,000 km',
#        '36,000 km', '32,000 km', '39,000 km', '31,500 km', '20,000 km',
#        '14,000 km', '75,000 km', '10,000 km', '9,500 km', '23,500 km',
#        '67,000 km', '3,500 km', '91,000 km', '30,500 km', '140,000 km',
#        '56,000 km', '27,000 km', '76,300 km', '28,000 km', '76,000 km',
#        '46,000 km', '77,500 km', '261 km', '89,000 km', '170,000 km',
#        '275,595 km', '23,000 km', '90,000 km', '125,000 km', '70,000 km',
#        '58,000 km', '84,248 km', '43,900 km', '107,000 km', '220,000 km',
#        '128,000 km', '195,000 km', '240,000 km', '196,000 km',
#        '47,000 km', '192,000 km', '43,300 km', '152,123 km', '19,170 km',
#        '191,000 km', '4,900 km', '129,400 km', '175,000 km', '11,000 km',
#        '16,335 km', '81,000 km', '89,409 km', '90,568 km', '61,000 km',
#        '138,000 km', '64,000 km', '148,500 km', '86,100 km', '46,316 km',
#        '103,000 km', '18,000 km', '73,000 km', '62,000 km', '83,000 km',
#        '132,000 km', '19,100 km', '135,890 km', '198,952 km', '30,227 km',
#        '107,500 km', '12,800 km', '100,500 km', '300,000 km',
#        '124,600 km', '230,000 km', '127,500 km', '185,326 km',
#        '211,000 km', '16,500 km', '40,000 km', '86,000 km', '168,000 km',
#        '45,000 km', '65,000 km', '69,000 km', '25,000 km', '224,000 km',
#        '193,200 km', '41,532 km', '66,300 km', '139,000 km', '43,000 km',
#        '34,000 km', '31,000 km', '9,100 km', '13,000 km', '0 km',
#        '180,000 km', '79,500 km', '35,000 km', '8,000 km', '895,603 km',
#        '96,500 km', '116,000 km', '105,500 km', '55,000 km', '77,000 km',
#        '80,000 km', '355,000 km', '115,680 km', '33,000 km', '38,000 km',
#        '82,000 km', '63,200 km', '7,900 km', '144,000 km', '165,000 km',
#        '121,000 km', '71,000 km', '59,000 km', '87,000 km', '105,000 km',
#        '17,500 km', '53,750 km', '8,500 km', '9,000 km', '114,000 km',
#        '130,000 km', '147,205 km', '35,874 km', '5,600 km', '20,800 km',
#        '98,000 km', '40,200 km', '129,000 km', '176,400 km', '115,803 km',
#        '49,200 km', '46,940 km', '27,900 km', '21,906 km', '62,180 km',
#        '49,000 km', '30,000 km', '14,990 km', '67,225 km', '6,000 km',
#        '260,000 km', '57,750 km', '135,000 km', '90 km', '141,000 km',
#        '24,800 km', '169,000 km', '36,800 km', '88,000 km', '6,500 km',
#        '111,000 km', '85,000 km', '167,000 km', '91,458 km', '163,000 km',
#        '134,580 km', '430,000 km', '155,000 km', '102,000 km',
#        '247,000 km', '137,000 km', '98,630 km', '93,260 km', '64,520 km',
#        '24,000 km', '186,632 km', '93,000 km', '127,000 km', '44,700 km',
#        '205,000 km', '112,000 km', '56,150 km', '137,408 km', '12,500 km',
#        '74,000 km', '51,000 km', '44,825 km', '129,500 km', '5,500 km',
#        '136,000 km', '96,000 km', '99,500 km', '152,000 km', '148,000 km',
#        '113,400 km', '63,000 km', '131,000 km', '52,000 km', '126,000 km',
#        '95,500 km', '149,000 km', '134,500 km', '297,805 km', '72,500 km',
#        '134,000 km', '45,939 km', '174,000 km', '361,200 km',
#        '143,000 km', '99,000 km', '78,000 km', '67,100 km', '41,900 km',
#        '223,999 km', '38,500 km', '200,000 km', '31,400 km', '36,636 km',
#        '104,000 km', '48,000 km', '19,000 km', '32,500 km', '910,000 km',
#        '44,000 km', '67,113 km', '181,256 km', '152,480 km', '137,560 km',
#        '63,450 km', '155,290 km', '49,500 km', '15,340 km', '54,000 km',
#        '7,000 km', '268,796 km', '91,240 km', '38,900 km', '61,852 km',
#        '50,900 km', '34,800 km', '44,250 km', '87,300 km', '243,000 km',
#        '80,635 km', '29,925 km', '13,500 km', '225,000 km', '52,200 km',
#        '41,000 km', '25,542 km', '39,600 km', '50,000 km', '28,200 km',
#        '112,500 km', '26,000 km', '66,700 km', '48,900 km', '8,254 km',
#        '89,500 km', '250,000 km', '95,225 km', '44,500 km', '75,900 km',
#        '58,500 km', '81,500 km', '98,500 km', '30,300 km', '113,000 km',
#        '122,000 km', '146,000 km', '56,477 km', '8,200 km', '84,500 km',
#        '39,754 km', '151,589 km', '13,200 km', '288,000 km', '400,000 km',
#        '66,983 km', '319,200 km', '51,800 km', '36,820 km', '32,200 km',
#        '49,630 km', '153,000 km', '105,212 km', '153,800 km',
#        '119,198 km', '109,184 km', '159,000 km', '9,300 km', '83,133 km',
#        '43,600 km', '155,663 km', '142,800 km', '80,800 km', '900 km',
#        '8,800 km', '63,352 km', '800 km', '147,000 km', '171,000 km',
#        '23,400 km', '19,977 km', '10,900 km', '41,504 km', '63,523 km',
#        '950 km', '1,923 km', '142,000 km', '23,661 km', '113,200 km',
#        '145,484 km', '83,805 km', '83,695 km', '18,181 km', '133,000 km',
#        '151,460 km', '179,000 km', '236,615 km', '19,500 km',
#        '281,250 km', '173,000 km', '53,600 km', '151,000 km', '23,900 km',
#        '176,000 km', '104,820 km', '64,400 km', '18,863 km', '94,000 km',
#        '52,500 km', '16,850 km', '148,150 km', '49,950 km', '148,300 km',
#        '100,400 km', '108,026 km', '950,000 km', '97,000 km', '98,456 km',
#        '163,890 km', '119,730 km', '143,678 km', '44,541 km',
#        '231,000 km', '48,141 km', '54,500 km', '900,000 km', '59,300 km',
#        '123,000 km', '43,500 km', '21,663 km', '38,600 km', '198,000 km',
#        '78,725 km', '177,500 km', '167,452 km', '118,156 km', '600 km',
#        '63,405 km', '106,142 km', '18,910 km', '110,124 km', '5,512 km',
#        '21,544 km', '31,563 km', '41,430 km', '255,855 km', '197,000 km',
#        '13,800 km', '29,800 km', '4,100 km', '157,000 km', '66,500 km',
#        '91,028 km', '21,700 km', '93,400 km', '82,500 km', '124,000 km',
#        '92,164 km', '9,550 km', '16,900 km', '310,000 km', '183,000 km',
#        '43,150 km', '104,833 km', '62,382 km', '9,200 km', '53,996 km',
#        '54,450 km', '25,600 km', '16,000 km', '123,500 km', '102,455 km',
#        '107,750 km', '76,500 km', '30,204 km', '77,600 km', '172,386 km',
#        '271,960 km', '42,374 km', '23,104 km', '227,250 km', '86,600 km',
#        '76,100 km', '58,700 km', '85,600 km', '409,392 km', '79,211 km',
#        '12,682 km', '20,120 km', '23,198 km', '7,500 km', '5,400 km',
#        '8,300 km', '123,290 km', '159,766 km', '234,000 km', '193,418 km',
#        '139,230 km', '23,300 km', '87,250 km', '37,375 km', '119,998 km',
#        '129,029 km', '66,720 km', '46,600 km', '162,000 km', '39,854 km',
#        '89,800 km', '103,823 km', '37,600 km', '34,500 km', '166,000 km',
#        '41,500 km', '89,953 km', '182,800 km', '222,000 km', '68,437 km',
#        '226,800 km', '184,400 km', '20,900 km', '75,625 km', '2,500 km',
#        '113,670 km', '52,407 km', '61,300 km', '69,780 km', '185,000 km',
#        '114,587 km', '34,080 km', '81,441 km', '50,340 km', '61,500 km',
#        '235,000 km', '22,502 km', '9,800 km', '207,000 km', '5,862 km',
#        '25,500 km', '10,500 km', '44,835 km', '73,976 km', '29,500 km',
#        '28,700 km', '11,514 km', '290,000 km', '22,586 km', '139,675 km',
#        '142,654 km', '27,027 km', '30,713 km', '115,380 km', '32,766 km',
#        '160,028 km', '92,500 km', '3,200 km', '6,880 km', '19,200 km',
#        '206,000 km', '178,000 km', '108,752 km', '7,950 km', '105,900 km',
#        '135,915 km', '2,600 km', '3,900 km', '29,600 km', '5,700 km',
#        '10,320 km', '277,000 km', '27,350 km', '72,831 km', '280,000 km',
#        '45,869 km', '40,500 km', '68,435 km', '74,500 km', '359,000 km',
#        '65,106 km', '46,583 km', '69,800 km', '73,700 km', '120,001 km',
#        '57,828 km', '16,800 km', '143,400 km', '172,000 km', '77,356 km',
#        '87,219 km', '59,800 km', '73,150 km', '186,555 km', '53,990 km',
#        '86,060 km', '14,555 km', '22,800 km', '105,095 km', '154,000 km',
#        '78,100 km', '181,106 km', '78,473 km', '10,006 km', '63,500 km',
#        '48,300 km', '79,163 km', '88,371 km', '86,900 km', '31,600 km',
#        '63,100 km', '245,000 km', '97,522 km', '136,452 km', '47,852 km',
#        '136,752 km', '87,253 km', '127,522 km', '218,400 km', '65,140 km',
#        '72,010 km', '70,005 km', '75,010 km', '82,010 km', '71,010 km',
#        '41,005 km', '12,865 km', '70,100 km', '125,745 km', '40,985 km',
#        '85,500 km', '9,854 km', '9,221 km', '42,230 km', '174,200 km',
#        '54,462 km', '38,800 km', '182,000 km', '24,500 km', '81,800 km',
#        '128,307 km', '46,430 km', '61,580 km', '65,774 km', '33,510 km',
#        '6,700 km', '24,809 km', '50,966 km', '39,342 km', '125,250 km',
#        '60,492 km', '76,800 km', '177,852 km', '8,141 km', '65,842 km',
#        '50,423 km', '112,795 km', '186,525 km', '24,813 km', '39,652 km',
#        '136,223 km', '151,745 km', '59,988 km', '42,765 km', '258,000 km',
#        '34,931 km', '56,297 km', '175,365 km', '130,847 km', '56,664 km',
#        '16,300 km', '76,350 km', '85,300 km', '136,800 km', '26,660 km',
#        '11,950 km', '62,174 km', '92,014 km', '33,015 km', '64,887 km',
#        '39,874 km', '210,000 km', '294,000 km', '44,285 km', '520,550 km',
#        '16,977 km', '93,500 km', '19,032 km', '39,767 km', '171,800 km',
#        '970 km', '3,000 km', '234,567 km', '74,960 km', '226,402 km',
#        '71,500 km', '63,587 km', '64,103 km', '48,465 km', '57,135 km',
#        '117,560 km', '9,900 km', '127,230 km', '67,780 km', '34,582 km',
#        '40,618 km', '37,712 km', '11,989 km', '54,111 km', '108,376 km',
#        '57,362 km', '53,092 km', '94,070 km', '23,087 km', '67,444 km',
#        '74,600 km', '238,450 km', '131,840 km', '90,670 km', '56,117 km',
#        '41,800 km', '33,136 km', '26,275 km', '267,815 km', '66,900 km',
#        '10,800 km', '123,716 km', '66,810 km', '21,500 km', '78,200 km',
#        '48,244 km', '78,673 km', '61,074 km', '32,330 km', '444,000 km',
#        '29,700 km', '71,248 km', '49,800 km', '66,168 km', '81,975 km',
#        '157,380 km', '60,700 km', '2,000 km', '126,300 km', '51,100 km',
#        '34,752 km', '103,215 km', '88,500 km', '88,843 km', '7,300 km',
#        '8,133 km', '200 km', '214,838 km', '52,258 km', '394,800 km',
#        '183,104 km', '325,488 km', '30,700 km', '268,800 km',
#        '108,620 km', '22,450 km', '14,500 km', '50,465 km', '28,436 km',
#        '67,500 km', '41,096 km', '62,200 km', '44,039 km', '40,100 km',
#        '1,235 km', '236,000 km', '59,027 km', '27,564 km', '99,037 km',
#        '187,000 km', '164,000 km', '87,500 km', '60,500 km', '59,500 km',
#        '138,500 km', '20,500 km', '121,789 km', '145,632 km',
#        '285,000 km', '37,500 km', '119,000 km', '15,520 km', '104,535 km',
#        '68,700 km', '29,760 km', '130,238 km', '51,300 km', '12,325 km',
#        '40,784 km', '9,445 km', '12,080 km', '79,201 km', '921 km',
#        '19,800 km', '225,832 km', '88,948 km', '120,750 km', '232,396 km',
#        '308,930 km', '266,447 km', '48,937 km', '102,494 km', '46,500 km',
#        '100,800 km', '109,431 km', '137,144 km', '41,785 km', '54,750 km',
#        '74,100 km', '70,500 km', '51,400 km', '67,128 km', '69,025 km',
#        '82,762 km', '86,821 km', '95,110 km', '32,760 km', '102,897 km',
#        '159,480 km', '18,411 km', '122,430 km', '42,036 km', '91,456 km',
#        '148,100 km', '95,600 km', '22,569 km', '68,450 km', '130,192 km',
#        '34,422 km', '37,905 km', '72,800 km', '373,311 km', '13,100 km',
#        '208,654 km', '18,200 km', '292,000 km', '27,400 km', '152,478 km',
#        '89,503 km', '83,442 km', '9,678 km', '61,700 km', '211,500 km',
#        '52,660 km', '352,800 km', '105,613 km', '216,000 km',
#        '215,049 km', '83,851 km', '196,700 km', '130,500 km', '13,735 km',
#        '28,100 km', '14,815 km', '718,699 km', '23,450 km', '32,924 km',
#        '41,144 km', '93,986 km', '116,300 km', '23,596 km', '4,000 km',
#        '9,517 km', '19,900 km', '101,300 km', '132,487 km', '92,800 km',
#        '11,313 km', '80,200 km', '85,700 km', '29,400 km', '98,900 km',
#        '153,255 km', '40,875 km', '73,500 km', '133,187 km', '22,600 km',
#        '51,960 km', '111,500 km', '51,050 km', '101,216 km', '143,772 km',
#        '23,658 km', '110,752 km', '55,616 km', '11,225 km', '54,258 km',
#        '12,105 km', '119,590 km', '38,775 km', '189,640 km', '12,450 km',
#        '108,050 km', '82,196 km', '64,500 km', '17,253 km', '177,000 km',
#        '211,224 km', '149,620 km', '18,972 km', '161,000 km', '25,700 km',
#        '134,800 km', '100,917 km', '270,000 km', '310,800 km',
#        '302,400 km', '197,520 km', '218,467 km', '130,880 km',
#        '11,783 km', '65,600 km', '100,598 km', '10,523 km', '378,000 km',
#        '79,999 km', '76,560 km', '218,500 km', '209,000 km', '231,226 km',
#        '403,200 km', '3,950 km', '18,500 km', '44,518 km', '76,340 km',
#        '73,258 km', '208,000 km', '39,700 km', '145,200 km', '106,815 km',
#        '40,800 km', '2,400 km', '76,878 km', '74,400 km', '28,165 km',
#        '213,500 km', '99,825 km', '14,860 km', '37,150 km', '226,400 km',
#        '18,950 km', '1,000 km', '111,470 km', '184,000 km', '40,600 km',
#        '45,230 km', '2,800 km', '6,100 km', '37,805 km', '89,700 km',
#        '62,050 km', '70,600 km', '21,558 km', '64,488 km', '96,434 km',
#        '21,393 km', '121,500 km', '94,224 km', '74,975 km', '75,490 km',
#        '44,865 km', '44,852 km', '41,521 km', '187,452 km', '64,891 km',
#        '79,800 km', '106,000 km', '260,400 km', '240,682 km', '90,703 km',
#        '17,400 km', '70,512 km', '44,640 km', '186,990 km', '47,800 km',
#        '158,988 km', '18,974 km', '65,500 km', '69,925 km', '88,862 km',
#        '181,289 km', '276,220 km', '82,775 km', '59,487 km', '73,200 km',
#        '104,500 km', '194,000 km', '29,980 km', '21,600 km', '41,642 km',
#        '200,100 km', '58,520 km', '35,250 km', '23,078 km', '35,600 km',
#        '107,300 km', '155,998 km', '113,800 km', '5,200 km', '63,750 km',
#        '32,049 km', '56,970 km', '450,000 km', '80,700 km', '85,195 km',
#        '114,800 km', '80,900 km', '11,700 km', '426,000 km', '295,000 km',
#        '177,678 km', '24,150 km', '192,012 km', '13,838 km', '62,624 km',
#        '25,931 km', '98,950 km', '204,500 km', '24,586 km', '61,725 km',
#        '51,529 km', '25,775 km', '32,800 km', '324,117 km', '57,857 km',
#        '27,800 km', '1,080 km', '87,888 km', '22,500 km', '456,123 km',
#        '37,653 km', '323,013 km', '15,900 km', '20,100 km', '1,500 km',
#        '8,725 km', '53,500 km', '17,300 km', '369,600 km', '10,684 km',
#        '6,250 km', '189,000 km', '193,000 km', '167,500 km', '164,199 km',
#        '204,000 km', '30,900 km', '151,450 km', '91,695 km', '126,500 km',
#        '35,500 km', '63,400 km', '36,500 km', '64,610 km', '17,293 km',
#        '275,556 km', '94,600 km', '36,779 km', '54,424 km', '55,340 km',
#        '8,900 km', '50,800 km', '88,432 km', '90,100 km', '40,087 km',
#        '41,465 km', '27,500 km', '88,603 km', '137,170 km', '12,900 km',
#        '44,130 km', '122,980 km', '17,800 km', '21,400 km', '21,800 km',
#        '116,612 km', '102,002 km', '97,500 km', '50,200 km', '215,000 km',
#        '56,500 km', '13,300 km', '39,852 km', '42,852 km', '182,773 km',
#        '154,254 km', '28,500 km', '21,970 km', '11,933 km', '17,200 km',
#        '56,941 km', '99,800 km', '48,956 km', '69,700 km', '10,012 km',
#        '90,643 km', '15,245 km', '33,047 km', '160,745 km', '39,855 km',
#        '40,874 km', '41,079 km', '13,600 km', '63,522 km', '63,900 km',
#        '47,725 km', '74,750 km', '92,421 km', '48,050 km', '42,500 km',
#        '52,437 km', '32,120 km', '225,948 km', '181,300 km', '124,999 km',
#        '32,348 km', '344,400 km', '33,784 km', '28,294 km', '64,444 km',
#        '45,138 km', '203,393 km', '143,278 km', '22,117 km', '136,950 km',
#        '147,287 km', '4,250 km', '275,747 km', '158,697 km', '78,880 km',
#        '19,623 km', '19,276 km', '182,780 km', '81,300 km', '75,600 km',
#        '22,100 km', '169,997 km', '90,730 km', '19,300 km', '87,332 km',
#        '344 km', '116,800 km', '19,760 km', '6,875 km', '62,190 km',
#        '62,700 km', '390,000 km', '26,539 km', '600,000 km', '42,300 km',
#        '7,700 km', '58,100 km', '69,100 km', '62,100 km', '100,797 km',
#        '52,800 km', '68,100 km', '81,200 km', '78,178 km', '25,200 km',
#        '156,377 km', '102,780 km', '15,500 km', '68,200 km', '118,213 km',
#        '7,200 km', '82,235 km', '25,666 km', '96,210 km', '26,600 km',
#        '257,000 km', '67,120 km', '50,753 km', '91,170 km', '15,800 km',
#        '48,500 km', '46,439 km', '38,652 km', '150,381 km', '58,750 km',
#        '142,882 km', '76,600 km', '284,000 km', '53,247 km', '68,934 km',
#        '17,900 km', '84,247 km', '1,400 km', '336,000 km', '186,000 km',
#        '125,226 km', '51,401 km', '128,500 km', '179,215 km', '28,800 km',
#        '306,000 km', '140,650 km', '40,175 km', '5,660 km', '50,100 km',
#        '2,450 km', '141,253 km', '23,156 km', '53,430 km', '68,800 km',
#        '121,600 km', '24,232 km', '8,137 km', '133,500 km', '94,275 km',
#        '63,648 km', '45,500 km', '67,003 km', '67,250 km', '285,600 km',
#        '85,236 km', '38,107 km', '32,476 km', '52,275 km', '11,650 km',
#        '53,190 km', '57,909 km', '74,089 km', '16,720 km', '136,941 km',
#        '48,200 km', '75,794 km', '33,900 km', '151,231 km', '241,000 km',
#        '83,483 km', '107,529 km', '114,703 km', '28,265 km', '96,400 km',
#        '13,635 km', '94,077 km', '63,513 km', '96,689 km', '76,450 km',
#        '27,600 km', '212,000 km', '98,345 km', '4,950 km', '123,285 km',
#        '19,109 km', '102,321 km', '74,920 km', '78,500 km', '9,420 km',
#        '65,640 km', '15,845 km', '214,000 km', '158,456 km', '237,000 km',
#        '70,018 km', '44,485 km', '42,445 km', '44,656 km', '75,283 km',
#        '89,200 km', '20,813 km', '78,600 km', '16,350 km', '233,000 km',
#        '70,800 km', '181,000 km', '12,465 km', '57,600 km', '78,900 km',
#        '58,800 km', '9,600 km', '106,500 km', '32,400 km', '86,400 km',
#        '9,750 km', '31,867 km', '41,700 km', '212,700 km', '87,479 km',
#        '107,800 km', '82,175 km', '16,600 km', '47,148 km', '26,500 km',
#        '71,700 km', '63,679 km', '48,669 km', '23,624 km', '55,800 km',
#        '45,213 km', '33,766 km', '10,646 km', '24,100 km', '131,500 km',
#        '76,547 km', '63,429 km', '78,451 km', '88,531 km', '94,500 km',
#        '125,800 km', '46,101 km', '13,400 km', '94,137 km', '91,500 km',
#        '64,200 km', '56,400 km', '59,889 km', '20,555 km', '43,234 km',
#        '62,568 km', '17,600 km', '130,450 km', '74,730 km', '47,200 km',
#        '157,880 km', '80,856 km', '88,525 km', '109,895 km', '88,600 km',
#        '188,703 km', '70,542 km', '20,185 km', '3,045 km', '39,134 km',
#        '15,534 km', '33,840 km', '56,550 km', '87,320 km', '171,441 km',
#        '20,780 km', '108,500 km', '97,630 km', '96,810 km', '109,500 km',
#        '148,950 km', '106,860 km', '41,931 km', '14,300 km', '15,774 km',
#        '213,086 km', '125,815 km', '55,600 km', '59,100 km', '70,789 km',
#        '34,600 km', '132,589 km', '44,950 km', '323,000 km', '47,500 km',
#        '26,900 km', '77,634 km', '68,500 km', '36,954 km', '45,900 km',
#        '226,000 km', '76,456 km', '64,220 km', '54,400 km', '87,875 km',
#        '78,085 km', '199,800 km', '107,046 km', '19,136 km', '16,320 km',
#        '114,635 km', '77,850 km', '188,000 km', '83,068 km', '63,600 km',
#        '12,756 km', '8,963 km', '55,111 km', '79,200 km', '139,700 km',
#        '74,185 km', '5,800 km', '105,480 km', '68,900 km', '25,980 km',
#        '82,600 km', '68,390 km', '81,092 km', '71,069 km', '21,630 km',
#        '3,800 km', '56,200 km', '69,500 km', '10,400 km', '324,421 km',
#        '80,490 km', '41,720 km', '30,100 km', '50,400 km', '33,500 km',
#        '182,532 km', '44,200 km', '122,287 km', '24,891 km', '118,600 km',
#        '58,622 km', '22,280 km', '934,979 km', '740,000 km', '15,600 km',
#        '131,719 km', '24,400 km', '151,760 km', '70,286 km', '19,450 km',
#        '253,000 km', '105,725 km', '117,800 km', '135,635 km',
#        '420,000 km', '31,200 km', '42,854 km', '46,450 km', '37,106 km',
#        '31,800 km', '340,000 km', '60,735 km', '24,444 km', '12,227 km',
#        '162,536 km', '44,854 km', '109,440 km', '56,700 km', '56,211 km',
#        '94,166 km', '80,193 km', '42,541 km', '51,186 km', '20,280 km',
#        '270,340 km', '92,215 km', '158,300 km', '70,300 km', '16,172 km',
#        '152,600 km', '64,869 km', '24,370 km', '5,555 km', '94,529 km',
#        '47,814 km', '134,450 km', '163,028 km', '78,932 km', '202,000 km',
#        '11,851 km', '83,200 km', '201,760 km', '53,607 km', '51,498 km',
#        '602,625 km', '11,200 km', '11,600 km', '50,456 km', '152,779 km',
#        '199,000 km', '6,300 km', '14,065 km', '45,999 km', '172,457 km',
#        '103,300 km', '30,800 km', '87,575 km', '49,350 km', '134,250 km',
#        '39,522 km', '106,550 km', '72,925 km', '89,523 km', '90,802 km',
#        '148,587 km', '500,000 km', '251,000 km', '116,234 km',
#        '89,104 km', '62,800 km', '250,400 km', '291,000 km', '69,900 km',
#        '87,862 km', '800,000 km', '24,900 km', '67,341 km', '41,121 km',
#        '51,500 km', '369,000 km', '62,500 km', '181,450 km', '12,650 km',
#        '59,950 km', '83,023 km', '152,860 km', '33,600 km', '180,828 km',
#        '650,000 km', '19 km', '350,000 km', '55,200 km', '38,542 km',
#        '235,200 km', '73,401 km', '98,955 km', '11,875 km', '183,400 km',
#        '14,630 km', '94,850 km', '201,000 km', '41,854 km', '39,865 km',
#        '30,409 km', '212,100 km', '411,600 km', '112,175 km', '41,876 km',
#        '156,155 km', '65,493 km', '38,952 km', '580,000 km', '7,100 km',
#        '24,154 km', '127,300 km', '38,655 km', '114,998 km', '13,594 km',
#        '173,500 km', '123,456 km', '90,588 km', '80,002 km', '14,700 km',
#        '12,345 km', '333,000 km', '84,660 km', '135,100 km', '41,875 km',
#        '42,875 km', '277,200 km', '182,305 km', '384,000 km',
#        '168,800 km', '155,400 km', '988,995 km', '10,730 km', '73,999 km',
#        '73,888 km', '196,265 km', '77,250 km', '41,874 km', '78,693 km',
#        '2,900 km', '182,500 km', '91,927 km', '85,625 km', '744,225 km',
#        '360,000 km', '6,780 km', '92,127 km', '109,544 km', '124,584 km',
#        '123,698 km', '834,583 km', '20,600 km', '114,871 km',
#        '146,242 km', '131,042 km', '65,165 km', '199,198 km', '83,500 km',
#        '146,080 km', '92,037 km', '56,680 km', '56,392 km', '93,665 km',
#        '149,200 km', '113,626 km', '48,945 km', '227,000 km',
#        '228,000 km', '31,650 km', '142,888 km', '47,999 km', '252,000 km',
#        '44,321 km', '35,900 km', '159,099 km', '122,300 km', '18,900 km',
#        '18,340 km', '94,567 km', '72,463 km', '78,685 km', '121,456 km',
#        '119,720 km', '58,400 km', '97,600 km', '71,400 km', '199,922 km',
#        '162,100 km', '136,110 km', '54,200 km', '316,000 km',
#        '101,800 km', '67,924 km', '163,700 km', '90,910 km', '32,458 km',
#        '44,957 km', '123,021 km', '39,800 km', '4,744 km', '191,960 km',
#        '142,474 km', '67,124 km', '7,990 km', '4,600 km', '39,200 km',
#        '5,300 km', '142,400 km', '36,463 km', '164,900 km', '78,568 km',
#        '118,245 km', '1 km', '97,452 km', '97,582 km', '32,719 km',
#        '113,500 km', '12,135 km', '112,354 km', '223,000 km', '59,250 km',
#        '99,200 km', '39,500 km', '21,150 km', '99,325 km', '31,250 km',
#        '24,758 km', '44,650 km', '16,782 km', '63,520 km', '15,666 km',
#        '38,654 km', '108,250 km', '6,524 km', '1,100 km', '71,245 km',
#        '77,900 km', '19,650 km', '34,150 km', '38,150 km', '40,010 km',
#        '250,206 km', '69,587 km', '68,400 km', '54,600 km', '84,900 km',
#        '107,010 km', '67,539 km', '53,100 km', '40,702 km', '46,281 km',
#        '74,950 km', '75,800 km', '94,379 km', '185,423 km', '118,300 km',
#        '61,482 km', '28,552 km', '148,416 km', '23,600 km', '70,250 km',
#        '43,516 km', '66,724 km', '76,272 km', '63,580 km', '110,926 km',
#        '93,200 km', '48,140 km', '69,655 km', '49,700 km', '311,000 km',
#        '104,369 km', '138,700 km', '102,169 km', '139,977 km',
#        '65,542 km', '35,100 km', '32,900 km', '133,309 km', '29,100 km',
#        '80,400 km', '4,885 km', '95,153 km', '10,649 km', '98,675 km',
#        '108,366 km', '85,460 km', '64,277 km', '111,342 km', '123,987 km',
#        '81,897 km', '89,632 km', '70,400 km', '173,300 km', '15,452 km',
#        '15,421 km', '22,900 km', '88,900 km', '82,240 km', '111,111 km',
#        '191,200 km', '149,444 km', '249,560 km', '27,150 km',
#        '122,500 km', '30,035 km', '14,800 km', '17,817 km', '88,700 km',
#        '221,326 km', '45,466 km', '32,512 km', '97,856 km', '6,600 km',
#        '165,250 km', '89,560 km', '81,456 km', '271,495 km', '151,609 km',
#        '189,460 km', '131,841 km', '187,560 km', '27,690 km',
#        '102,456 km', '510,076 km', '33,030 km', '68,125 km', '320,000 km',
#        '161,500 km', '57,782 km', '120,422 km', '169,530 km', '6,073 km',
#        '105,983 km', '74,833 km', '68,547 km', '127,600 km', '50,450 km',
#        '279,000 km', '114,523 km', '36,200 km', '131,200 km',
#        '110,525 km', '272,208 km', '50,172 km', '113,550 km', '60,293 km',
#        '93,345 km', '86,500 km', '28,627 km', '76,801 km', '60,776 km',
#        '74,356 km', '118,250 km', '125,400 km', '76,618 km', '238,500 km',
#        '75,012 km', '114,236 km', '46,027 km', '275,000 km', '60,790 km',
#        '77,429 km', '148,008 km', '43,244 km', '30,231 km', '52,363 km',
#        '66,490 km', '39,882 km', '78,746 km', '11,450 km', '22,182 km',
#        '90,523 km', '13,900 km', '126,377 km', '225 km', '203,900 km',
#        '982,000 km', '69,600 km', '70,125 km', '63,850 km', '134,978 km',
#        '102,985 km', '76,200 km', '12,541 km', '14,150 km', '211,345 km',
#        '54,650 km', '38,451 km', '110,290 km', '77,146 km', '82,620 km',
#        '82,790 km', '112,567 km', '80,100 km', '50 km', '14,100 km',
#        '125,528 km', '90,500 km', '79,130 km', '67,350 km', '2,407 km',
#        '250 km', '99,950 km', '49,824 km', '4,601 km', '385,000 km',
#        '72,200 km', '156,324 km', '26,902 km', '19,600 km', '45,668 km',
#        '250,055 km', '159,845 km', '2,017 km', '29,321 km', '33,045 km',
#        '15,367 km', '11,530 km', '125,633 km', '75,251 km', '58,900 km',
#        '89,134 km', '51,258 km', '60,100 km', '71,100 km', '38,200 km',
#        '122,600 km', '272,000 km', '233,195 km', '3,250 km', '27,750 km',
#        '65,880 km', '196,532 km', '169,500 km', '136,923 km', '45,400 km',
#        '111,100 km', '97,150 km', '21,100 km', '17,770 km', '168,200 km',
#        '69 km', '141,300 km', '398,542 km', '164,799 km', '55,300 km',
#        '44,796 km', '19,906 km', '21,726 km', '229,000 km', '9,756 km',
#        '29,650 km', '48,650 km', '97,333 km', '48,100 km', '82,796 km',
#        '74,862 km', '15,082 km', '35,095 km', '145,883 km', '125,627 km',
#        '59,876 km', '3,600 km', '246,360 km', '71,843 km', '36,152 km',
#        '187,941 km', '298,568 km', '69,345 km', '125,444 km', '81,750 km',
#        '75,241 km', '68,542 km', '215,324 km', '124,147 km', '30,650 km',
#        '198,450 km', '9,006 km', '31,150 km', '12,580 km', '150,009 km',
#        '286,000 km', '109,523 km', '82,250 km', '10,165 km', '94,620 km',
#        '45,100 km', '20,400 km', '39,842 km', '84,543 km', '15,244 km',
#        '232,156 km', '123,980 km', '132,562 km', '167,532 km',
#        '141,523 km', '1,350 km', '150,500 km', '269,341 km', '6,450 km',
#        '179,300 km', '110,200 km', '48,700 km', '21,120 km', '18,650 km',
#        '91,083 km', '6,248 km', '4,700 km', '6,634 km', '125,809 km',
#        '163,805 km', '158,843 km', '30,894 km', '12,412 km', '52,700 km',
#        '153,376 km', '322,246 km', '265,000 km', '94,125 km',
#        '103,978 km', '267,000 km', '81,755 km', '40,125 km', '219,011 km',
#        '5,900 km', '65,896 km', '16,054 km', '37,542 km', '167,854 km',
#        '71,247 km', '38,745 km', '121,400 km', '132,280 km', '39,441 km',
#        '97,400 km', '114,200 km', '30,920 km', '192,965 km', '109,592 km',
#        '165,930 km', '99,600 km', '43,800 km', '167,342 km', '192,116 km',
#        '146,151 km', '79,450 km', '125,600 km', '86,341 km', '193,036 km',
#        '157,267 km', '245,825 km', '232,500 km', '105,718 km',
#        '666,677 km', '100,156 km', '202,445 km', '75,560 km', '44,612 km',
#        '140,532 km', '78,109 km', '41,650 km', '523,147 km', '31,300 km',
#        '114,005 km', '137,980 km', '73,741 km', '85,456 km', '137,423 km',
#        '57,612 km', '17,654 km', '151,050 km', '81,120 km', '27,252 km',
#        '33,300 km', '235,333 km', '88,806 km', '91,700 km', '150,800 km',
#        '242,000 km', '385,194 km', '36,120 km', '72,400 km', '77 km',
#        '249,698 km', '79,423 km', '151,950 km', '97,950 km', '18,700 km',
#        '113,795 km', '198,500 km', '16,527 km', '12,340 km', '12,543 km',
#        '52,960 km', '17,854 km', '5,847 km', '26,237 km', '108,900 km',
#        '36,828 km', '123,102 km', '89,034 km', '14,210 km', '2,100 km',
#        '330,000 km', '247,487 km', '114,586 km', '40,144 km', '95,132 km',
#        '34,650 km', '36,254 km', '56,800 km', '173,473 km', '71,692 km',
#        '213,000 km', '232,161 km', '65,750 km', '26,100 km', '8,700 km',
#        '168,546 km', '358,000 km', '92,600 km', '141,500 km',
#        '342,000 km', '191,700 km', '120,500 km', '328,000 km',
#        '40,700 km', '208,835 km', '233,150 km', '1,000,000 km',
#        '183,310 km', '67,800 km', '13,680 km', '6,200 km', '57,975 km',
#        '11,327 km', '88,134 km', '112,543 km', '99,940 km', '396,744 km',
#        '46,510 km', '365,590 km', '27,085 km', '65,650 km', '68,861 km',
#        '46,350 km', '107,222 km', '313,163 km', '105,874 km',
#        '146,523 km', '4,788 km', '76,231 km', '550,000 km', '22,522 km',
#        '105,950 km', '307,386 km', '10,600 km', '287,000 km', '47,660 km',
#        '56,338 km', '248,600 km', '88,850 km', '89,808 km', '16,995 km',
#        '16,700 km', '113,376 km', '242,130 km', '53,516 km', '171,278 km',
#        '266,000 km', '263,950 km', '6,550 km', '266,941 km', '111,200 km',
#        '178,170 km', '268,000 km', '98,800 km', '33,800 km', '72,174 km',
#        '11,178 km', '92,480 km', '179,766 km', '111,345 km', '47,900 km',
#        '201,660 km', '247,422 km', '116,977 km', '98,141 km',
#        '263,000 km', '22,337 km', '21,236 km', '77,030 km', '165,304 km',
#        '98,812 km', '86,478 km', '43,914 km', '61,668 km', '31,521 km',
#        '38,541 km', '124,154 km', '100,869 km', '90,274 km', '287,564 km',
#        '131,600 km', '17,122 km', '2,581 km', '3 km', '137,299 km',
#        '167,490 km', '29,227 km', '58,499 km', '35,421 km', '8,025 km',
#        '157,800 km', '260,500 km', '244,000 km', '26,800 km', '77,300 km',
#        '397,998 km', '46,375 km', '122,536 km', '45,807 km', '63,809 km',
#        '100,008 km', '23,383 km', '96,452 km', '36,541 km', '101,375 km',
#        '1,200 km', '15,200 km', '4 km', '295,714 km', '137,200 km',
#        '239,124 km', '70,200 km', '162,629 km', '256,740 km', '41,200 km',
#        '163,923 km', '271,373 km', '46,002 km', '43,666 km', '39,875 km',
#        '77,700 km', '123,156 km', '115,359 km', '10,047 km', '79,900 km',
#        '40,854 km', '204,910 km', '97,100 km', '101,550 km', '145,090 km',
#        '95,413 km', '64,170 km', '151,234 km', '14,312 km', '29,652 km',
#        '52,760 km', '151,813 km', '44,540 km', '26,975 km', '166,091 km',
#        '87,422 km', '74,523 km', '168,120 km', '96,483 km', '20,543 km',
#        '194,931 km', '165,891 km', '90,696 km', '143,550 km',
#        '201,134 km', '68,626 km', '56,985 km', '36,521 km', '60,940 km',
#        '37,625 km', '66,800 km', '111,450 km', '39,400 km', '96,800 km',
#        '42,700 km', '185,551 km', '375,000 km', '126,555 km',
#        '125,325 km', '56,412 km', '141,350 km', '45,284 km', '147,200 km',
#        '91,245 km', '104,200 km', '4,985 km', '10 km', '41,852 km',
#        '69,834 km', '86,523 km', '128,331 km', '86,115 km', '166,522 km',
#        '19,999 km', '159,990 km', '1,700 km', '6,400 km', '55,500 km',
#        '18,562 km', '97,900 km', '94,300 km', '113,300 km', '67,950 km',
#        '64,829 km', '97,598 km', '162,322 km', '98,600 km', '105,600 km',
#        '131,549 km', '150,769 km', '163,822 km', '148,515 km',
#        '122,552 km', '103,017 km', '193,778 km', '77,930 km', '25,069 km',
#        '119 km', '167,543 km', '119,235 km', '45,325 km', '24,009 km',
#        '135,045 km', '143,852 km', '39,103 km', '36,128 km', '24,130 km',
#        '53,200 km', '74,667 km', '22,220 km', '67,200 km', '30,450 km',
#        '124,587 km', '131,250 km', '44,860 km', '113,265 km', '95,279 km',
#        '299,900 km', '14,299 km', '50,446 km', '81,250 km', '99,449 km',
#        '83,698 km', '61,113 km', '81,311 km', '184,700 km', '255,000 km',
#        '36,425 km', '221,324 km', '126,498 km', '81,235 km', '87,452 km',
#        '60,120 km', '35,046 km', '6,425 km', '71,234 km', '137,800 km',
#        '114,567 km', '89,750 km', '78,675 km', '112,546 km', '87,919 km',
#        '89,526 km', '177,884 km', '122,692 km', '9,490 km', '105,200 km',
#        '298,000 km', '37,514 km', '25,007 km', '170,600 km', '60,800 km',
#        '235,822 km', '1,300 km', '111,813 km', '189,560 km', '49,644 km',
#        '214,590 km', '71,759 km', '136,481 km', '261,200 km', '38,890 km',
#        '48,250 km', '167,454 km', '65,560 km', '47,626 km', '46,214 km',
#        '120,625 km', '29,315 km', '19,291 km', '82,150 km', '181,250 km',
#        '66,478 km', '45,581 km', '176,378 km', '40,237 km', '85,961 km',
#        '123,689 km', '87,654 km', '104,534 km', '63,457 km', '75,400 km',
#        '306,705 km', '131,346 km', '63,800 km', '145,100 km',
#        '224,300 km', '56,856 km', '194,100 km', '116,631 km', '28,999 km',
#        '65,100 km', '650,040 km', '188,260 km', '262,000 km', '60,040 km',
#        '107,817 km', '49,520 km', '105,051 km', '147,119 km',
#        '117,130 km', '64,750 km', '74,925 km', '1,268 km', '59,600 km',
#        '38,100 km', '10,100 km', '218,000 km', '12,360 km', '1,950 km',
#        '75,300 km', '88,670 km', '49,025 km', '136,847 km', '34,094 km',
#        '98,537 km', '391,000 km', '174,800 km', '450,500 km', '11,300 km',
#        '137,847 km', '280,194 km', '130,425 km', '21,768 km', '21,984 km',
#        '13,070 km', '61,342 km', '33,166 km', '61,391 km', '55,870 km',
#        '99,150 km', '77,604 km', '183,762 km', '82,123 km', '43,250 km',
#        '277,146 km', '59,018 km', '63,532 km', '41,460 km', '89,081 km',
#        '235,682 km', '72,100 km', '16,200 km', '230,863 km', '35,700 km',
#        '85,637 km', '293,000 km', '889,703 km', '107,015 km',
#        '319,912 km', '29,899 km', '45,254 km', '175,850 km', '36,700 km',
#        '27,621 km', '42,584 km', '41,865 km', '45,874 km', '132,870 km',
#        '43,400 km', '57,587 km', '115,850 km', '137,300 km', '390,085 km',
#        '39,241 km', '17,886 km', '299,000 km', '53,075 km', '57,245 km',
#        '100,900 km', '14,997 km', '380,000 km', '67,700 km', '28,293 km',
#        '59,863 km', '119,955 km', '22,144 km', '97,274 km', '11,447 km',
#        '124,693 km', '90,130 km', '73,293 km', '57,100 km', '104,508 km',
#        '87,788 km', '45,882 km', '183,388 km', '780,000 km', '42,150 km',
#        '20,005 km', '259,590 km', '52,147 km', '63,080 km', '145,638 km',
#        '42,512 km', '42,295 km', '36,452 km', '40,876 km', '53,280 km',
#        '21,157 km', '129,100 km', '114,500 km', '42,399 km', '44,309 km',
#        '93,153 km', '138,254 km', '27,486 km', '216,421 km', '397,000 km',
#        '99,897 km', '263,684 km', '174,041 km', '191,896 km',
#        '235,590 km', '90,928 km', '245,872 km', '344,165 km',
#        '200,500 km', '60,540 km', '34,300 km', '126,375 km', '153,233 km',
#        '64,304 km', '246,257 km', '278,000 km', '69,537 km', '52,160 km',
#        '15,300 km', '103,297 km', '180,050 km', '3,347 km', '274,000 km',
#        '133,546 km', '77,775 km', '22,985 km', '67,930 km', '84,507 km',
#        '85,825 km', '58,871 km', '104,861 km', '14,152 km', '15,949 km',
#        '48,935 km', '106,950 km', '207,620 km', '169,850 km',
#        '241,311 km', '38,645 km', '246,000 km', '325,000 km', '88,985 km',
#        '16,250 km', '17,708 km', '162,354 km', '40,851 km', '131,319 km',
#        '125,870 km', '118,450 km', '205,255 km', '94,201 km', '12,854 km',
#        '54,800 km', '186,200 km', '109,198 km', '121,990 km', '62,400 km',
#        '87,100 km', '106,700 km', '82,300 km', '89,900 km', '65,555 km',
#        '100,060 km', '217,000 km', '95,800 km', '30,200 km', '208,540 km',
#        '90,409 km', '8,400 km', '259,714 km', '126,023 km', '138,800 km',
#        '127,996 km', '100,420 km', '98,536 km', '67,861 km', '3,150 km',
#        '115,215 km', '238,000 km', '248,000 km', '82,655 km',
#        '412,000 km', '27,650 km', '38,650 km', '45,178 km', '9,450 km',
#        '156,520 km', '188,890 km', '68,564 km', '112,600 km',
#        '214,567 km', '201,350 km', '12,600 km', '26,236 km', '90,200 km',
#        '51,119 km', '26,614 km', '183,021 km', '21,300 km', '198,200 km',
#        '82,445 km', '68,075 km', '95,282 km', '60,769 km', '35,875 km',
#        '289,543 km', '114,360 km', '67,581 km', '252,500 km', '89,830 km',
#        '99,700 km', '143,790 km', '184,800 km', '97,800 km', '45,204 km',
#        '68,463 km', '69,490 km', '80,421 km', '136,845 km', '47,526 km',
#        '395,000 km', '68,300 km', '327,600 km', '75,500 km', '95,509 km',
#        '142,600 km', '141,675 km', '66,480 km', '232,000 km',
#        '129,028 km', '450 km', '40,120 km', '112,723 km', '51,870 km',
#        '132,800 km', '71,926 km', '118,551 km', '192,500 km',
#        '147,212 km', '116,532 km', '74,563 km', '89,600 km', '40,785 km',
#        '146,500 km', '425,000 km', '122,721 km', '79,980 km',
#        '280,104 km', '47,956 km', '12,525 km', '189,567 km', '112,227 km',
#        '114,520 km', '154,400 km', '98,700 km', '128,520 km', '84,700 km',
#        '100 km', '6,800 km', '85,614 km', '149,854 km', '10,250 km',
#        '146,987 km', '100,295 km', '165,428 km', '155,236 km',
#        '164,200 km', '15,658 km', '67,098 km', '85,379 km', '82,128 km',
#        '213,911 km', '79,320 km', '114,765 km', '77,677 km', '107,017 km',
#        '70,001 km', '230,001 km', '139,652 km', '95,300 km', '98,523 km',
#        '99,819 km', '132,233 km', '34,955 km', '145,500 km', '84,462 km',
#        '125,412 km', '113,452 km', '57,300 km', '85,830 km', '192,033 km',
#        '102,145 km', '96,818 km', '75,358 km', '66,777 km', '64,720 km',
#        '80 km', '60,284 km', '4,996 km', '26,254 km', '28,509 km',
#        '159,880 km', '46,796 km', '27,914 km', '55,142 km', '156,624 km',
#        '83,119 km', '4,800 km', '99,840 km', '142,208 km', '130,350 km',
#        '41,752 km', '41,864 km', '251,424 km', '296,210 km', '77,422 km',
#        '119,088 km', '157,714 km', '323,480 km', '37,900 km',
#        '198,520 km', '212,702 km', '182,650 km', '317,225 km',
#        '36,350 km', '63,540 km', '324,000 km', '72,460 km', '19,460 km',
#        '155,148 km', '143,987 km', '90,664 km', '220,067 km', '31,977 km',
#        '43,560 km', '29,840 km', '167,986 km', '165,999 km', '115,098 km',
#        '168,542 km', '221,000 km', '59,880 km', '199,993 km', '37,108 km',
#        '95,808 km', '39,643 km', '37,268 km', '165,289 km', '243,645 km',
#        '107,220 km', '25,661 km', '256,901 km', '33,700 km', '13,530 km',
#        '2,150 km', '201,633 km', '158,205 km', '103,500 km', '40,657 km',
#        '239,000 km', '42,542 km', '434,319 km', '127,583 km',
#        '227,500 km', '222,124 km', '174,037 km', '81,400 km',
#        '214,500 km', '98,522 km', '110,320 km', '218,900 km', '12,054 km',
#        '10,502 km', '127,706 km', '45,298 km', '128,980 km', '61,110 km',
#        '188,500 km', '99,990 km', '25,662 km', '99,999 km', '249,027 km',
#        '143,255 km', '34,173 km', '62,879 km', '142,550 km', '98,575 km',
#        '244,773 km', '70,833 km', '213,870 km', '5 km', '42,554 km',
#        '102,200 km', '995,699 km', '69,200 km', '165,842 km', '55,030 km',
#        '171,200 km', '5,050 km', '73,165 km', '286,991 km', '14,670 km',
#        '85,900 km', '63,700 km', '55,256 km', '36,850 km', '20,434 km',
#        '81,434 km', '61,800 km', '120,300 km', '53,728 km', '50,700 km',
#        '78,800 km', '136,745 km', '151,452 km', '65,423 km', '115,700 km',
#        '93,800 km', '27,200 km', '20 km', '56,132 km', '95,008 km',
#        '177,452 km', '81,450 km', '99,808 km', '98,870 km', '149,358 km',
#        '127,855 km', '60,250 km', '30,498 km', '44,871 km', '57,423 km',
#        '72,333 km', '135,680 km', '62,797 km', '117,525 km', '106,445 km',
#        '700 km', '16,400 km', '40,872 km', '33,723 km', '87,750 km',
#        '15,222 km', '65,876 km', '19,700 km', '10,700 km', '15,109 km',
#        '192,860 km', '181,650 km', '110,533 km', '33,608 km', '77,583 km',
#        '78,523 km', '113,560 km', '158,692 km', '93,763 km', '24,700 km',
#        '46,300 km', '99,400 km', '154,250 km', '96,260 km', '101,122 km',
#        '74,512 km', '156,100 km', '118,900 km', '49,400 km', '63,401 km',
#        '74,620 km', '110,500 km', '72,005 km', '29,820 km', '65,950 km',
#        '82,005 km', '112,850 km', '75,002 km', '71,005 km', '12,100 km',
#        '63,652 km', '87,456 km', '47,288 km', '227,624 km', '82,133 km',
#        '27 km', '196,498 km', '8,944 km', '76,533 km', '980,000 km',
#        '48,336 km', '67,900 km', '72,555 km', '152,545 km', '155,673 km',
#        '98,650 km', '52,600 km', '167,800 km', '46,980 km', '40,900 km',
#        '102,900 km', '80,250 km', '5,864 km', '66,553 km', '95,088 km',
#        '92,708 km', '24,600 km', '81,241 km', '84,172 km', '33,564 km',
#        '428,400 km', '38,205 km', '105,010 km', '23,825 km', '88,487 km',
#        '58,320 km', '103,124 km', '77,162 km', '113,523 km', '17,689 km',
#        '212,900 km', '72,785 km', '79,877 km', '90,800 km', '115 km',
#        '115,008 km', '98,653 km', '13,950 km', '49,490 km', '118 km',
#        '143,434 km', '90,400 km', '35,471 km', '42,567 km', '67,053 km',
#        '12,992 km', '29,656 km', '124,650 km', '64,600 km', '2,200 km',
#        '20,850 km', '11,562 km', '261,537 km', '41,214 km', '100,005 km',
#        '200,175 km', '122,474 km', '129,020 km', '147,990 km',
#        '84,630 km', '89,773 km', '31,900 km', '11,062 km', '78,835 km',
#        '164,500 km', '188,010 km', '41,320 km', '84,521 km', '15,400 km',
#        '109,700 km', '200,499 km', '106,234 km', '133,989 km',
#        '71,300 km', '41,857 km', '132,845 km', '49,827 km', '590,000 km',
#        '32,793 km', '14,530 km', '74,690 km', '64,514 km', '44,150 km',
#        '264,000 km', '15,700 km', '102,400 km', '104,290 km', '88,662 km',
#        '136,542 km', '52,400 km', '180,265 km', '13,599 km', '58,950 km',
#        '18,826 km', '80,600 km', '21,860 km', '94,904 km', '19,745 km',
#        '9 km', '116 km', '85,168 km', '65,134 km', '203,801 km',
#        '7,922 km', '82,718 km', '37,800 km', '216,400 km', '12,285 km',
#        '128,431 km', '44,713 km', '35,092 km', '145,414 km', '34,200 km',
#        '78,120 km', '102,381 km', '59,885 km', '12,700 km', '84,527 km',
#        '151,200 km', '101,200 km', '4,500 km', '123,985 km', '76,412 km',
#        '45,143 km', '193,300 km', '39,900 km', '44,800 km', '55,885 km',
#        '102,623 km', '59,565 km', '309,800 km', '120,332 km', '8,750 km',
#        '87,008 km', '114,232 km', '36,561 km', '113,600 km', '69,180 km',
#        '24,587 km', '83,700 km', '84,450 km', '66,632 km', '73,600 km',
#        '238,200 km', '42,900 km', '41,432 km', '122,865 km', '185,620 km',
#        '23,200 km', '118,500 km', '15,430 km', '16,584 km', '27,208 km',
#        '96,562 km', '36,306 km', '14,358 km', '145,280 km', '215,077 km',
#        '37,652 km', '364,146 km', '223,800 km', '14,570 km', '181,938 km',
#        '18,600 km', '128,548 km', '17,552 km', '154,354 km', '173,273 km',
#        '66,660 km', '50,175 km', '75,856 km', '68,250 km', '74,661 km',
#        '137,771 km', '144,632 km', '169,421 km', '215,893 km',
#        '63,125 km', '149,900 km', '41,045 km', '60,270 km', '271,855 km',
#        '44,300 km', '117,065 km', '204,900 km', '147,600 km', '42,028 km',
#        '62,920 km', '73,400 km', '60,481 km', '46,782 km', '103,075 km',
#        '8,525 km', '30 km', '40,201 km', '21,650 km', '28,150 km',
#        '59,200 km', '48,446 km', '43,875 km', '570,000 km', '66,221 km',
#        '46,550 km', '208,040 km', '128,708 km', '33,953 km', '105,700 km',
#        '43,520 km', '89,250 km', '138,120 km', '50,600 km', '75,100 km',
#        '201,385 km', '112,778 km', '28,600 km', '36,900 km', '214,200 km',
#        '68,209 km', '44,251 km', '39,300 km', '26,300 km', '125,700 km',
#        '201,352 km', '39,653 km', '27,854 km', '120,033 km', '94,791 km',
#        '7,693 km', '60,400 km', '182,389 km', '145,620 km', '194,523 km',
#        '74,468 km', '9,825 km', '37,200 km', '23,003 km', '177,502 km',
#        '65,418 km', '33,311 km', '71,998 km', '18,415 km', '142,598 km',
#        '66,250 km', '11,040 km', '11,400 km', '119,453 km', '52,300 km',
#        '165,212 km', '10,200 km', '132,546 km', '31,905 km', '114,140 km',
#        '361,254 km', '47,568 km', '26,753 km', '66,755 km', '35,542 km',
#        '45,343 km', '189,045 km', '100,601 km', '135,232 km', '75,365 km',
#        '70,474 km', '154,500 km', '88,400 km', '181,360 km', '219,069 km',
#        '42,457 km', '70,997 km', '141,265 km', '125,962 km', '110,450 km',
#        '18,400 km', '112,453 km', '175 km', '114,860 km', '155,095 km',
#        '175,889 km', '34,098 km', '67,853 km', '165,406 km', '127,822 km',
#        '82,100 km', '15,683 km', '153,680 km', '91,320 km', '45 km',
#        '110,526 km', '104,632 km', '3,700 km', '32,584 km', '37,864 km',
#        '63,835 km', '285 km', '84,800 km', '88,800 km', '6,900 km',
#        '44,999 km', '14,400 km', '135,534 km', '48,020 km', '80,234 km',
#        '137,522 km', '9,700 km', '301,200 km', '90,415 km', '96,600 km',
#        '74,560 km', '64,136 km', '145,600 km', '73,250 km', '36,600 km',
#        '37,100 km', '25,400 km', '85,620 km', '273,000 km', '5,878 km',
#        '203,438 km', '157,292 km', '26,864 km', '7,531 km', '23,485 km',
#        '32,754 km', '112,550 km', '145,975 km', '8,100 km', '84,893 km',
#        '7,690 km', '35,412 km', '151,500 km', '9,567 km', '85,224 km',
#        '249,000 km', '312,000 km', '205,667 km', '283,073 km', '1,600 km',
#        '31,523 km', '120,253 km', '388,000 km', '138,231 km',
#        '112,326 km', '21,137 km', '2,880 km', '72,980 km', '74,263 km',
#        '203,000 km', '94,309 km', '50,300 km', '59,948 km', '29,523 km',
#        '78,465 km', '70,109 km', '29,331 km', '220,629 km', '138,481 km',
#        '186,360 km', '99,595 km', '134,467 km', '92,038 km', '193,195 km',
#        '36,437 km', '39,654 km', '125,698 km', '139,866 km', '3,100 km',
#        '42,100 km', '115,356 km', '956,384 km', '201,569 km',
#        '145,040 km', '87,587 km', '85,910 km', '62,928 km', '127,700 km',
#        '74,534 km', '2,060 km', '17,700 km', '95,580 km', '73,469 km',
#        '247,547 km', '187,410 km', '47,826 km', '63,300 km', '38,400 km',
#        '128,931 km', '45,012 km', '59,700 km', '51,200 km', '74,300 km',
#        '126,398 km', '136,700 km', '66,639 km', '83,520 km', '172,712 km',
#        '60,550 km', '69,980 km', '182,074 km', '45,602 km', '206,739 km',
#        '8,060 km', '20,395 km', '175,434 km', '28,400 km', '54,950 km',
#        '109,600 km', '89,635 km', '190,125 km', '28,794 km', '146,800 km',
#        '201,966 km', '174,609 km', '98,200 km', '60,630 km', '17,950 km',
#        '49,120 km', '237,972 km', '64,513 km', '680,000 km', '43,163 km',
#        '130,133 km', '72,950 km', '16,433 km', '39,676 km', '31,240 km',
#        '160,500 km', '98,100 km', '243,200 km', '36,854 km', '199,889 km',
#        '148,733 km', '3,762 km', '109,254 km', '233,200 km', '61,282 km',
#        '46,288 km', '54,300 km', '60,842 km', '313,935 km', '80,320 km',
#        '68,971 km', '131,900 km', '20,130 km', '19,718 km', '141,913 km',
#        '68,292 km', '88,607 km', '94,100 km', '100,282 km', '97,300 km',
#        '67,650 km', '28,590 km', '121,046 km', '91,055 km', '108,770 km',
# ...
#        '94,844 km', '6,034 km', '52,650 km', '40,856 km', '35,483 km',
#        '21,876 km', '13,475 km', '4,271 km', '96,032 km', '49,423 km',
#        '24,260 km', '24,650 km', '129,927 km', '55,710 km', '67,194 km',
#        '11,194 km', '162,475 km', '36,815 km', '28,359 km', '29,464 km',
#        '31,848 km', '28,164 km', '59,900 km', '45,963 km', '86,890 km',
#        '167,600 km', '21,149 km', '45,200 km', '83,256 km', '102,429 km',
#        '146,852 km', '21,394 km', '90,658 km', '44,550 km', '11,111 km',
#        '21,661 km', '116,891 km', '49,875 km', '286,122 km', '138,789 km',
#        '71,122 km', '80,448 km', '62,161 km', '68,006 km', '76,346 km',
#        '470,000 km', '38,540 km', '536,892 km', '11,825 km', '9,723 km',
#        '60,907 km', '111,785 km', '89,254 km', '84,950 km', '128,600 km',
#        '28,965 km', '165,723 km', '95,745 km', '105,423 km', '31,534 km',
#        '159,701 km', '39,694 km', '150,427 km', '79,400 km', '4,400 km',
#        '313,663 km', '163,074 km', '143,500 km', '75,999 km',
#        '132,450 km', '185,266 km', '257,490 km', '124,108 km',
#        '202,250 km', '241,586 km', '85,469 km', '287,490 km', '23,905 km',
#        '245,890 km', '324,150 km', '70,321 km', '100,200 km', '48,524 km',
#        '57,200 km', '31,821 km', '29,072 km', '84,588 km', '26,665 km',
#        '57,960 km', '73,680 km', '68,780 km', '72,943 km', '83,280 km',
#        '91,650 km', '128,323 km', '24,667 km', '8,119 km', '115,516 km',
#        '11,511 km', '125,495 km', '184,340 km', '103,235 km',
#        '112,278 km', '40,541 km', '171,013 km', '12,694 km', '66,572 km',
#        '160,030 km', '125,840 km', '100,600 km', '50,390 km', '66,750 km',
#        '67,458 km', '14,375 km', '847,802 km', '58,348 km', '98,985 km',
#        '98,470 km', '31,586 km', '122,568 km', '287,149 km', '324,752 km',
#        '98,742 km', '166,497 km', '41,728 km', '17,748 km', '43,196 km',
#        '33,483 km', '80,766 km', '35,967 km', '178,621 km', '62,761 km',
#        '29,592 km', '51,715 km', '27,960 km', '8,939 km', '26,811 km',
#        '40,336 km', '73,509 km', '28,963 km', '13,360 km', '111,902 km',
#        '118,458 km', '296,400 km', '153,850 km', '84,190 km', '24,632 km',
#        '90,700 km', '23,290 km', '121,612 km', '33,929 km', '42,754 km',
#        '45,852 km', '189,632 km', '126,802 km', '83,667 km', '110,037 km',
#        '44,874 km', '261,000 km', '8,564 km', '41,950 km', '147,800 km',
#        '49,970 km', '153,254 km', '43,064 km', '42,840 km', '333,600 km',
#        '40,818 km', '169,901 km', '157,520 km', '86,520 km', '850 km',
#        '81,230 km', '25,900 km', '40,150 km', '31,267 km', '163,100 km',
#        '95,241 km', '119,856 km', '84,030 km', '52,686 km', '730,710 km',
#        '54,068 km', '114,100 km', '150,029 km', '258,796 km', '914 km',
#        '132,200 km', '74,179 km', '66,740 km', '52,069 km', '56,926 km',
#        '89,050 km', '35,580 km', '790,000 km', '9,350 km', '411,288 km',
#        '97,264 km', '90,499 km', '125,086 km', '55,138 km', '19,236 km',
#        '168,850 km', '101,275 km', '47,234 km', '112,987 km', '86,278 km',
#        '230,858 km', '37,644 km', '106,880 km', '220,244 km', '91,819 km',
#        '32,300 km', '45,007 km', '72,690 km', '61,548 km', '18,589 km',
#        '16,678 km', '154,600 km', '143,734 km', '39,740 km', '215,598 km',
#        '7,874 km', '191,228 km', '64,320 km', '44,513 km', '86,322 km',
#        '106,073 km', '122,670 km', '77,240 km', '151,817 km',
#        '245,553 km', '123,555 km', '25,840 km', '84,678 km', '185,425 km',
#        '88,425 km', '73,848 km', '90,610 km', '24,530 km', '29,785 km',
#        '34,977 km', '99,383 km', '107,105 km', '199,320 km', '43,230 km',
#        '99,286 km', '130,664 km', '198,552 km', '100,696 km', '75,135 km',
#        '23,120 km', '55,580 km', '54,440 km', '128,879 km', '89,300 km',
#        '68,633 km', '254,500 km', '60,720 km', '14,982 km', '42,651 km',
#        '123,470 km', '46,157 km', '83,010 km', '56,600 km', '43,302 km',
#        '150,200 km', '26,700 km', '67,815 km', '45,721 km', '25,632 km',
#        '136,852 km', '142,456 km', '189,348 km', '36,780 km',
#        '177,800 km', '46,700 km', '51,700 km', '47,300 km', '1,264 km',
#        '45,682 km', '48,652 km', '17,100 km', '67,157 km', '129,999 km',
#        '77,424 km', '74,234 km', '93,899 km', '184,300 km', '24,764 km',
#        '58,983 km', '65,191 km', '56,938 km', '28,515 km', '45,875 km',
#        '139,900 km', '113,268 km', '100,100 km', '87,319 km',
#        '125,343 km', '180,213 km', '22,565 km', '101,812 km',
#        '152,193 km', '156,500 km', '76,250 km', '41,630 km', '625,000 km',
#        '6,542 km', '46,542 km', '47,521 km', '105,300 km', '382,500 km',
#        '42,359 km', '73,831 km', '68,357 km', '470,400 km', '25,625 km',
#        '63,867 km', '11,242 km', '113,782 km', '28,329 km', '187,482 km',
#        '131,975 km', '280,661 km', '19,995 km', '36,526 km', '125,863 km',
#        '76,280 km', '55,160 km', '157,957 km', '148,815 km', '247,456 km',
#        '123,420 km', '32,568 km', '108,750 km', '162,778 km', '66,773 km',
#        '253,064 km', '61,450 km', '187,880 km', '5,590 km', '61,499 km',
#        '122,800 km', '89,421 km', '118,523 km', '85,530 km', '45,010 km',
#        '78,251 km', '61,550 km', '62,428 km', '96,350 km', '80,488 km',
#        '113,950 km', '85,107 km', '60,128 km', '117,123 km', '97,841 km',
#        '187,400 km', '44,091 km', '37,456 km', '55,168 km', '165,357 km',
#        '43,495 km', '155,563 km', '127,466 km', '21,830 km', '90,078 km',
#        '234,768 km', '310,234 km', '150,130 km', '54,801 km', '47,260 km',
#        '186,453 km', '361,000 km', '58,460 km', '110,563 km', '26,013 km',
#        '22,052 km', '87,574 km', '70,475 km', '102,910 km', '256,968 km',
#        '288,520 km', '81,700 km', '53,446 km', '35,509 km', '144,700 km',
#        '53,626 km', '98,080 km', '99,696 km', '87,087 km', '249,451 km',
#        '172,500 km', '37,960 km', '34,636 km', '40,710 km', '134,483 km',
#        '120,452 km', '79,675 km', '122,586 km', '9,930 km', '94,150 km',
#        '98,652 km', '137,564 km', '158,946 km', '88,860 km', '76,549 km',
#        '277,881 km', '41,545 km', '98,374 km', '111,578 km', '74,588 km',
#        '14,070 km', '157,420 km', '110,810 km', '149,128 km', '87,680 km',
#        '124,262 km', '401,000 km', '226,531 km', '64,762 km', '20,364 km',
#        '38,730 km', '141,440 km', '115,950 km', '31,425 km', '109,400 km',
#        '127,210 km', '107,321 km', '98,734 km', '200,200 km', '94,800 km',
#        '44,768 km', '132,765 km', '74,532 km', '47,090 km', '120,939 km',
#        '17,423 km', '133,906 km', '95,336 km', '123,686 km', '97,650 km',
#        '172,600 km', '63,590 km', '233,731 km', '116,552 km',
#        '196,568 km', '124,512 km', '181,212 km', '118,199 km',
#        '111,480 km', '123,488 km', '106,750 km', '169,778 km',
#        '172,246 km', '97,279 km', '120,753 km', '147,819 km', '50,176 km',
#        '127,451 km', '18,800 km', '88,256 km', '39,119 km', '75,700 km',
#        '148,791 km', '23,431 km', '88,625 km', '129,600 km', '40,400 km',
#        '350 km', '99,357 km', '23,154 km', '40,148 km', '46,754 km',
#        '7,421 km', '67,580 km', '46,874 km', '23,103 km', '103,526 km',
#        '100,151 km', '198,560 km', '2,593 km', '68,590 km', '130,001 km',
#        '43,842 km', '368,000 km', '324,590 km', '162,772 km', '54,356 km',
#        '132,560 km', '132,590 km', '64,100 km', '83,690 km', '281,240 km',
#        '157,890 km', '64,900 km', '72,123 km', '323,815 km', '425,132 km',
#        '90,300 km', '12,536 km', '200,582 km', '25,419 km', '40,279 km',
#        '65,520 km', '135,500 km', '47,350 km', '78,876 km', '26,545 km',
#        '39,100 km', '37,130 km', '96,523 km', '18,245 km', '56,563 km',
#        '57,326 km', '48,247 km', '132,703 km', '85,760 km', '102,340 km',
#        '47,253 km', '3,226 km', '120,680 km', '95,952 km', '11,743 km',
#        '44,735 km', '33,032 km', '8,600 km', '5,653 km', '49,250 km',
#        '46,008 km', '112,650 km', '19,179 km', '45,560 km', '88,590 km',
#        '224,900 km', '84,927 km', '145,025 km', '94,533 km', '105,583 km',
#        '59,514 km', '296,365 km', '5,689 km', '24,739 km', '176,500 km',
#        '91,189 km', '185,623 km', '135,985 km', '72,700 km', '134,695 km',
#        '238,944 km', '345,000 km', '87,578 km', '11,526 km', '75,489 km',
#        '135,662 km', '9,108 km', '28,780 km', '29,920 km', '89,923 km',
#        '28,555 km', '19,124 km', '116,666 km', '176,600 km', '34,547 km',
#        '40,225 km', '31,450 km', '65,096 km', '109,888 km', '124,535 km',
#        '146,100 km', '162,549 km', '177,406 km', '101,220 km',
#        '151,236 km', '61,310 km', '4,474 km', '554,400 km', '41,400 km',
#        '88,386 km', '178,787 km', '315,264 km', '26,200 km', '186,300 km',
#        '33,260 km', '22,950 km', '125,841 km', '152,638 km', '33,472 km',
#        '37,321 km', '129,904 km', '125,450 km', '67,588 km', '108,532 km',
#        '81,140 km', '113,700 km', '41,600 km', '117,131 km', '98,636 km',
#        '190,870 km', '52,029 km', '25,633 km', '203,100 km', '52,250 km',
#        '89,140 km', '25,100 km', '121,675 km', '155,525 km', '163,434 km',
#        '229,346 km', '34,400 km', '14,600 km', '42,568 km', '186,180 km',
#        '40,563 km', '19,937 km', '50,170 km', '186,974 km', '79,683 km',
#        '121,355 km', '143,427 km', '44,523 km', '78,850 km', '28,102 km',
#        '138,480 km', '54,205 km', '176,240 km', '126,750 km', '47,230 km',
#        '134,600 km', '295,469 km', '7,205 km', '112,614 km', '184,600 km',
#        '54,516 km', '64,275 km', '46,217 km', '46,572 km', '33,243 km',
#        '22,142 km', '154,321 km', '89,563 km', '109,800 km', '45,580 km',
#        '44,913 km', '80,750 km', '186,520 km', '15,243 km', '20,389 km',
#        '65,986 km', '15,326 km', '112,100 km', '80,444 km', '249,756 km',
#        '14,534 km', '8,388 km', '46,742 km', '113,564 km', '209,715 km',
#        '122,315 km', '87,270 km', '62,546 km', '181,432 km', '30,621 km',
#        '77,200 km', '179,642 km', '31,202 km', '29,860 km', '47,005 km',
#        '74,564 km', '8,754 km', '2,280 km', '170,190 km', '186,523 km',
#        '227,332 km', '117,856 km', '46,574 km', '189,800 km', '59,567 km',
#        '43,120 km', '157,780 km', '110,369 km', '177,130 km', '17,955 km',
#        '60,082 km', '31,885 km', '125,006 km', '73,750 km', '26,574 km',
#        '181,994 km', '208,200 km', '234,041 km', '99,254 km', '27,100 km',
#        '86,550 km', '104,400 km', '710,000 km', '57,150 km', '46,587 km',
#        '419,000 km', '27,337 km', '131,306 km', '129,584 km',
#        '101,011 km', '35,645 km', '111,556 km', '80,430 km', '11,585 km',
#        '205,099 km', '106,107 km', '238,049 km', '21,694 km', '62,780 km',
#        '24,242 km', '58,423 km', '73,710 km', '92,499 km', '78,240 km',
#        '43,100 km', '136,136 km', '100,955 km', '92,750 km', '150,204 km',
#        '16,670 km', '55,224 km', '70,650 km', '60,070 km', '89,390 km',
#        '79,150 km', '33,707 km', '109,370 km', '99,535 km', '48,255 km',
#        '101,817 km', '74,207 km', '75,610 km', '175,112 km', '158,623 km',
#        '34,040 km', '192,382 km', '110,387 km', '115,119 km', '75,577 km',
#        '87,822 km', '35,963 km', '97,269 km', '42,458 km', '58,339 km',
#        '30,545 km', '113,017 km', '127,053 km', '127,463 km', '79,987 km',
#        '492,000 km', '84,846 km', '43,782 km', '132,900 km', '33,876 km',
#        '56,275 km', '86,250 km', '4,719 km', '152,658 km', '2,453 km',
#        '151,475 km', '128,225 km', '25,742 km', '63,285 km', '114,852 km',
#        '108,452 km', '177,855 km', '122,667 km', '44,055 km',
#        '148,900 km', '51,150 km', '84,150 km', '83,600 km', '53,638 km',
#        '659,000 km', '44,873 km', '112,229 km', '111,531 km', '85,434 km',
#        '51,290 km', '44,192 km', '65,525 km', '39,666 km', '165,294 km',
#        '89,650 km', '4,456 km', '64,590 km', '85,650 km', '118,320 km',
#        '129,860 km', '126,580 km', '234,680 km', '94,849 km',
#        '109,998 km', '93,290 km', '95,026 km', '155,690 km', '122,560 km',
#        '72,510 km', '61,560 km', '198,250 km', '138,560 km', '119,250 km',
#        '36,980 km', '153,261 km', '111,540 km', '255,582 km', '52,365 km',
#        '93,270 km', '59,303 km', '34,450 km', '44,375 km', '156,856 km',
#        '220,229 km', '167,988 km', '188,655 km', '72,142 km',
#        '202,300 km', '17,177 km', '93,005 km', '46,361 km', '182,325 km',
#        '65,055 km', '162,800 km', '177,464 km', '57,643 km', '64,950 km',
#        '60,214 km', '165,800 km', '105,473 km', '185,236 km', '59,360 km',
#        '91,763 km', '144,745 km', '35,749 km', '98,819 km', '61,284 km',
#        '20,810 km', '36,981 km', '334,000 km', '155,886 km', '77,856 km',
#        '173,528 km', '106,300 km', '206,400 km', '168,829 km',
#        '135,999 km', '63,902 km', '85,200 km', '32,965 km', '85,125 km',
#        '123,743 km', '71,456 km', '68,104 km', '93,558 km', '149,776 km',
#        '138,750 km', '25,954 km', '139,231 km', '110,562 km',
#        '100,450 km', '73,388 km', '166,641 km', '105,730 km',
#        '152,099 km', '101,100 km', '195,249 km', '55,400 km', '50,150 km',
#        '58,741 km', '38,690 km', '36,650 km', '68,214 km', '88,760 km',
#        '31,842 km', '5,184 km', '6,451 km', '110,675 km', '36,300 km',
#        '101,135 km', '87,235 km', '50,120 km', '64,300 km', '48,800 km',
#        '120,029 km', '2,080 km', '112,900 km', '64,280 km', '136,991 km',
#        '26,124 km', '168,825 km', '129,817 km', '109,863 km',
#        '179,400 km', '174,963 km', '81,950 km', '33,495 km', '202,027 km',
#        '100,861 km', '226,628 km', '304,910 km', '9,531 km', '51,423 km',
#        '132,526 km', '170,233 km', '96,831 km', '102,576 km', '36,226 km',
#        '70,976 km', '113,544 km', '138,143 km', '69,241 km', '109,445 km',
#        '32,370 km', '50,001 km', '73,924 km', '60,132 km', '52,059 km',
#        '67,293 km', '136,716 km', '176,528 km', '32,271 km', '179,867 km',
#        '42,174 km', '58,911 km', '121,537 km', '42,550 km', '35,391 km',
#        '3,400 km', '37,174 km', '233,361 km', '92,563 km', '61,600 km',
#        '97,999 km', '104,850 km', '146,600 km', '11,525 km', '52,885 km',
#        '52,568 km', '257,313 km', '62,043 km', '118,699 km', '78,112 km',
#        '22,448 km', '138,264 km', '108,342 km', '179,464 km', '7,512 km',
#        '31,542 km', '26,187 km', '29,761 km', '157,166 km', '51,678 km',
#        '293,292 km', '67,716 km', '151,597 km', '180,172 km', '71,667 km',
#        '17,625 km', '18,675 km', '15,150 km', '47,760 km', '29,300 km',
#        '71,544 km', '10,206 km', '83,087 km', '69,783 km', '750 km',
#        '25 km', '1,690 km', '92,204 km', '85,241 km', '178,900 km',
#        '227,675 km', '74,521 km', '37,300 km', '8,450 km', '210,560 km',
#        '82,869 km', '36,124 km', '37,813 km', '139,136 km', '129,252 km',
#        '41,110 km', '40,523 km', '19,457 km', '11,512 km', '110,476 km',
#        '8,153 km', '110,477 km', '51,324 km', '58,970 km', '41,250 km',
#        '96,345 km', '47,514 km', '21,827 km', '182,837 km', '80,293 km',
#        '265,250 km', '50,985 km', '50,260 km', '67,557 km', '114,941 km',
#        '42,163 km', '4,482 km', '154,813 km', '53,978 km', '58,233 km',
#        '90,504 km', '45,708 km', '23,677 km', '126,097 km', '64,250 km',
#        '74,969 km', '2,584 km', '73,160 km', '142,260 km', '89,280 km',
#        '73,450 km', '205,142 km', '150,100 km', '114,340 km',
#        '117,775 km', '860,000 km', '86,392 km', '83,041 km', '103,372 km',
#        '41,980 km', '115,900 km', '251 km', '113,233 km', '156,290 km',
#        '99,957 km', '6,080 km', '79,513 km', '112,852 km', '98,324 km',
#        '210,604 km', '126,440 km', '42,495 km', '31,876 km', '61,723 km',
#        '74,231 km', '92,198 km', '21,543 km', '89,400 km', '196,484 km',
#        '1,480 km', '14,679 km', '41,023 km', '59,835 km', '73,460 km',
#        '115,200 km', '71,551 km', '71,850 km', '60,916 km', '255,304 km',
#        '79,100 km', '22,743 km', '32,600 km', '54,020 km', '100,006 km',
#        '61,400 km', '190,320 km', '75,459 km', '103,700 km', '123,750 km',
#        '22,650 km', '84,265 km', '12,400 km', '19,750 km', '22,289 km',
#        '133,600 km', '89,128 km', '281,675 km', '15,100 km', '77,156 km'],
#       dtype=object)

# %%
#add change the column to int and remove km from the string on rows
carset['Mileage'] = carset['Mileage'].str.split(" ").str.get(0).str.replace(",",'').astype(int)

# %%
#check info
carset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40531 entries, 0 to 40530
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Price         40531 non-null  int64
#  1   Brand         40531 non-null  object
#  2   Model         40531 non-null  object
#  3   Edition       40531 non-null  object
#  4   Year          40531 non-null  int64
#  5   Condition     40531 non-null  object
#  6   Transmission  40531 non-null  object
#  7   Body          40531 non-null  object
#  8   Fuel          40531 non-null  object
#  9   Capacity      40531 non-null  object
#  10  Mileage       40531 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 3.4+ MB
